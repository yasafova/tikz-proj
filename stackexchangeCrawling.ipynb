# %%
import re
import requests
import csv
import os
import time
from bs4 import BeautifulSoup

# Configure API parameters
API_URL = "https://api.stackexchange.com/2.3/questions"
PARAMS = {
    "order": "desc",
    "sort": "activity",
    "tagged": "tikz-pgf",
    "site": "tex",
    "pagesize": 100,
    "filter": "withbody",
    "key": "rl_7GGwTLUfiPg84pCtVMipME7HX"
}

# CSV output structure
CSV_COLUMNS = [
    'code',
    'caption',
    'source_url',
    'libraries',
    'packages',
    'question_id',
    'answer_id',
    'latex_file_path'  # New column for file paths
]

ESSENTIAL_PACKAGES = {'tikz', 'xcolor', 'amsmath', 'pgfplots'}
ESSENTIAL_LIBRARIES = {'arrows.meta', 'calc', 'positioning'}

# Configure output directories
OUTPUT_DIR = "tikz_data"
CODE_DIR = os.path.join(OUTPUT_DIR, "code")
os.makedirs(CODE_DIR, exist_ok=True)

def create_compilable_latex(tikz_code, packages, libraries):
    """Create compilable LaTeX document with full dependencies"""
    # Merge with essential dependencies
    all_packages = ESSENTIAL_PACKAGES.union(packages)
    all_libraries = ESSENTIAL_LIBRARIES.union(libraries)

    # Build package imports
    package_lines = []
    for pkg in all_packages:
        package_lines.append(f"\\usepackage{{{pkg}}}")

    # Build library imports
    library_line = f"\\usetikzlibrary{{{','.join(all_libraries)}}}" if all_libraries else ""

    package_block = "\n".join(package_lines)

    return f"""\\documentclass[crop,tikz]{{standalone}}
{package_block}
{library_line}
\\begin{{document}}
\\begin{{tikzpicture}}
{tikz_code}
\\end{{tikzpicture}}
\\end{{document}}"""


def save_latex_file(tikz_code, question_id, answer_id, packages, libraries):
    """Save TikZ code with proper dependencies"""
    try:
        filename = f"tikz_{question_id}_{answer_id}_{hash(tikz_code) % 1000000}.tex"
        filepath = os.path.join(CODE_DIR, filename)

        full_doc = create_compilable_latex(tikz_code, packages, libraries)

        with open(filepath, 'w', encoding='utf-8') as f:
            f.write(full_doc)

        return filepath

    except Exception as e:
        print(f"Error saving LaTeX file: {str(e)}")
        return None

def extract_tikz_code(body):
    """Extract TikZ code blocks from answer body with validation"""
    blocks = re.findall(
        r'\\begin{tikzpicture}(.*?)\\end{tikzpicture}',
        body,
        re.DOTALL
    )
    return [b.strip() for b in blocks if 'tikz' in b.lower()]


def extract_dependencies(body):
    """Extract packages and libraries from full answer body"""
    # Improved regex patterns to handle package options
    packages = set(re.findall(r'\\usepackage(?:\[[^\]]*\])?{([^}]+)}', body))
    libraries = set()

    # Handle multiple libraries in single declaration
    for lib_group in re.findall(r'\\usetikzlibrary{([^}]+)}', body):
        libraries.update(lib_group.split(','))

    return packages, libraries

def process_questions(output_file, start_page=1):
    """Main processing function with improved rate limiting"""
    with open(output_file, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=CSV_COLUMNS)
        writer.writeheader()

        page = start_page
        has_more = True
        retries = 0
        max_retries = 5

        while has_more and retries < max_retries:
            try:
                PARAMS['page'] = page
                response = requests.get(API_URL, params=PARAMS)

                if response.status_code == 429:
                    # Handle rate limit with Retry-After header
                    retry_after = int(response.headers.get('Retry-After', 60))
                    print(f"Rate limited. Retrying after {retry_after} seconds")
                    time.sleep(retry_after)
                    retries += 1
                    continue

                if response.status_code != 200:
                    print(f"Error: {response.status_code}")
                    break

                data = response.json()
                has_more = data.get('has_more', False)

                # Check remaining quota
                quota_remaining = data.get('quota_remaining', 1)
                if quota_remaining < 10:
                    print(f"Daily quota exhausted. Remaining: {quota_remaining}")
                    break

                # Process questions
                for question in data.get('items', []):
                    process_question(question, writer)
                    time.sleep(1)  # Add delay between questions

                # Handle backoff
                backoff = data.get('backoff', 1)
                print(f"Backing off for {backoff} seconds")
                time.sleep(backoff + 1)

                page += 1
                retries = 0  # Reset retry counter on success
                print(f"Processed page {page}")

            except requests.exceptions.RequestException as e:
                print(f"Request failed: {str(e)}")
                retries += 1
                time.sleep(min(2 ** retries, 60))  # Exponential backoff

def process_question(question, writer):
    """Process individual question with rate limit awareness"""
    try:
        answers_url = f"{API_URL}/{question['question_id']}/answers"
        response = requests.get(answers_url, params={
            "site": "tex",
            "filter": "withbody",
            "key": PARAMS["key"]
        })

        if response.status_code == 429:
            raise requests.exceptions.HTTPError("Rate limit exceeded")

        answers = response.json().get('items', [])
        for answer in answers:
            process_answer(question, answer, writer)
            time.sleep(0.5)  # Add delay between answers

    except Exception as e:
        print(f"Error processing question: {str(e)}")


def process_answer(question, answer, writer):
    """Process answer with enhanced dependency handling"""
    body = answer['body']

    # Extract dependencies from entire answer body
    packages, libraries = extract_dependencies(body)

    # Extract TikZ code blocks
    tikz_blocks = re.findall(r'\\begin{tikzpicture}(.*?)\\end{tikzpicture}', body, re.DOTALL)

    for code in tikz_blocks:
        code = code.strip()
        if not code:
            continue

        file_path = save_latex_file(
            code,
            question.get('question_id', 'unknown'),
            answer.get('answer_id', 'unknown'),
            packages,
            libraries
        )

        if not file_path:
            continue

        writer.writerow({
            'code': code,
            'caption': question.get('title', ''),
            'source_url': answer.get('link', ''),
            'libraries': ', '.join(libraries),
            'packages': ', '.join(packages),
            'question_id': question.get('question_id', ''),
            'answer_id': answer.get('answer_id', ''),
            'latex_file_path': file_path
        })

if __name__ == "__main__":
    output_csv = os.path.join(OUTPUT_DIR, "tex_stackexchange_tikz.csv")
    process_questions(output_csv, start_page=108)
    print(f"Data saved to {output_csv} and LaTeX files in {CODE_DIR}")
# Out:
# Backing off for 1 seconds
# Processed page 109
# Backing off for 1 seconds
# Processed page 110
# Backing off for 1 seconds
# Processed page 111
# Backing off for 1 seconds
# Processed page 112
# Backing off for 1 seconds
# Processed page 113
# Backing off for 1 seconds
# Processed page 114
# Backing off for 1 seconds
# Processed page 115
# Backing off for 1 seconds
# Processed page 116
# Backing off for 1 seconds
# Processed page 117
# Backing off for 1 seconds
# Processed page 118
# Backing off for 1 seconds
# Processed page 119
# Backing off for 1 seconds
# Processed page 120
# Backing off for 1 seconds
# Processed page 121
# Backing off for 1 seconds
# Processed page 122
# Backing off for 1 seconds
# Processed page 123
# Backing off for 1 seconds
# Processed page 124
# Backing off for 1 seconds
# Processed page 125
# Backing off for 1 seconds
# Processed page 126
# Backing off for 1 seconds
# Processed page 127
# Backing off for 1 seconds
# Processed page 128
# Backing off for 1 seconds
# Processed page 129
# Backing off for 1 seconds
# Processed page 130
# Backing off for 1 seconds
# Processed page 131
# Backing off for 1 seconds
# Processed page 132
# Backing off for 1 seconds
# Processed page 133
# Backing off for 1 seconds
# Processed page 134
# Backing off for 1 seconds
# Processed page 135
# Backing off for 1 seconds
# Processed page 136
# Backing off for 1 seconds
# Processed page 137
# Backing off for 1 seconds
# Processed page 138
# Backing off for 1 seconds
# Processed page 139
# Backing off for 1 seconds
# Processed page 140
# Backing off for 1 seconds
# Processed page 141
# Backing off for 1 seconds
# Processed page 142
# Backing off for 1 seconds
# Processed page 143
# Backing off for 1 seconds
# Processed page 144
# Backing off for 1 seconds
# Processed page 145
# Backing off for 1 seconds
# Processed page 146
# Backing off for 1 seconds
# Processed page 147
# Backing off for 1 seconds
# Processed page 148
# Backing off for 1 seconds
# Processed page 149
# Backing off for 1 seconds
# Processed page 150

# %%
# !zip -r stackexchange2.zip '/content/tikz_data'
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/tikz_data/code/tikz_595157_595194_998810.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_572051_572056_837236.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_593437_593874_68474.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_633668_633724_123003.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_621640_621656_953602.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_602869_602874_420770.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_268830_269029_996117.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_449911_450439_110531.tex (deflated 68%)
#   adding: content/tikz_data/code/tikz_654451_654488_258234.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_625993_626000_805869.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_621321_621358_621688.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_617805_617920_3777.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_653075_653093_35842.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_588571_588574_497266.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_606088_606103_441887.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_632731_632809_371732.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_308907_579560_693233.tex (deflated 82%)
#   adding: content/tikz_data/code/tikz_614302_614317_954187.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_510748_510754_483707.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_653424_653427_627305.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_615130_615132_670625.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_577687_577750_512388.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_583947_583994_757903.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_635654_635664_306313.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_452176_452182_195861.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_649162_649163_760574.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_628013_628014_257278.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_198057_198082_874935.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_479395_532992_925579.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_361375_361392_838922.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_577320_577324_956654.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_646539_646545_205716.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_611284_611288_801771.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_42611_42675_379813.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_172273_172356_139840.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_601298_601303_210459.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_651839_651849_930386.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_653567_653583_858044.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_618379_620587_335447.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_654414_654422_141813.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_597512_597514_589062.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_28802_29491_792835.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_587779_587787_659734.tex (deflated 79%)
#   adding: content/tikz_data/code/tikz_601594_601604_573775.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_592928_592968_729458.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_592293_592304_629458.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_623147_623243_71464.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_110820_110821_501048.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_591958_591968_9384.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_648798_649590_950278.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_557891_560855_520524.tex (deflated 67%)
#   adding: content/tikz_data/code/tikz_461573_461587_6949.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_583917_583996_149115.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_646559_646574_554942.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_646249_646263_292484.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_657729_657734_456570.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_625397_625401_892798.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_93925_93927_248044.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_551460_584018_477216.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_623737_623743_735319.tex (deflated 71%)
#   adding: content/tikz_data/code/tikz_604288_610095_328649.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_603532_603584_848865.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_645282_645360_236340.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_431139_572151_126164.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_641223_641228_90720.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_575636_575669_212037.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_595315_595316_375831.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_629779_629823_215803.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_647373_647378_252689.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_617895_617918_45257.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_574887_574896_376235.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_574072_574074_22079.tex (deflated 67%)
#   adding: content/tikz_data/code/tikz_567147_567156_938293.tex (deflated 72%)
#   adding: content/tikz_data/code/tikz_629162_629172_519365.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_624794_624804_117312.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_654117_654120_19082.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_568940_568980_989307.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_479395_479506_892418.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_615013_615016_730637.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_608887_608921_793862.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_613884_613955_345511.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_618361_618363_259762.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_601526_622526_941569.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_656538_656581_817025.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_569374_569379_366145.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_26382_26386_926507.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_646464_646497_522494.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_630357_630362_880565.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_628133_628135_751706.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_557891_560855_277676.tex (deflated 66%)
#   adding: content/tikz_data/code/tikz_213743_619570_185871.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_648929_648940_616553.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_32442_32447_118750.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_601835_601839_280008.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_80215_577723_691973.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_602530_602535_163341.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_600352_600354_37508.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_574191_574345_345621.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_600883_600932_227043.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_595157_595160_525203.tex (deflated 77%)
#   adding: content/tikz_data/code/tikz_649191_654630_669728.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_569920_569935_771244.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_617420_617422_370977.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_625792_625798_747654.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_540879_540883_94535.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_568557_568571_200491.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_574142_574159_637630.tex (deflated 68%)
#   adding: content/tikz_data/code/tikz_588111_588117_678797.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_594391_631258_600341.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_654080_654090_668553.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_588434_588435_247651.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_610490_618045_322977.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_651949_651962_980801.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_586391_586392_782912.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_584773_584783_161376.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_67573_67588_545124.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_601427_601440_502469.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_581509_581685_909375.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_640440_640471_64282.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_621539_621541_722059.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_575721_575722_745298.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_634604_634628_150001.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_617538_617540_994305.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_569100_569110_606949.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_49096_49108_652013.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_651951_651994_696173.tex (deflated 67%)
#   adding: content/tikz_data/code/tikz_648188_648191_221277.tex (deflated 79%)
#   adding: content/tikz_data/code/tikz_623529_623532_587620.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_593467_593523_130633.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_419991_656319_904001.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_576318_576327_212765.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_651910_651919_795498.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_578910_578916_146796.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_641202_641207_658741.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_609363_609377_928712.tex (deflated 67%)
#   adding: content/tikz_data/code/tikz_296341_606535_581534.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_616929_617051_821313.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_629779_629823_6423.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_619925_619929_340688.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_583218_583222_247804.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_634798_634800_570514.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_582506_582512_381753.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_26846_26852_902697.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_639502_639518_218832.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_620876_620887_469069.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_583913_587991_152399.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_616942_616995_392454.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_566291_566296_356048.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_504568_648681_133461.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_602538_602797_666532.tex (deflated 68%)
#   adding: content/tikz_data/code/tikz_98924_213390_198184.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_571575_571633_676211.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_134904_134909_204638.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_602166_602501_996469.tex (deflated 76%)
#   adding: content/tikz_data/code/tikz_613928_613931_7378.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_594755_594789_545426.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_649844_649870_84133.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_643297_643304_745241.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_601769_601774_326072.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_591451_591475_321391.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_568557_568576_371331.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_648929_648940_286032.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_302518_302524_573213.tex (deflated 71%)
#   adding: content/tikz_data/code/tikz_568629_569348_945841.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_615503_615964_116208.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_588741_588753_604685.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_606813_609499_17819.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_657442_657462_813504.tex (deflated 73%)
#   adding: content/tikz_data/code/tikz_631302_631307_489135.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_657113_657117_783592.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_624490_624499_256947.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_632207_632220_386536.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_651918_651926_359023.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_573725_573763_247974.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_587371_587375_477986.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_611831_612688_249178.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_61237_653376_904183.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_646241_646250_36260.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_637222_637237_51397.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_573397_573399_108566.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_531994_624814_883935.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_648079_648110_268447.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_616425_616429_96720.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_602214_602224_220555.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_640696_640727_589429.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_625156_625158_944860.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_622285_622287_832819.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_657141_657145_398618.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_605410_605416_947038.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_635110_635116_826670.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_426269_426272_442264.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_584488_584491_66973.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_345368_621677_243090.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_617799_617801_280774.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_593285_593550_422295.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_339301_339384_3812.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_579786_579796_60721.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_592375_592378_617269.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_648670_648672_555501.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_648269_648276_342139.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_573451_573454_351845.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_61237_61244_39301.tex (deflated 64%)
#   adding: content/tikz_data/code/tikz_594801_595614_904448.tex (deflated 73%)
#   adding: content/tikz_data/code/tikz_591092_591118_857974.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_617538_617540_421268.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_629303_629418_927707.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_622050_622081_84952.tex (deflated 86%)
#   adding: content/tikz_data/code/tikz_619084_619088_672081.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_568303_568321_219293.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_647074_647092_322085.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_247627_247629_330838.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_616311_616315_205938.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_582700_582731_644133.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_123671_124114_976088.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_595561_596144_154670.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_630334_630335_610422.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_580976_581050_938749.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_12010_12031_957685.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_184792_639264_162758.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_568897_569305_80492.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_593021_593034_152897.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_645649_645657_123546.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_568948_569229_710726.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_582832_583017_688308.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_402100_402139_138821.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_595325_595368_687823.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_571440_571446_793555.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_128232_130119_822988.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_656538_656606_686524.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_566760_566857_946289.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_642098_642232_568829.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_591207_591210_845089.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_642543_642545_763632.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_604109_604125_561309.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_656416_656422_441169.tex (deflated 69%)
#   adding: content/tikz_data/code/tikz_656033_656167_218437.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_652371_652376_607570.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_630443_638760_295992.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_593437_593447_286245.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_578984_579034_413199.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_565626_574635_10684.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_644857_644915_573059.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_578187_610100_781201.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_596088_596108_678445.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_621693_621701_239318.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_621955_621961_645466.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_656968_656984_949073.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_617020_617031_117629.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_632842_632845_977809.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_583947_584019_119790.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_591015_591018_267730.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_609811_609846_511882.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_588988_588994_344653.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_612184_612284_667667.tex (deflated 66%)
#   adding: content/tikz_data/code/tikz_595829_595833_532745.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_581522_581527_28689.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_39474_167392_397313.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_1111_633104_621022.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_593315_593319_627393.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_633872_640884_430319.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_655501_655505_588053.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_539003_539006_722869.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_545034_636938_860207.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_623177_623182_599894.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_637816_637826_7513.tex (deflated 66%)
#   adding: content/tikz_data/code/tikz_582832_582856_996357.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_640094_640098_354947.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_600976_600995_134410.tex (deflated 66%)
#   adding: content/tikz_data/code/tikz_576855_576862_702716.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_597587_597591_450246.tex (deflated 64%)
#   adding: content/tikz_data/code/tikz_647623_647627_635862.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_604508_604535_531318.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_89649_102569_510659.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_587372_587378_368778.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_599983_600107_205668.tex (deflated 75%)
#   adding: content/tikz_data/code/tikz_655648_655659_823867.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_566742_566747_451239.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_593641_593650_808900.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_419991_420013_43972.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_642111_642214_745611.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_590691_590702_597716.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_477206_477208_186765.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_635640_635647_235156.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_233246_233250_511611.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_624363_624408_456103.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_570111_570377_341268.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_584207_584252_429337.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_567913_568297_1100.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_644544_644547_845110.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_648923_648932_337670.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_644874_645452_732611.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_614199_614570_924920.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_566399_566400_819435.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_69439_80322_235157.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_610630_610632_469559.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_593406_593595_258038.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_6388_53011_268455.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_6388_32627_715402.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_645601_645634_949011.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_581346_581349_562643.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_615740_615806_520327.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_637655_637719_960357.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_26846_26852_858887.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_634029_634054_484688.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_653780_653817_5881.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_594754_594778_956167.tex (deflated 78%)
#   adding: content/tikz_data/code/tikz_625776_625778_553153.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_361375_654433_898304.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_635278_635456_687539.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_634241_634349_620622.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_642261_642625_486209.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_39037_39039_550278.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_411430_411437_727954.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_588035_588096_831296.tex (deflated 69%)
#   adding: content/tikz_data/code/tikz_629598_629612_78420.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_619180_619186_951422.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_630371_630374_670909.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_629162_629180_375447.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_588473_588491_39705.tex (deflated 69%)
#   adding: content/tikz_data/code/tikz_570552_570558_337805.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_638411_638413_991982.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_612247_612256_655571.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_567552_567561_945144.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_627883_627951_226590.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_588571_588624_477178.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_492419_492432_147093.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_635166_635167_577098.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_618213_618220_792912.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_254844_305834_470513.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_616237_616278_594835.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_616810_616815_115820.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_644211_644329_219538.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_593234_593256_151734.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_614043_614225_699178.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_619262_619264_487275.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_630436_630450_164994.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_602551_602599_585945.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_628778_628779_141642.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_44897_618258_508023.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_633699_633712_505834.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_638645_638666_567137.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_580978_580983_149984.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_639115_639136_670740.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_637161_637166_608560.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_599844_599870_877871.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_448920_448925_85466.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_612620_612630_132628.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_653781_653783_967691.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_611127_611198_193541.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_569577_569657_652181.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_582309_582380_252992.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_622695_622696_813029.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_642711_642726_270712.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_616560_616568_510574.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_593552_593553_730463.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_348933_349140_200395.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_636129_636131_826914.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_598613_657328_995964.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_606843_606862_707897.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_631402_631405_901859.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_162687_586576_593146.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_428394_428399_564125.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_575353_575370_645526.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_650021_650026_618546.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_623167_623206_251067.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_579242_579270_439432.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_653258_653283_456918.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_654897_654938_604445.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_601430_601445_668089.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_603165_603169_574792.tex (deflated 71%)
#   adding: content/tikz_data/code/tikz_577687_577698_214097.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_631354_631363_746939.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_598418_598433_441655.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_589070_589092_209385.tex (deflated 82%)
#   adding: content/tikz_data/code/tikz_610118_610201_187604.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_611982_611984_431677.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_588300_588303_877315.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_588815_588828_600144.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_568662_620370_394710.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_597549_597578_537327.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_519265_521142_665508.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_624409_624413_49450.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_651401_651402_611004.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_593771_593776_127613.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_636650_636898_468254.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_631346_631349_418871.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_51228_51233_265624.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_631851_631868_212370.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_548586_548757_689098.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_567552_567561_510380.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_464572_464575_870455.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_649049_649050_57545.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_571173_571175_840896.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_634960_635059_939182.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_622050_622059_522319.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_419991_656319_290061.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_582700_582702_987345.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_593773_593781_32374.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_571680_572225_734771.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_629960_630040_999600.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_600935_600975_269420.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_583864_583880_599319.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_624482_624496_50744.tex (deflated 85%)
#   adding: content/tikz_data/code/tikz_648929_648940_621113.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_618780_618867_708355.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_213075_213080_263356.tex (deflated 74%)
#   adding: content/tikz_data/code/tikz_388016_624007_862066.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_609481_609484_790121.tex (deflated 37%)
#   adding: content/tikz_data/code/tikz_394368_639280_902881.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_543825_644209_846517.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_640695_640728_488661.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_570771_570870_111733.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_631339_631480_903627.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_433859_433870_17672.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_652408_652501_9576.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_579803_579814_943298.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_604783_604814_248173.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_368604_368607_543668.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_599759_599763_767918.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_175016_175027_487297.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_646692_646902_520483.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_67573_67588_71.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_634707_634731_664405.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_624610_624615_92645.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_588571_588574_266253.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_638008_638015_343379.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_587171_587181_698456.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_523119_523120_231619.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_570938_571042_66547.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_338282_629791_701578.tex (deflated 71%)
#   adding: content/tikz_data/code/tikz_619578_619637_580162.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_413692_413694_343205.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_587203_587253_939167.tex (deflated 35%)
#   adding: content/tikz_data/code/tikz_646809_646844_36912.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_646930_646939_709105.tex (deflated 64%)
#   adding: content/tikz_data/code/tikz_634853_634924_662923.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_633690_633800_196461.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_597256_597267_330976.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_569976_570242_814538.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_594536_594547_847109.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_643847_643849_721634.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_594407_594410_81144.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_560506_560520_860479.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_531708_531721_368027.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_620785_620802_18556.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_651252_651370_203349.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_610398_610412_708292.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_609172_609188_910280.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_656447_656483_610296.tex (deflated 78%)
#   adding: content/tikz_data/code/tikz_588980_588985_785570.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_612431_612433_400482.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_648768_648770_775268.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_585277_594716_508089.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_49096_49113_844637.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_581588_581601_837680.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_166481_166483_505485.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_600784_600907_703442.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_594353_595113_694377.tex (deflated 71%)
#   adding: content/tikz_data/code/tikz_599522_599565_760409.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_596658_596660_67315.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_604584_604592_233566.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_107057_637002_524875.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_591207_591210_634399.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_223664_223665_226029.tex (deflated 64%)
#   adding: content/tikz_data/code/tikz_609102_609221_310518.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_650557_650796_337312.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_269108_581948_480707.tex (deflated 67%)
#   adding: content/tikz_data/code/tikz_636424_636435_459036.tex (deflated 76%)
#   adding: content/tikz_data/code/tikz_612364_612369_508631.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_615694_615696_857543.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_650602_650651_896193.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_574920_574921_45921.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_642853_642870_320537.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_635327_635344_999771.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_111660_583834_569726.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_637119_637134_468982.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_633872_633948_941261.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_565997_568884_950232.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_629761_629764_913919.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_627753_627759_43763.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_591037_591042_874825.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_434008_435007_38549.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_567958_567972_925888.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_656700_656701_946655.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_59001_59219_19918.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_12010_14515_256526.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_648594_648644_770663.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_30032_30038_943965.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_648965_648987_61490.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_602278_602287_156101.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_634929_634935_843879.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_592152_592158_487602.tex (deflated 67%)
#   adding: content/tikz_data/code/tikz_345368_345372_361390.tex (deflated 81%)
#   adding: content/tikz_data/code/tikz_628727_628732_840468.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_647973_647982_461772.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_547958_547970_821765.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_594222_594311_95131.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_596050_596058_841318.tex (deflated 74%)
#   adding: content/tikz_data/code/tikz_651595_651598_341897.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_591656_591821_612227.tex (deflated 67%)
#   adding: content/tikz_data/code/tikz_330970_331010_920182.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_45902_45904_758838.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_653424_653427_815633.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_641125_643098_412364.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_551160_551205_758211.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_595910_595929_302155.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_599474_599483_817833.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_626087_626093_277488.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_628060_628109_326183.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_570732_570733_754999.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_213743_619568_388840.tex (deflated 69%)
#   adding: content/tikz_data/code/tikz_646702_646711_272514.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_595476_595597_895009.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_595518_595520_299442.tex (deflated 72%)
#   adding: content/tikz_data/code/tikz_605844_605847_361161.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_587152_587160_185639.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_586710_586812_272589.tex (deflated 67%)
#   adding: content/tikz_data/code/tikz_600474_600490_705275.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_38461_38572_501558.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_646845_646855_553539.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_516723_516727_61697.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_623259_623270_156340.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_635654_635664_749561.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_286878_286899_896659.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_611525_611565_7539.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_596088_596112_173673.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_570743_570754_736934.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_630129_630134_690430.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_540425_542024_826953.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_632231_632234_268834.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_646506_646508_347025.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_166958_166966_12559.tex (deflated 68%)
#   adding: content/tikz_data/code/tikz_653822_653893_571012.tex (deflated 74%)
#   adding: content/tikz_data/code/tikz_6388_297928_135561.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_631277_631280_594757.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_595138_595145_993032.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_67573_67588_961958.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_643269_643288_102437.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_581346_581349_423126.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_650021_650027_954445.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_647747_647821_841197.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_606371_606374_113653.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_628589_628605_774615.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_639719_639819_38308.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_621554_621655_718842.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_647110_647121_486395.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_12091_648813_304876.tex (deflated 37%)
#   adding: content/tikz_data/code/tikz_592353_592369_52089.tex (deflated 68%)
#   adding: content/tikz_data/code/tikz_571012_571325_266324.tex (deflated 73%)
#   adding: content/tikz_data/code/tikz_609479_609480_565723.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_433317_433318_136217.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_595881_595898_931616.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_604890_604909_410123.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_614439_614443_654621.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_577450_577455_119957.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_545901_545905_394384.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_575240_575302_687299.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_107902_107912_953987.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_629684_629686_833560.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_645649_645705_121786.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_651199_651203_109669.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_571986_571988_510409.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_577275_577278_266896.tex (deflated 68%)
#   adding: content/tikz_data/code/tikz_575636_575669_68284.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_629730_629737_725367.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_623179_623193_447644.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_577575_577588_622972.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_238329_238335_505379.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_648062_648077_956943.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_594624_594628_786729.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_594075_594098_461780.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_437556_565789_364931.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_656603_656604_912959.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_637119_637136_829942.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_593129_593150_861267.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_588089_588140_325940.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_588020_588021_492441.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_123671_124114_522167.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_649622_649635_18448.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_578524_578526_521234.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_656751_656759_858563.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_635943_635969_117271.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_602872_602900_557290.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_576030_576132_905069.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_645382_645386_433581.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_601461_601510_311420.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_619988_620004_91904.tex (deflated 69%)
#   adding: content/tikz_data/code/tikz_630554_630555_288521.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_83888_540718_721255.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_609638_609679_281011.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_579385_579412_778591.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_597415_597421_783488.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_599922_599947_139458.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_657444_657712_579535.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_156719_159456_819419.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_595518_595521_185742.tex (deflated 75%)
#   adding: content/tikz_data/code/tikz_624391_624394_468939.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_630281_630304_518948.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_185474_629421_921948.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_647078_649894_631952.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_42611_42673_487074.tex (deflated 67%)
#   adding: content/tikz_data/code/tikz_645369_645373_440213.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_657113_657117_727803.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_150644_150675_641680.tex (deflated 87%)
#   adding: content/tikz_data/code/tikz_602047_602058_297697.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_641125_641137_591923.tex (deflated 71%)
#   adding: content/tikz_data/code/tikz_648423_648436_858070.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_655579_655581_847807.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_119914_142491_783659.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_631354_631355_425530.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_604080_604102_167976.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_601570_601573_825894.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_653258_653288_701319.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_631317_631326_529116.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_600132_600137_653000.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_565382_565386_448042.tex (deflated 42%)
# ...
#   adding: content/tikz_data/code/tikz_622951_622954_323479.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_636839_636859_936330.tex (deflated 64%)
#   adding: content/tikz_data/code/tikz_47392_47431_957733.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_569799_569853_777566.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_627916_627943_661680.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_611678_611684_531728.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_624467_624483_795486.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_577061_577083_727424.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_388948_623180_834992.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_628066_628071_72344.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_577313_577322_22377.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_638411_638423_334156.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_570233_570270_410329.tex (deflated 37%)
#   adding: content/tikz_data/code/tikz_58878_58880_98581.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_631002_631003_266304.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_569033_569062_853535.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_530762_530769_774833.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_653999_654182_118875.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_5461_167031_944904.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_561233_561294_381919.tex (deflated 74%)
#   adding: content/tikz_data/code/tikz_485482_486146_235435.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_622131_622157_638052.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_656950_656983_584127.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_67573_67588_199952.tex (deflated 62%)
#   adding: content/tikz_data/code/tikz_593234_593887_670303.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_502638_502641_212970.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_598106_598118_374323.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_651115_651120_64097.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_644367_644377_423898.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_654230_654232_973399.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_610382_610394_35744.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_652371_652376_908536.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_651061_651064_506503.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_582614_582664_562441.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_571575_571579_302942.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_648678_648680_410440.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_651691_651700_63694.tex (deflated 69%)
#   adding: content/tikz_data/code/tikz_593685_593688_906676.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_590471_590478_747202.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_580271_580284_890739.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_614845_614846_877246.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_606819_606872_217096.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_582150_582151_74179.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_610887_610905_697499.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_587409_587448_708474.tex (deflated 36%)
#   adding: content/tikz_data/code/tikz_630453_630465_674840.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_645730_645735_919467.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_581540_581548_193113.tex (deflated 72%)
#   adding: content/tikz_data/code/tikz_578010_578027_285705.tex (deflated 78%)
#   adding: content/tikz_data/code/tikz_641053_641054_686884.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_595874_595901_507314.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_29359_29367_958966.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_652630_652633_701399.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_48092_48111_896828.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_643437_643446_813403.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_619620_619796_924549.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_601769_601774_156476.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_593955_593959_438348.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_650720_650774_325230.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_569751_569761_6759.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_602629_602635_928840.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_635714_635724_372893.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_577717_577720_231572.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_593552_593648_199927.tex (deflated 84%)
#   adding: content/tikz_data/code/tikz_628311_628324_565125.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_575727_575734_82160.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_610278_610312_585704.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_629303_629418_518312.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_599416_599423_565140.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_584364_584367_101049.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_640857_640871_78979.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_579713_579716_206181.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_616102_616109_434436.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_623266_623269_741653.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_654461_654468_14092.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_600352_601066_630074.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_586035_586061_279013.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_641706_641713_260988.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_580026_580040_956895.tex (deflated 51%)
#   adding: content/tikz_data/code/tikz_595311_595313_566751.tex (deflated 75%)
#   adding: content/tikz_data/code/tikz_640183_640223_131321.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_599374_599377_138473.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_640857_640874_859549.tex (deflated 76%)
#   adding: content/tikz_data/code/tikz_568735_568748_451981.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_651593_651597_930053.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_625492_625498_71637.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_620346_620347_151038.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_623371_623374_48944.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_604767_604772_77978.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_630371_630374_853483.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_415462_415468_885548.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_627425_627432_924474.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_648594_648644_418424.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_619698_619767_124554.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_652619_652622_174446.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_654798_654805_270911.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_582923_582925_125411.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_591420_591445_166756.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_543781_543784_384387.tex (deflated 64%)
#   adding: content/tikz_data/code/tikz_652890_652905_556459.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_545317_545506_343391.tex (deflated 66%)
#   adding: content/tikz_data/code/tikz_40516_40795_982610.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_657358_657374_440293.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_593427_593431_225353.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_571169_571833_93336.tex (deflated 66%)
#   adding: content/tikz_data/code/tikz_570282_570285_629208.tex (deflated 69%)
#   adding: content/tikz_data/code/tikz_584292_584353_232123.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_55760_56161_840027.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_568940_569016_263811.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_597830_597839_863046.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_625321_625323_365268.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_658953_658964_92721.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_207953_208039_776100.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_47995_48059_154580.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_569113_569416_160751.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_575474_575476_683997.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_16870_16872_853700.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_583458_583492_996367.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_594231_594267_155877.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_609809_609857_839405.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_47392_572818_181974.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_592842_592850_621480.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_574736_574755_57879.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_9687_9696_127995.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_582607_582619_621552.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_594193_594197_464412.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_599017_599039_807596.tex (deflated 64%)
#   adding: content/tikz_data/code/tikz_644524_644529_389647.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_86309_86457_79609.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_111660_111736_876360.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_591094_591102_580449.tex (deflated 73%)
#   adding: content/tikz_data/code/tikz_653798_653842_410340.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_542375_542464_210621.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_73977_73978_799525.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_633668_633724_747281.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_484027_484029_83037.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_582869_582930_252767.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_654080_654090_746650.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_628560_628602_254675.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_269916_269922_349379.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_401847_401905_233996.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_580940_581048_752426.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_656224_656246_960844.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_634558_634562_503544.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_497105_583847_347027.tex (deflated 77%)
#   adding: content/tikz_data/code/tikz_618290_618299_885277.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_593129_593180_354577.tex (deflated 45%)
#   adding: content/tikz_data/code/tikz_497877_497901_632808.tex (deflated 70%)
#   adding: content/tikz_data/code/tikz_623529_623577_67729.tex (deflated 43%)
#   adding: content/tikz_data/code/tikz_625974_625976_667847.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_635085_635095_445720.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_621216_621262_265086.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_604921_605009_309262.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_494758_494760_676943.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_598747_598783_191695.tex (deflated 54%)
#   adding: content/tikz_data/code/tikz_538970_538981_193215.tex (deflated 65%)
#   adding: content/tikz_data/code/tikz_648005_648009_170316.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_602175_602179_617115.tex (deflated 72%)
#   adding: content/tikz_data/code/tikz_627904_627915_324170.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_549836_583292_66200.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_600961_600968_438492.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_598506_598516_83902.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_248723_318524_1144.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_587221_587222_995510.tex (deflated 39%)
#   adding: content/tikz_data/code/tikz_578524_578526_61571.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_593603_594113_811057.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_413963_427596_22794.tex (deflated 38%)
#   adding: content/tikz_data/code/tikz_567543_567563_524538.tex (deflated 57%)
#   adding: content/tikz_data/code/tikz_581140_581674_736073.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_633170_633249_630264.tex (deflated 63%)
#   adding: content/tikz_data/code/tikz_623379_623394_838875.tex (deflated 66%)
#   adding: content/tikz_data/code/tikz_590950_590951_227390.tex (deflated 58%)
#   adding: content/tikz_data/code/tikz_115923_115956_911385.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_583082_583090_669941.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_597135_597233_809540.tex (deflated 60%)
#   adding: content/tikz_data/code/tikz_616810_616816_919449.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_575954_575956_574172.tex (deflated 44%)
#   adding: content/tikz_data/code/tikz_652865_652876_721903.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_591441_591447_107780.tex (deflated 50%)
#   adding: content/tikz_data/code/tikz_197253_197258_57133.tex (deflated 53%)
#   adding: content/tikz_data/code/tikz_648166_648175_329605.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_587372_587378_904945.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_582112_582126_372164.tex (deflated 49%)
#   adding: content/tikz_data/code/tikz_637816_637823_846162.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_616497_616549_654562.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_632351_632355_986597.tex (deflated 61%)
#   adding: content/tikz_data/code/tikz_641125_642767_696451.tex (deflated 66%)
#   adding: content/tikz_data/code/tikz_619274_654661_930076.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_639519_639555_457225.tex (deflated 41%)
#   adding: content/tikz_data/code/tikz_568866_568867_221301.tex (deflated 52%)
#   adding: content/tikz_data/code/tikz_602602_602605_733865.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_639449_639482_393153.tex (deflated 46%)
#   adding: content/tikz_data/code/tikz_571038_571039_101723.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_624043_624118_917295.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_625270_625271_287540.tex (deflated 68%)
#   adding: content/tikz_data/code/tikz_645098_645158_316612.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_594658_594666_654471.tex (deflated 68%)
#   adding: content/tikz_data/code/tikz_645633_645639_831577.tex (deflated 48%)
#   adding: content/tikz_data/code/tikz_635834_635839_488805.tex (deflated 56%)
#   adding: content/tikz_data/code/tikz_654533_654547_395064.tex (deflated 55%)
#   adding: content/tikz_data/code/tikz_572732_572734_668014.tex (deflated 40%)
#   adding: content/tikz_data/code/tikz_587510_590791_638819.tex (deflated 59%)
#   adding: content/tikz_data/code/tikz_653620_653625_985930.tex (deflated 47%)
#   adding: content/tikz_data/code/tikz_588163_588165_629645.tex (deflated 42%)
#   adding: content/tikz_data/code/tikz_633348_633555_287306.tex (deflated 65%)

# %%
from google.colab import files

# Download the zip file
files.download('stackexchange2.zip')
