# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (11.1.0)
# Collecting pygithub (from -r requirements.txt (line 4))
#   Downloading PyGithub-2.6.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->-r requirements.txt (line 1)) (2025.1.31)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Collecting pynacl>=1.4.0 (from pygithub->-r requirements.txt (line 4))
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: pyjwt>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub->-r requirements.txt (line 4)) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from pygithub->-r requirements.txt (line 4)) (4.13.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from pygithub->-r requirements.txt (line 4)) (1.2.18)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.11/dist-packages (from pyjwt[crypto]>=2.4.0->pygithub->-r requirements.txt (line 4)) (43.0.3)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pynacl>=1.4.0->pygithub->-r requirements.txt (line 4)) (1.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->pygithub->-r requirements.txt (line 4)) (1.17.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->-r requirements.txt (line 4)) (2.22)
# Downloading PyGithub-2.6.1-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 9.8 MB/s eta 0:00:00
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 33.4 MB/s eta 0:00:00
# Installing collected packages: pynacl, pygithub
# Successfully installed pygithub-2.6.1 pynacl-1.5.0

# %%
import os
os.environ["GITHUB_TOKEN"] = "github_token"

# %%
#!/usr/bin/env python3
"""
GitHub TikZ Code Crawler WITH RANDOMNESS

This script systematically crawls GitHub repositories to extract TikZ code,
corresponding images, and captions. It uses the GitHub API to search for
repositories containing TikZ code and then processes the results.
"""

import os
import re
import base64
import time
import requests
import json
from urllib.parse import urlparse
from github import Github
from github.GithubException import RateLimitExceededException, UnknownObjectException
import pandas as pd
from PIL import Image
from io import BytesIO
import logging
import random
import pandas as pd

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("tikz_crawler.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

class GitHubTikZCrawler:
    def __init__(self, github_token, output_dir="tikz_data"):
        """
        Initialize the GitHub TikZ crawler.

        Args:
            github_token (str): GitHub API token for authentication
            output_dir (str): Directory to save extracted data
        """
        self.github_token = github_token
        self.output_dir = output_dir
        self.g = Github(github_token)
        self.tikz_data = []

        # Create output directories
        os.makedirs(output_dir, exist_ok=True)
        os.makedirs(os.path.join(output_dir, "code"), exist_ok=True)

    def search_repositories(self, max_repos=1):
        """
        Search for repositories containing TikZ code with added randomness.

        Args:
            max_repos (int): Maximum number of repositories to process

        Returns:
            list: List of repository objects
        """
        logger.info(f"Searching for repositories with randomness")
        repositories = []
        try:
            # Introduce randomness by using different keywords or sort orders
            random_keywords = [
                                "TikZ graphics",
                                "TikZ flowchart",
                                "TikZ scientific figure",
                                "LaTeX diagrams",
                                "pgfplots examples",
                                "TikZ neural network",
                                "TikZ machine learning",
                                "TikZ graph theory",
                                "TikZ tree diagram",
                                "TikZ data visualization",
                                "TikZ publication-ready figures",
                                "\\begin{tikzpicture}",
                                "\\usetikzlibrary"
                            ]
            additional_parameters = [
                            "extension:.tex",  # Focus on LaTeX files
                            "extension:.tikz",  # TikZ-specific files
                            "topic:latex",  # Repositories tagged with LaTeX-related topics
                            "topic:visualization",  # Visualization-related repositories
                            "size:<50000",  # Avoid overly large repositories
                        ]
            random_sort = random.choice(["stars", "forks", "updated"])
            randomized_query = f"{random.choice(random_keywords)} language:tex stars:>={random.randint(1, 100)} sort:{random_sort}"
            full_query = f"{randomized_query} {' '.join(additional_parameters)}"

            results = self.g.search_repositories(query=full_query, sort=random_sort)
            count = 0

            for repo in results:
                repositories.append(repo)
                count += 1
                if count >= max_repos:
                    break

                # Check if approaching rate limit
                if self.g.get_rate_limit().search.remaining < 10:
                    reset_time = self.g.get_rate_limit().search.reset
                    sleep_time = reset_time.timestamp() - time.time() + 10
                    logger.info(f"Approaching rate limit, sleeping for {sleep_time} seconds")
                    time.sleep(max(1, sleep_time))

            logger.info(f"Found {len(repositories)} repositories")
            return repositories

        except RateLimitExceededException:
            logger.warning("Rate limit exceeded, waiting for reset")
            reset_time = self.g.get_rate_limit().search.reset
            sleep_time = reset_time.timestamp() - time.time() + 10
            time.sleep(max(1, sleep_time))
            return repositories

    def find_tikz_files(self, repo, max_files=50):
        """
        Find files containing TikZ code in a repository.

        Args:
            repo: GitHub repository object
            max_files (int): Maximum number of files to process

        Returns:
            list: List of content file objects
        """
        logger.info(f"Searching for TikZ files in {repo.full_name}")
        tikz_files = []
        try:
            # Get repository contents
            contents = repo.get_contents("")
            count = 0

            while contents and count < max_files:
                file_content = contents.pop(0)

                if file_content.type == "dir":
                    # Add directory contents to the stack
                    try:
                        contents.extend(repo.get_contents(file_content.path))
                    except Exception as e:
                        logger.warning(f"Could not access directory {file_content.path}: {str(e)}")
                elif file_content.name.endswith('.tex'):
                    # Check if file contains TikZ code
                    try:
                        file_data = base64.b64decode(file_content.content).decode('utf-8', errors='ignore')
                        if '\\begin{tikzpicture}' in file_data or '\\usetikzlibrary' in file_data:
                            tikz_files.append(file_content)
                            count += 1
                    except Exception as e:
                        logger.warning(f"Could not decode file {file_content.path}: {str(e)}")

                # Check if approaching rate limit
                if self.g.get_rate_limit().core.remaining < 10:
                    reset_time = self.g.get_rate_limit().core.reset
                    sleep_time = reset_time.timestamp() - time.time() + 10
                    logger.info(f"Approaching rate limit, sleeping for {sleep_time} seconds")
                    time.sleep(max(1, sleep_time))

            logger.info(f"Found {len(tikz_files)} TikZ files in {repo.full_name}")
            return tikz_files

        except Exception as e:
            logger.error(f"Error processing repository {repo.full_name}: {str(e)}")
            return []

    def extract_tikz_code(self, file_content):
        """
        Extract TikZ code blocks from a file.

        Args:
            file_content: GitHub file content object

        Returns:
            list: List of dictionaries containing TikZ code blocks and metadata
        """
        try:
            file_data = base64.b64decode(file_content.content).decode('utf-8', errors='ignore')
            repo = file_content.repository

            # Extract TikZ picture environments
            tikz_blocks = re.findall(r'\\begin{tikzpicture}(.*?)\\end{tikzpicture}', file_data, re.DOTALL)

            results = []
            for i, block in enumerate(tikz_blocks):
                # Try to find a caption near the TikZ code
                caption_search = re.search(r'\\caption{(.*?)}', file_data, re.DOTALL)
                caption = caption_search.group(1) if caption_search else ""

                # Clean up the caption (remove LaTeX commands)
                caption = re.sub(r'\\[a-zA-Z]+(\[[^\]]*\])?(\{[^}]*\})?', '', caption).strip()

                # Create complete TikZ code block
                complete_code = f"\\begin{{tikzpicture}}{block}\\end{{tikzpicture}}"

                # Look for TikZ libraries
                libraries = re.findall(r'\\usetikzlibrary{(.*?)}', file_data)

                # Extract used packages
                used_packages = re.findall(r'\\usepackage{(.*?)}', file_data)

                results.append({
                    'code': complete_code,
                    'caption': caption,
                    'libraries': libraries,
                    'repo_name': repo.full_name,
                    'file_path': file_content.path,
                    'file_url': file_content.html_url,
                    'raw_url': file_content.download_url,
                    'used_packages': used_packages,
                })

            return results

        except Exception as e:
            logger.error(f"Error extracting TikZ code from {file_content.path}: {str(e)}")
            return []

    def save_tikz_code(self, tikz_data):
        """
        Save TikZ code to a file.

        Args:
            tikz_data (dict): TikZ code data
        """
        try:
            # Generate a filename
            repo_name_safe = tikz_data['repo_name'].replace('/', '_')
            file_path_safe = os.path.basename(tikz_data['file_path']).replace('/', '_')
            code_filename = f"{repo_name_safe}_{file_path_safe}.tex"

            # Create a complete LaTeX document for compilation
            libraries = ','.join(tikz_data.get('libraries', []))
            used_packages = tikz_data.get('used_packages', [])

            document = '\\documentclass[crop, tikz]{standalone}\n'
            document += '\\usepackage{tikz}\n'

            if libraries:
                document += f'\\usetikzlibrary{{{libraries}}}\n'
            for package in used_packages:
                document += f'\\usepackage{{{package}}}\n'

            document += '\\begin{document}\n'
            document += tikz_data['code'] + '\n'
            document += '\\end{document}'

            # Save the complete document
            complete_code_path = os.path.join(self.output_dir, "code", f"complete_{code_filename}")
            with open(complete_code_path, 'w', encoding='utf-8') as f:
                f.write(document)

            # Update TikZ data
            tikz_data['local_complete_code_path'] = complete_code_path

            logger.info(f"Successfully saved TikZ code to {complete_code_path}")
            return True

        except Exception as e:
            logger.error(f"Error saving TikZ code: {str(e)}")
            return False

    def crawl(self, max_repos=3, max_files_per_repo=100):
        """
        Crawl GitHub repositories for TikZ code.

        Args:
            max_repos (int): Maximum number of repositories to process
            max_files_per_repo (int): Maximum number of files to process per repository
        """
        logger.info("Starting TikZ crawler")

        # Load previously processed repository names (if available)
        processed_repos_path = os.path.join(self.output_dir, "processed_repos.txt")
        if os.path.exists(processed_repos_path):
            with open(processed_repos_path, 'r') as f:
                processed_repos = set(f.read().splitlines())
        else:
            processed_repos = set()

        # Search for new repositories with randomness introduced above.
        repositories = self.search_repositories(max_repos=max_repos)

        for repo in repositories:
            if repo.full_name in processed_repos:
                logger.info(f"Skipping already processed repository: {repo.full_name}")
                continue

            try:
                # Find TikZ files in the repository.
                tikz_files = self.find_tikz_files(repo, max_files=max_files_per_repo)

                for file_content in tikz_files:
                    # Extract TikZ code blocks from each file.
                    tikz_blocks = self.extract_tikz_code(file_content)

                    for tikz_block in tikz_blocks:
                        # Save TikZ code block.
                        self.save_tikz_code(tikz_block)
                        self.tikz_data.append(tikz_block)

                # Mark repository as processed.
                with open(processed_repos_path, 'a') as f:
                    f.write(repo.full_name + '\n')

            except Exception as e:
                logger.error(f"Error processing repository {repo.full_name}: {str(e)}")

        # Save the dataset after crawling is complete.
        self.save_dataset()

        logger.info(f"Crawling complete. Extracted {len(self.tikz_data)} TikZ code blocks.")

    def save_dataset(self):
      """
      Save the dataset to a CSV file and a JSON file, appending new data if the file exists
      and ensuring no duplicates are added.
      """
      try:
          # Convert the current TikZ data to a DataFrame
          df_new = pd.DataFrame(self.tikz_data)

          # Paths for CSV and JSON files
          csv_path = os.path.join(self.output_dir, "tikz_dataset.csv")
          json_path = os.path.join(self.output_dir, "tikz_dataset.json")

          # Handle CSV file
          if os.path.exists(csv_path):
              # Load existing data
              df_existing = pd.read_csv(csv_path)

              # Combine new and existing data, removing duplicates
              df_combined = pd.concat([df_existing, df_new]).drop_duplicates(subset=['repo_name', 'file_path', 'code'])

              # Save back to CSV
              df_combined.to_csv(csv_path, index=False)
          else:
              # Save new data directly if file doesn't exist
              df_new.to_csv(csv_path, index=False)

          # Handle JSON file
          if os.path.exists(json_path):
              with open(json_path, 'r', encoding='utf-8') as f:
                  existing_data = json.load(f)

              # Combine new and existing data, removing duplicates based on unique keys
              combined_data = list({tuple(sorted(d.items())): d for d in existing_data + self.tikz_data}.values())

              with open(json_path, 'w', encoding='utf-8') as f:
                  json.dump(combined_data, f, indent=2)
          else:
              # Save new data directly if file doesn't exist
              with open(json_path, 'w', encoding='utf-8') as f:
                  json.dump(self.tikz_data, f, indent=2)

          logger.info(f"Dataset saved to {csv_path} and {json_path}")

      except Exception as e:
          logger.error(f"Error saving dataset: {str(e)}")

def main():
    """
    Main function to run the crawler.
    """
    github_token = os.environ.get("GITHUB_TOKEN")
    if not github_token:
        logger.error("GitHub token not found. Please set the GITHUB_TOKEN environment variable.")
        return

    crawler = GitHubTikZCrawler(github_token)
    for i in range(10):
      print(i)
      crawler.crawl(max_repos=3, max_files_per_repo=100)

if __name__ == "__main__":
    main()
# Out:
# 0
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768
# 1
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768
# 2
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768
# 3
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768
# 4
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768
# 5
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768
# 6
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768
# 7
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768
# 8
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768
# 9
# ERROR:__main__:Error saving dataset: unhashable type: 'list'
# 6698
# 1768

# %%
from google.colab import files
files.download("tikz_data/tikz_dataset.json")

# %%
# !zip -r code.zip "tikz_data"
# Out:
#   adding: tikz_data/ (stored 0%)
#   adding: tikz_data/pdfs/ (stored 0%)
#   adding: tikz_data/pdfs/Exam_images_mock-img04.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Exam_images_mock-img04.tex/Exam_images_mock-img04.tex.tex (deflated 68%)
#   adding: tikz_data/pdfs/Exam_images_mock-img04.tex/Exam_images_mock-img04.tex_page_1.png (deflated 17%)
#   adding: tikz_data/pdfs/Exam_images_mock-img04.tex/Exam_images_mock-img04.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/advanced-math_exercise_7-integral-calculus-of-multivariate-functions_integral-calculus-of-multivariate-functions.tex/ (stored 0%)
#   adding: tikz_data/pdfs/advanced-math_exercise_7-integral-calculus-of-multivariate-functions_integral-calculus-of-multivariate-functions.tex/advanced-math_exercise_7-integral-calculus-of-multivariate-functions_integral-calculus-of-multivariate-functions.tex_page_1.png (deflated 7%)
#   adding: tikz_data/pdfs/advanced-math_exercise_7-integral-calculus-of-multivariate-functions_integral-calculus-of-multivariate-functions.tex/advanced-math_exercise_7-integral-calculus-of-multivariate-functions_integral-calculus-of-multivariate-functions.tex.tex (deflated 50%)
#   adding: tikz_data/pdfs/advanced-math_exercise_7-integral-calculus-of-multivariate-functions_integral-calculus-of-multivariate-functions.tex/advanced-math_exercise_7-integral-calculus-of-multivariate-functions_integral-calculus-of-multivariate-functions.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/Kampf_Ausweichen_ausweichen.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Kampf_Ausweichen_ausweichen.tex/Kampf_Ausweichen_ausweichen.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/test_testbeamer1.tex/ (stored 0%)
#   adding: tikz_data/pdfs/test_testbeamer1.tex/test_testbeamer1.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/8.tex/ (stored 0%)
#   adding: tikz_data/pdfs/8.tex/8.tex.tex (deflated 41%)
#   adding: tikz_data/pdfs/paper_chapters_4-implementation.tex/ (stored 0%)
#   adding: tikz_data/pdfs/paper_chapters_4-implementation.tex/paper_chapters_4-implementation.tex.tex (deflated 62%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_ComplexFunctions_ComplexFunctions.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_ComplexFunctions_ComplexFunctions.tex/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_ComplexFunctions_ComplexFunctions.tex.tex (deflated 48%)
#   adding: tikz_data/pdfs/Examples_bat.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Examples_bat.tex/Examples_bat.tex.tex (deflated 37%)
#   adding: tikz_data/pdfs/Examples_bat.tex/Examples_bat.tex_page_1.png (deflated 3%)
#   adding: tikz_data/pdfs/Examples_bat.tex/Examples_bat.tex.pdf (deflated 9%)
#   adding: tikz_data/pdfs/ciphers_Pockenacci_LaTeX_stills_key_schedule_key_schedule.tex/ (stored 0%)
#   adding: tikz_data/pdfs/ciphers_Pockenacci_LaTeX_stills_key_schedule_key_schedule.tex/ciphers_Pockenacci_LaTeX_stills_key_schedule_key_schedule.tex.tex (deflated 80%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_aFirstCourseLinearAlgebra_exercises_LinearTransformations-Special.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_aFirstCourseLinearAlgebra_exercises_LinearTransformations-Special.tex/Intro-Math-Programming_baseText_aFirstCourseLinearAlgebra_exercises_LinearTransformations-Special.tex.tex (deflated 36%)
#   adding: tikz_data/pdfs/source_lecture4_source.tex/ (stored 0%)
#   adding: tikz_data/pdfs/source_lecture4_source.tex/source_lecture4_source.tex.tex (deflated 57%)
#   adding: tikz_data/pdfs/PricesVsQuantitites_Ps-vs-Qs-MAC-steep.tex/ (stored 0%)
#   adding: tikz_data/pdfs/PricesVsQuantitites_Ps-vs-Qs-MAC-steep.tex/PricesVsQuantitites_Ps-vs-Qs-MAC-steep.tex.tex (deflated 59%)
#   adding: tikz_data/pdfs/qt_05measure.tex/ (stored 0%)
#   adding: tikz_data/pdfs/qt_05measure.tex/qt_05measure.tex.tex (deflated 46%)
#   adding: tikz_data/pdfs/images_cone.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_cone.tex/images_cone.tex_page_1.png (deflated 5%)
#   adding: tikz_data/pdfs/images_cone.tex/images_cone.tex.tex (deflated 41%)
#   adding: tikz_data/pdfs/images_cone.tex/images_cone.tex.pdf (deflated 1%)
#   adding: tikz_data/pdfs/ArtificialIntelligence_genetic_crossover.tex/ (stored 0%)
#   adding: tikz_data/pdfs/ArtificialIntelligence_genetic_crossover.tex/ArtificialIntelligence_genetic_crossover.tex.tex (deflated 54%)
#   adding: tikz_data/pdfs/example_paths.ortho-hvvh.tex/ (stored 0%)
#   adding: tikz_data/pdfs/example_paths.ortho-hvvh.tex/example_paths.ortho-hvvh.tex.tex (deflated 55%)
#   adding: tikz_data/pdfs/Content_images_L07-img08.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L07-img08.tex/Content_images_L07-img08.tex.tex (deflated 53%)
#   adding: tikz_data/pdfs/documents_Analysis_III_Kapitel-1.tex/ (stored 0%)
#   adding: tikz_data/pdfs/documents_Analysis_III_Kapitel-1.tex/documents_Analysis_III_Kapitel-1.tex.tex (deflated 64%)
#   adding: tikz_data/pdfs/examples_latex_tikz-peaks.tex/ (stored 0%)
#   adding: tikz_data/pdfs/examples_latex_tikz-peaks.tex/examples_latex_tikz-peaks.tex_page_1.png (deflated 2%)
#   adding: tikz_data/pdfs/examples_latex_tikz-peaks.tex/examples_latex_tikz-peaks.tex.pdf (deflated 1%)
#   adding: tikz_data/pdfs/examples_latex_tikz-peaks.tex/examples_latex_tikz-peaks.tex.tex (deflated 38%)
#   adding: tikz_data/pdfs/psnodig_test_programs_thesis_FizzBuzz_FizzBuzz_ibp.tex/ (stored 0%)
#   adding: tikz_data/pdfs/psnodig_test_programs_thesis_FizzBuzz_FizzBuzz_ibp.tex/psnodig_test_programs_thesis_FizzBuzz_FizzBuzz_ibp.tex.tex (deflated 69%)
#   adding: tikz_data/pdfs/src_3d-cone+pgf.tex/ (stored 0%)
#   adding: tikz_data/pdfs/src_3d-cone+pgf.tex/src_3d-cone+pgf.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/src_3d-cone+pgf.tex/src_3d-cone+pgf.tex.tex (deflated 46%)
#   adding: tikz_data/pdfs/src_3d-cone+pgf.tex/src_3d-cone+pgf.tex_page_1.png (deflated 5%)
#   adding: tikz_data/pdfs/tikz_dropout.tex/ (stored 0%)
#   adding: tikz_data/pdfs/tikz_dropout.tex/tikz_dropout.tex.tex (deflated 72%)
#   adding: tikz_data/pdfs/tikz_dropout.tex/tikz_dropout.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/tikz_dropout.tex/tikz_dropout.tex_page_1.png (deflated 5%)
#   adding: tikz_data/pdfs/PIDcircuitTikZ.tex/ (stored 0%)
#   adding: tikz_data/pdfs/PIDcircuitTikZ.tex/PIDcircuitTikZ.tex.tex (deflated 54%)
#   adding: tikz_data/pdfs/images_tikz12.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_tikz12.tex/images_tikz12.tex.tex (deflated 61%)
#   adding: tikz_data/pdfs/doc_tikz-ext-manual-en-library-misc.tex/ (stored 0%)
#   adding: tikz_data/pdfs/doc_tikz-ext-manual-en-library-misc.tex/doc_tikz-ext-manual-en-library-misc.tex.tex (deflated 48%)
#   adding: tikz_data/pdfs/18-the-quantum-atom.tex/ (stored 0%)
#   adding: tikz_data/pdfs/18-the-quantum-atom.tex/18-the-quantum-atom.tex.tex (deflated 59%)
#   adding: tikz_data/pdfs/demo_association.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_association.tex/demo_association.tex.tex (deflated 56%)
#   adding: tikz_data/pdfs/Content_images_L13-img04.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L13-img04.tex/Content_images_L13-img04.tex.tex (deflated 58%)
#   adding: tikz_data/pdfs/tex_circuitikz-0.7-body.tex/ (stored 0%)
#   adding: tikz_data/pdfs/tex_circuitikz-0.7-body.tex/tex_circuitikz-0.7-body.tex.tex (deflated 36%)
#   adding: tikz_data/pdfs/year-3_Principles-of-Quantum-Mechanics_Principles-of-Quantum-Mechanics-Notes.tex/ (stored 0%)
#   adding: tikz_data/pdfs/year-3_Principles-of-Quantum-Mechanics_Principles-of-Quantum-Mechanics-Notes.tex/year-3_Principles-of-Quantum-Mechanics_Principles-of-Quantum-Mechanics-Notes.tex.tex (deflated 63%)
#   adding: tikz_data/pdfs/LaTeX_and_pdfs_Kittel_Kroemer_Thermal_Physics.tex/ (stored 0%)
#   adding: tikz_data/pdfs/LaTeX_and_pdfs_Kittel_Kroemer_Thermal_Physics.tex/LaTeX_and_pdfs_Kittel_Kroemer_Thermal_Physics.tex.tex (deflated 37%)
#   adding: tikz_data/pdfs/LaTeX_and_pdfs_Kittel_Kroemer_Thermal_Physics.tex/LaTeX_and_pdfs_Kittel_Kroemer_Thermal_Physics.tex.out (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L18-img03.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L18-img03.tex/Content_images_L18-img03.tex.tex (deflated 66%)
#   adding: tikz_data/pdfs/buffercount.tex/ (stored 0%)
#   adding: tikz_data/pdfs/buffercount.tex/buffercount.tex.tex (deflated 70%)
#   adding: tikz_data/pdfs/catch.tex/ (stored 0%)
#   adding: tikz_data/pdfs/catch.tex/catch.tex.tex (deflated 71%)
#   adding: tikz_data/pdfs/magnify-glass_example-1.tex/ (stored 0%)
#   adding: tikz_data/pdfs/magnify-glass_example-1.tex/magnify-glass_example-1.tex_page_1.png (deflated 6%)
#   adding: tikz_data/pdfs/magnify-glass_example-1.tex/magnify-glass_example-1.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/magnify-glass_example-1.tex/magnify-glass_example-1.tex.tex (deflated 53%)
#   adding: tikz_data/pdfs/resources_paraboloid.tex/ (stored 0%)
#   adding: tikz_data/pdfs/resources_paraboloid.tex/resources_paraboloid.tex.tex (deflated 52%)
#   adding: tikz_data/pdfs/year-3_Numerical-Recipes_Numerical_Recipes_notes.tex/ (stored 0%)
#   adding: tikz_data/pdfs/year-3_Numerical-Recipes_Numerical_Recipes_notes.tex/year-3_Numerical-Recipes_Numerical_Recipes_notes.tex.tex (deflated 69%)
#   adding: tikz_data/pdfs/doc_generic_pgf_pgfmanual-en-base-patterns.tex/ (stored 0%)
#   adding: tikz_data/pdfs/doc_generic_pgf_pgfmanual-en-base-patterns.tex/doc_generic_pgf_pgfmanual-en-base-patterns.tex.tex (deflated 48%)
#   adding: tikz_data/pdfs/CS2102_cs2102-cheatsheet.tex/ (stored 0%)
#   adding: tikz_data/pdfs/CS2102_cs2102-cheatsheet.tex/CS2102_cs2102-cheatsheet.tex.tex (deflated 50%)
#   adding: tikz_data/pdfs/images_cayley.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_cayley.tex/images_cayley.tex.tex (deflated 61%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_aFirstCourseLinearAlgebra_frontmatter_backpage.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_aFirstCourseLinearAlgebra_frontmatter_backpage.tex/Intro-Math-Programming_baseText_aFirstCourseLinearAlgebra_frontmatter_backpage.tex.tex (deflated 73%)
#   adding: tikz_data/pdfs/talks_include_header_beamer.tex/ (stored 0%)
#   adding: tikz_data/pdfs/talks_include_header_beamer.tex/talks_include_header_beamer.tex.tex (deflated 36%)
#   adding: tikz_data/pdfs/talks_include_header_beamer.tex/talks_include_header_beamer.tex.out (stored 0%)
#   adding: tikz_data/pdfs/examples_demo_manual_annotate_beamer.tex/ (stored 0%)
#   adding: tikz_data/pdfs/examples_demo_manual_annotate_beamer.tex/examples_demo_manual_annotate_beamer.tex.tex (deflated 63%)
#   adding: tikz_data/pdfs/assets_convergence_sca.tex/ (stored 0%)
#   adding: tikz_data/pdfs/assets_convergence_sca.tex/assets_convergence_sca.tex.tex (deflated 69%)
#   adding: tikz_data/pdfs/figures_graph_cut_graph_2.tex/ (stored 0%)
#   adding: tikz_data/pdfs/figures_graph_cut_graph_2.tex/figures_graph_cut_graph_2.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/figures_graph_cut_graph_2.tex/figures_graph_cut_graph_2.tex_page_1.png (deflated 2%)
#   adding: tikz_data/pdfs/figures_graph_cut_graph_2.tex/figures_graph_cut_graph_2.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume2_MarkovChains_MarkovChains.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume2_MarkovChains_MarkovChains.tex/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume2_MarkovChains_MarkovChains.tex.tex (deflated 54%)
#   adding: tikz_data/pdfs/tex_files_1t.tex/ (stored 0%)
#   adding: tikz_data/pdfs/tex_files_1t.tex/tex_files_1t.tex_page_1.png (deflated 6%)
#   adding: tikz_data/pdfs/tex_files_1t.tex/tex_files_1t.tex.tex (deflated 76%)
#   adding: tikz_data/pdfs/tex_files_1t.tex/tex_files_1t.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/Examples_TravisHoppe_pictures_tikzpics.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Examples_TravisHoppe_pictures_tikzpics.tex/Examples_TravisHoppe_pictures_tikzpics.tex.tex (deflated 69%)
#   adding: tikz_data/pdfs/Kampf_Angriff_angriff.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Kampf_Angriff_angriff.tex/Kampf_Angriff_angriff.tex.tex (deflated 60%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_aFirstCourseLinearAlgebra_content_RnVectorsApplicationsWork.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_aFirstCourseLinearAlgebra_content_RnVectorsApplicationsWork.tex/Intro-Math-Programming_baseText_aFirstCourseLinearAlgebra_content_RnVectorsApplicationsWork.tex.tex (deflated 49%)
#   adding: tikz_data/pdfs/chapter8.tex/ (stored 0%)
#   adding: tikz_data/pdfs/chapter8.tex/chapter8.tex.tex (deflated 52%)
#   adding: tikz_data/pdfs/Content_images_L15-img03.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L15-img03.tex/Content_images_L15-img03.tex.tex (deflated 62%)
#   adding: tikz_data/pdfs/images_tikz1.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_tikz1.tex/images_tikz1.tex.tex (deflated 76%)
#   adding: tikz_data/pdfs/advanced-math_knowledge_3-applications-of-derivatives_applications-of-derivatives.tex/ (stored 0%)
#   adding: tikz_data/pdfs/advanced-math_knowledge_3-applications-of-derivatives_applications-of-derivatives.tex/advanced-math_knowledge_3-applications-of-derivatives_applications-of-derivatives.tex.tex (deflated 49%)
#   adding: tikz_data/pdfs/BA2_NotesCours_Analyse-2_Lecture09_lecture9.tex/ (stored 0%)
#   adding: tikz_data/pdfs/BA2_NotesCours_Analyse-2_Lecture09_lecture9.tex/BA2_NotesCours_Analyse-2_Lecture09_lecture9.tex.tex (deflated 49%)
#   adding: tikz_data/pdfs/tikz_artificial_intelligence-nils_nilsson-arr.tex/ (stored 0%)
#   adding: tikz_data/pdfs/tikz_artificial_intelligence-nils_nilsson-arr.tex/tikz_artificial_intelligence-nils_nilsson-arr.tex.tex (deflated 66%)
#   adding: tikz_data/pdfs/demo_dropout.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_dropout.tex/demo_dropout.tex.tex (deflated 89%)
#   adding: tikz_data/pdfs/drawings_ocean.tex/ (stored 0%)
#   adding: tikz_data/pdfs/drawings_ocean.tex/drawings_ocean.tex.tex (deflated 60%)
#   adding: tikz_data/pdfs/signaling_games.tex/ (stored 0%)
#   adding: tikz_data/pdfs/signaling_games.tex/signaling_games.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/signaling_games.tex/signaling_games.tex_page_1.png (deflated 13%)
#   adding: tikz_data/pdfs/signaling_games.tex/signaling_games.tex.tex (deflated 75%)
#   adding: tikz_data/pdfs/demo_multiplex_epidemics-awareness_network.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_multiplex_epidemics-awareness_network.tex/demo_multiplex_epidemics-awareness_network.tex.tex (deflated 85%)
#   adding: tikz_data/pdfs/Exam_images_2013-2014-img03.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Exam_images_2013-2014-img03.tex/Exam_images_2013-2014-img03.tex.tex (deflated 69%)
#   adding: tikz_data/pdfs/test_testbeamer3b.tex/ (stored 0%)
#   adding: tikz_data/pdfs/test_testbeamer3b.tex/test_testbeamer3b.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_local-min.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_local-min.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_local-min.tex.tex (deflated 61%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_local-min.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_local-min.tex_page_1.png (deflated 9%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_local-min.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_local-min.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/test_testbeamer2b.tex/ (stored 0%)
#   adding: tikz_data/pdfs/test_testbeamer2b.tex/test_testbeamer2b.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/year-1_Physics-1B_Waves.tex/ (stored 0%)
#   adding: tikz_data/pdfs/year-1_Physics-1B_Waves.tex/year-1_Physics-1B_Waves.tex.tex (deflated 68%)
#   adding: tikz_data/pdfs/latex_lecture02_dl4nlp2023-lecture02.tex/ (stored 0%)
#   adding: tikz_data/pdfs/latex_lecture02_dl4nlp2023-lecture02.tex/latex_lecture02_dl4nlp2023-lecture02.tex.tex (deflated 68%)
#   adding: tikz_data/pdfs/chapter3.tex/ (stored 0%)
#   adding: tikz_data/pdfs/chapter3.tex/chapter3.tex.tex (deflated 29%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_linear-programming-mix-hildebrand-simplex-method.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_linear-programming-mix-hildebrand-simplex-method.tex/Intro-Math-Programming_baseText_optimization_linear-programming-mix-hildebrand-simplex-method.tex.tex (deflated 64%)
#   adding: tikz_data/pdfs/2023_convexity_convexity.tex/ (stored 0%)
#   adding: tikz_data/pdfs/2023_convexity_convexity.tex/2023_convexity_convexity.tex_page_1.png (deflated 5%)
#   adding: tikz_data/pdfs/2023_convexity_convexity.tex/2023_convexity_convexity.tex.tex (deflated 49%)
#   adding: tikz_data/pdfs/2023_convexity_convexity.tex/2023_convexity_convexity.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/A3C_execution_a3c_execution.tex/ (stored 0%)
#   adding: tikz_data/pdfs/A3C_execution_a3c_execution.tex/A3C_execution_a3c_execution.tex_page_1.png (deflated 7%)
#   adding: tikz_data/pdfs/A3C_execution_a3c_execution.tex/A3C_execution_a3c_execution.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/A3C_execution_a3c_execution.tex/A3C_execution_a3c_execution.tex.tex (deflated 69%)
#   adding: tikz_data/pdfs/networking_ICMPv6-Header_eng.tex/ (stored 0%)
#   adding: tikz_data/pdfs/networking_ICMPv6-Header_eng.tex/networking_ICMPv6-Header_eng.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/networking_ICMPv6-Header_eng.tex/networking_ICMPv6-Header_eng.tex_page_1.png (deflated 10%)
#   adding: tikz_data/pdfs/networking_ICMPv6-Header_eng.tex/networking_ICMPv6-Header_eng.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/Codes_004-line-styles.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Codes_004-line-styles.tex/Codes_004-line-styles.tex.tex (deflated 51%)
#   adding: tikz_data/pdfs/masterthesis_tikz_cnn_aufbau.tex/ (stored 0%)
#   adding: tikz_data/pdfs/masterthesis_tikz_cnn_aufbau.tex/masterthesis_tikz_cnn_aufbau.tex.tex (deflated 67%)
#   adding: tikz_data/pdfs/formatAndDefs.tex/ (stored 0%)
#   adding: tikz_data/pdfs/formatAndDefs.tex/formatAndDefs.tex.tex (deflated 56%)
#   adding: tikz_data/pdfs/Kampf_Schaden_schaden.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Kampf_Schaden_schaden.tex/Kampf_Schaden_schaden.tex.tex (deflated 64%)
#   adding: tikz_data/pdfs/pgf-en-3.1.5b_text-en_pgfmanual-en-base-layers.tex/ (stored 0%)
#   adding: tikz_data/pdfs/pgf-en-3.1.5b_text-en_pgfmanual-en-base-layers.tex/pgf-en-3.1.5b_text-en_pgfmanual-en-base-layers.tex.tex (deflated 55%)
#   adding: tikz_data/pdfs/images_create_step_function.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_create_step_function.tex/images_create_step_function.tex.tex (deflated 61%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_LinearTransformations_LinearTransformations.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_LinearTransformations_LinearTransformations.tex/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_LinearTransformations_LinearTransformations.tex.tex (deflated 49%)
#   adding: tikz_data/pdfs/notes_Chapter-Models_chap2.tex/ (stored 0%)
#   adding: tikz_data/pdfs/notes_Chapter-Models_chap2.tex/notes_Chapter-Models_chap2.tex.tex (deflated 76%)
#   adding: tikz_data/pdfs/examples_spl.tex/ (stored 0%)
#   adding: tikz_data/pdfs/examples_spl.tex/examples_spl.tex.tex (deflated 78%)
#   adding: tikz_data/pdfs/images_tikz19.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_tikz19.tex/images_tikz19.tex.tex (deflated 63%)
#   adding: tikz_data/pdfs/plot_SPM.tex/ (stored 0%)
#   adding: tikz_data/pdfs/plot_SPM.tex/plot_SPM.tex.tex (deflated 62%)
#   adding: tikz_data/pdfs/ciphers_Pockenacci_LaTeX_stills_authentication_mac_column_down.tex/ (stored 0%)
#   adding: tikz_data/pdfs/ciphers_Pockenacci_LaTeX_stills_authentication_mac_column_down.tex/ciphers_Pockenacci_LaTeX_stills_authentication_mac_column_down.tex.tex (deflated 80%)
#   adding: tikz_data/pdfs/Content_images_L01-img05.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L01-img05.tex/Content_images_L01-img05.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/ArtificialIntelligence_can_mis.tex/ (stored 0%)
#   adding: tikz_data/pdfs/ArtificialIntelligence_can_mis.tex/ArtificialIntelligence_can_mis.tex.tex (deflated 32%)
#   adding: tikz_data/pdfs/business_cycles.tex/ (stored 0%)
#   adding: tikz_data/pdfs/business_cycles.tex/business_cycles.tex_page_1.png (deflated 9%)
#   adding: tikz_data/pdfs/business_cycles.tex/business_cycles.tex.tex (deflated 69%)
#   adding: tikz_data/pdfs/business_cycles.tex/business_cycles.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/test_testbeamer5c.tex/ (stored 0%)
#   adding: tikz_data/pdfs/test_testbeamer5c.tex/test_testbeamer5c.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/02-First-steps-creating-TikZ-images_03-circles.tex/ (stored 0%)
#   adding: tikz_data/pdfs/02-First-steps-creating-TikZ-images_03-circles.tex/02-First-steps-creating-TikZ-images_03-circles.tex.tex (deflated 46%)
#   adding: tikz_data/pdfs/demo_multilayer_network.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_multilayer_network.tex/demo_multilayer_network.tex.tex (deflated 68%)
#   adding: tikz_data/pdfs/latex_lecture07_dl4nlp2023-lecture07.tex/ (stored 0%)
#   adding: tikz_data/pdfs/latex_lecture07_dl4nlp2023-lecture07.tex/latex_lecture07_dl4nlp2023-lecture07.tex.tex (deflated 51%)
#   adding: tikz_data/pdfs/arendt-dialectic.tex/ (stored 0%)
#   adding: tikz_data/pdfs/arendt-dialectic.tex/arendt-dialectic.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/arendt-dialectic.tex/arendt-dialectic.tex_page_1.png (deflated 14%)
#   adding: tikz_data/pdfs/arendt-dialectic.tex/arendt-dialectic.tex.tex (deflated 56%)
#   adding: tikz_data/pdfs/demo_x-cnn.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_x-cnn.tex/demo_x-cnn.tex.tex (deflated 88%)
#   adding: tikz_data/pdfs/example-10.18.tex/ (stored 0%)
#   adding: tikz_data/pdfs/example-10.18.tex/example-10.18.tex.tex (deflated 44%)
#   adding: tikz_data/pdfs/example-10.18.tex/example-10.18.tex_page_1.png (deflated 6%)
#   adding: tikz_data/pdfs/example-10.18.tex/example-10.18.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/src_3d-physics-jet-cones+3d+physics.tex/ (stored 0%)
#   adding: tikz_data/pdfs/src_3d-physics-jet-cones+3d+physics.tex/src_3d-physics-jet-cones+3d+physics.tex_page_1.png (deflated 3%)
#   adding: tikz_data/pdfs/src_3d-physics-jet-cones+3d+physics.tex/src_3d-physics-jet-cones+3d+physics.tex.tex (deflated 53%)
#   adding: tikz_data/pdfs/src_3d-physics-jet-cones+3d+physics.tex/src_3d-physics-jet-cones+3d+physics.tex.pdf (deflated 25%)
#   adding: tikz_data/pdfs/chapters_25-magnetic-fields.tex/ (stored 0%)
#   adding: tikz_data/pdfs/chapters_25-magnetic-fields.tex/chapters_25-magnetic-fields.tex.tex (deflated 58%)
#   adding: tikz_data/pdfs/2-ref_3ref.tex/ (stored 0%)
#   adding: tikz_data/pdfs/2-ref_3ref.tex/2-ref_3ref.tex.tex (deflated 59%)
#   adding: tikz_data/pdfs/example_prob2.tex/ (stored 0%)
#   adding: tikz_data/pdfs/example_prob2.tex/example_prob2.tex.tex (deflated 47%)
#   adding: tikz_data/pdfs/Kampf_Home_home.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Kampf_Home_home.tex/Kampf_Home_home.tex.tex (deflated 60%)
#   adding: tikz_data/pdfs/Content_images_L07-img14.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L07-img14.tex/Content_images_L07-img14.tex.tex (deflated 47%)
#   adding: tikz_data/pdfs/assets_path_loss.tex/ (stored 0%)
#   adding: tikz_data/pdfs/assets_path_loss.tex/assets_path_loss.tex.tex (deflated 68%)
#   adding: tikz_data/pdfs/Slides_Lecture16_singlelayer_perceptron_3.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Slides_Lecture16_singlelayer_perceptron_3.tex/Slides_Lecture16_singlelayer_perceptron_3.tex.tex (deflated 59%)
#   adding: tikz_data/pdfs/publicGoodsGarden_publicGoodsGarden-beamer.tex/ (stored 0%)
#   adding: tikz_data/pdfs/publicGoodsGarden_publicGoodsGarden-beamer.tex/publicGoodsGarden_publicGoodsGarden-beamer.tex.tex (deflated 58%)
#   adding: tikz_data/pdfs/Examples_ColemanKrawczyk_talk_Thesis_talk.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Examples_ColemanKrawczyk_talk_Thesis_talk.tex/Examples_ColemanKrawczyk_talk_Thesis_talk.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/block-diagram_example-1.tex/ (stored 0%)
#   adding: tikz_data/pdfs/block-diagram_example-1.tex/block-diagram_example-1.tex.tex (deflated 58%)
#   adding: tikz_data/pdfs/examples_minimal.tex/ (stored 0%)
#   adding: tikz_data/pdfs/examples_minimal.tex/examples_minimal.tex.tex (deflated 33%)
#   adding: tikz_data/pdfs/ciphers_Pockenacci_LaTeX_stills_encryption_alt_plaintext_post_iv.tex/ (stored 0%)
#   adding: tikz_data/pdfs/ciphers_Pockenacci_LaTeX_stills_encryption_alt_plaintext_post_iv.tex/ciphers_Pockenacci_LaTeX_stills_encryption_alt_plaintext_post_iv.tex.tex (deflated 79%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_gradient-descent.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_gradient-descent.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_gradient-descent.tex.pdf (deflated 1%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_gradient-descent.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_gradient-descent.tex_page_1.png (deflated 2%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_gradient-descent.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_gradient-descent.tex.tex (deflated 42%)
#   adding: tikz_data/pdfs/demo_gat_layer.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_gat_layer.tex/demo_gat_layer.tex.tex (deflated 82%)
#   adding: tikz_data/pdfs/lewis_turning_point.tex/ (stored 0%)
#   adding: tikz_data/pdfs/lewis_turning_point.tex/lewis_turning_point.tex_page_1.png (deflated 10%)
#   adding: tikz_data/pdfs/lewis_turning_point.tex/lewis_turning_point.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/lewis_turning_point.tex/lewis_turning_point.tex.tex (deflated 64%)
#   adding: tikz_data/pdfs/images_tikz13.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_tikz13.tex/images_tikz13.tex.tex (deflated 67%)
#   adding: tikz_data/pdfs/Content_images_L13-img03.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L13-img03.tex/Content_images_L13-img03.tex.tex (deflated 63%)
#   adding: tikz_data/pdfs/Slides_video05.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Slides_video05.tex/Slides_video05.tex.tex (deflated 57%)
#   adding: tikz_data/pdfs/Slides_video05.tex/Slides_video05.tex.out (stored 0%)
#   adding: tikz_data/pdfs/doc_preliminaries.tex/ (stored 0%)
#   adding: tikz_data/pdfs/doc_preliminaries.tex/doc_preliminaries.tex.tex (deflated 34%)
#   adding: tikz_data/pdfs/report_src_figures_add_example_sum.tex/ (stored 0%)
#   adding: tikz_data/pdfs/report_src_figures_add_example_sum.tex/report_src_figures_add_example_sum.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/flowchart_example-1.tex/ (stored 0%)
#   adding: tikz_data/pdfs/flowchart_example-1.tex/flowchart_example-1.tex.tex (deflated 66%)
#   adding: tikz_data/pdfs/assets_splitting_ratio_noise.tex/ (stored 0%)
#   adding: tikz_data/pdfs/assets_splitting_ratio_noise.tex/assets_splitting_ratio_noise.tex.tex (deflated 59%)
#   adding: tikz_data/pdfs/images_sigmoid_like.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_sigmoid_like.tex/images_sigmoid_like.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/images_sigmoid_like.tex/images_sigmoid_like.tex.tex (deflated 36%)
#   adding: tikz_data/pdfs/example.tex/ (stored 0%)
#   adding: tikz_data/pdfs/example.tex/example.tex.tex (deflated 53%)
#   adding: tikz_data/pdfs/CRT_rendering_crt_rendering.tex/ (stored 0%)
#   adding: tikz_data/pdfs/CRT_rendering_crt_rendering.tex/CRT_rendering_crt_rendering.tex.tex (deflated 74%)
#   adding: tikz_data/pdfs/CRT_rendering_crt_rendering.tex/CRT_rendering_crt_rendering.tex_page_1.png (deflated 5%)
#   adding: tikz_data/pdfs/CRT_rendering_crt_rendering.tex/CRT_rendering_crt_rendering.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/Codes_003-close-path.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Codes_003-close-path.tex/Codes_003-close-path.tex.tex (deflated 32%)
#   adding: tikz_data/pdfs/exercises_APE1_APE1-Introduction.tex/ (stored 0%)
#   adding: tikz_data/pdfs/exercises_APE1_APE1-Introduction.tex/exercises_APE1_APE1-Introduction.tex.tex (deflated 54%)
#   adding: tikz_data/pdfs/Content_images_L07-img07.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L07-img07.tex/Content_images_L07-img07.tex.tex (deflated 61%)
#   adding: tikz_data/pdfs/images_tikz11.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_tikz11.tex/images_tikz11.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/tikz_agent_interaction.tex/ (stored 0%)
#   adding: tikz_data/pdfs/tikz_agent_interaction.tex/tikz_agent_interaction.tex.tex (deflated 58%)
#   adding: tikz_data/pdfs/BA2_NotesCours_Analyse-2_Lecture11_lecture11.tex/ (stored 0%)
#   adding: tikz_data/pdfs/BA2_NotesCours_Analyse-2_Lecture11_lecture11.tex/BA2_NotesCours_Analyse-2_Lecture11_lecture11.tex.tex (deflated 53%)
#   adding: tikz_data/pdfs/images_sigmoid_function.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_sigmoid_function.tex/images_sigmoid_function.tex.tex (deflated 48%)
#   adding: tikz_data/pdfs/images_tikz23.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_tikz23.tex/images_tikz23.tex.tex (deflated 63%)
#   adding: tikz_data/pdfs/images_tikz17.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_tikz17.tex/images_tikz17.tex.tex (deflated 59%)
#   adding: tikz_data/pdfs/test_testbeamer2.tex/ (stored 0%)
#   adding: tikz_data/pdfs/test_testbeamer2.tex/test_testbeamer2.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/resources_steepest-descent-elliptic.tex/ (stored 0%)
#   adding: tikz_data/pdfs/resources_steepest-descent-elliptic.tex/resources_steepest-descent-elliptic.tex.tex (deflated 56%)
#   adding: tikz_data/pdfs/test_testbeamer4b.tex/ (stored 0%)
#   adding: tikz_data/pdfs/test_testbeamer4b.tex/test_testbeamer4b.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/demo_dna.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_dna.tex/demo_dna.tex.tex (deflated 71%)
#   adding: tikz_data/pdfs/report_src_figures_add_example_kroneker.tex/ (stored 0%)
#   adding: tikz_data/pdfs/report_src_figures_add_example_kroneker.tex/report_src_figures_add_example_kroneker.tex.tex (deflated 85%)
#   adding: tikz_data/pdfs/gaming-diagrams.tex/ (stored 0%)
#   adding: tikz_data/pdfs/gaming-diagrams.tex/gaming-diagrams.tex.tex (deflated 39%)
#   adding: tikz_data/pdfs/Oefeningenbundel_3BST.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Oefeningenbundel_3BST.tex/Oefeningenbundel_3BST.tex.tex (deflated 50%)
#   adding: tikz_data/pdfs/Fig._9-1._The_effect_of_rent_control_on_the_rental_market.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Fig._9-1._The_effect_of_rent_control_on_the_rental_market.tex/Fig._9-1._The_effect_of_rent_control_on_the_rental_market.tex_page_1.png (deflated 16%)
#   adding: tikz_data/pdfs/Fig._9-1._The_effect_of_rent_control_on_the_rental_market.tex/Fig._9-1._The_effect_of_rent_control_on_the_rental_market.tex.tex (deflated 61%)
#   adding: tikz_data/pdfs/Fig._9-1._The_effect_of_rent_control_on_the_rental_market.tex/Fig._9-1._The_effect_of_rent_control_on_the_rental_market.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/images_bump_3d.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_bump_3d.tex/images_bump_3d.tex.tex (deflated 62%)
#   adding: tikz_data/pdfs/images_bump_3d.tex/images_bump_3d.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/notes_Chapter-Refinements_chap5.tex/ (stored 0%)
#   adding: tikz_data/pdfs/notes_Chapter-Refinements_chap5.tex/notes_Chapter-Refinements_chap5.tex.tex (deflated 73%)
#   adding: tikz_data/pdfs/graph_box.tex/ (stored 0%)
#   adding: tikz_data/pdfs/graph_box.tex/graph_box.tex.tex (deflated 78%)
#   adding: tikz_data/pdfs/networking_ISO-modell_ger.tex/ (stored 0%)
#   adding: tikz_data/pdfs/networking_ISO-modell_ger.tex/networking_ISO-modell_ger.tex.tex (deflated 71%)
#   adding: tikz_data/pdfs/network_diagram.tex/ (stored 0%)
#   adding: tikz_data/pdfs/network_diagram.tex/network_diagram.tex.tex (deflated 76%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_tikz_extended-formulation2.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_tikz_extended-formulation2.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_tikz_extended-formulation2.tex.tex (deflated 54%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_tikz_extended-formulation2.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_tikz_extended-formulation2.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_tikz_extended-formulation2.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_tikz_extended-formulation2.tex_page_1.png (deflated 17%)
#   adding: tikz_data/pdfs/access-om3-dev-diagram.tex/ (stored 0%)
#   adding: tikz_data/pdfs/access-om3-dev-diagram.tex/access-om3-dev-diagram.tex.tex (deflated 87%)
#   adding: tikz_data/pdfs/5.tex/ (stored 0%)
#   adding: tikz_data/pdfs/5.tex/5.tex.tex (deflated 56%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_Differentiation_Differentiation.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_Differentiation_Differentiation.tex/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_Differentiation_Differentiation.tex.tex (deflated 75%)
#   adding: tikz_data/pdfs/badiou_conditions.tex/ (stored 0%)
#   adding: tikz_data/pdfs/badiou_conditions.tex/badiou_conditions.tex_page_1.png (deflated 5%)
#   adding: tikz_data/pdfs/badiou_conditions.tex/badiou_conditions.tex.tex (deflated 61%)
#   adding: tikz_data/pdfs/badiou_conditions.tex/badiou_conditions.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_simplex_method.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_simplex_method.tex/Intro-Math-Programming_baseText_optimization_simplex_method.tex.tex (deflated 64%)
#   adding: tikz_data/pdfs/demo_sparse_dgi.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_sparse_dgi.tex/demo_sparse_dgi.tex.tex (deflated 91%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_svm2.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_figures_figures-source_svm2.tex/Intro-Math-Programming_baseText_optimization_figures_figures-source_svm2.tex.tex (deflated 64%)
#   adding: tikz_data/pdfs/tikz_artificial_intelligence_bender-01.tex/ (stored 0%)
#   adding: tikz_data/pdfs/tikz_artificial_intelligence_bender-01.tex/tikz_artificial_intelligence_bender-01.tex.tex (deflated 68%)
#   adding: tikz_data/pdfs/examples_cloak.tex/ (stored 0%)
#   adding: tikz_data/pdfs/examples_cloak.tex/examples_cloak.tex.tex (deflated 50%)
#   adding: tikz_data/pdfs/images_example.tex/ (stored 0%)
#   adding: tikz_data/pdfs/images_example.tex/images_example.tex_page_1.png (deflated 9%)
#   adding: tikz_data/pdfs/images_example.tex/images_example.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/images_example.tex/images_example.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/README.tex/ (stored 0%)
#   adding: tikz_data/pdfs/README.tex/README.tex.tex (deflated 39%)
#   adding: tikz_data/pdfs/README.tex/README.tex_page_1.png (deflated 0%)
#   adding: tikz_data/pdfs/README.tex/README.tex.pdf (deflated 42%)
#   adding: tikz_data/pdfs/2022-projects_Voitovych_tikz_bipsgrowth.tex/ (stored 0%)
#   adding: tikz_data/pdfs/2022-projects_Voitovych_tikz_bipsgrowth.tex/2022-projects_Voitovych_tikz_bipsgrowth.tex.tex (deflated 66%)
#   adding: tikz_data/pdfs/block_residual2.tex/ (stored 0%)
#   adding: tikz_data/pdfs/block_residual2.tex/block_residual2.tex.tex (deflated 58%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume2_BreadthFirstSearch_BreadthFirstSearch.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume2_BreadthFirstSearch_BreadthFirstSearch.tex/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume2_BreadthFirstSearch_BreadthFirstSearch.tex.tex (deflated 46%)
#   adding: tikz_data/pdfs/flowchart_example-3.tex/ (stored 0%)
#   adding: tikz_data/pdfs/flowchart_example-3.tex/flowchart_example-3.tex.tex (deflated 55%)
#   adding: tikz_data/pdfs/1.tex/ (stored 0%)
#   adding: tikz_data/pdfs/1.tex/1.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_advancedIntegerProgramming.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_optimization_advancedIntegerProgramming.tex/Intro-Math-Programming_baseText_optimization_advancedIntegerProgramming.tex.tex (deflated 51%)
#   adding: tikz_data/pdfs/example_MPS.tex/ (stored 0%)
#   adding: tikz_data/pdfs/example_MPS.tex/example_MPS.tex.tex (deflated 57%)
#   adding: tikz_data/pdfs/probability-theory-and-mathematical-statistics_exercise_2-random-variables-and-distribution_random-variables-and-distribution.tex/ (stored 0%)
#   adding: tikz_data/pdfs/probability-theory-and-mathematical-statistics_exercise_2-random-variables-and-distribution_random-variables-and-distribution.tex/probability-theory-and-mathematical-statistics_exercise_2-random-variables-and-distribution_random-variables-and-distribution.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/probability-theory-and-mathematical-statistics_exercise_2-random-variables-and-distribution_random-variables-and-distribution.tex/probability-theory-and-mathematical-statistics_exercise_2-random-variables-and-distribution_random-variables-and-distribution.tex.tex (deflated 55%)
#   adding: tikz_data/pdfs/probability-theory-and-mathematical-statistics_exercise_2-random-variables-and-distribution_random-variables-and-distribution.tex/probability-theory-and-mathematical-statistics_exercise_2-random-variables-and-distribution_random-variables-and-distribution.tex_page_1.png (deflated 16%)
#   adding: tikz_data/pdfs/Fig._5-9._A_production-possibility_frontier_between_A_and_B.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Fig._5-9._A_production-possibility_frontier_between_A_and_B.tex/Fig._5-9._A_production-possibility_frontier_between_A_and_B.tex.tex (deflated 47%)
#   adding: tikz_data/pdfs/exercises_APE3_0301unFeasProb.tex/ (stored 0%)
#   adding: tikz_data/pdfs/exercises_APE3_0301unFeasProb.tex/exercises_APE3_0301unFeasProb.tex.tex (deflated 59%)
#   adding: tikz_data/pdfs/examples_Back.tex/ (stored 0%)
#   adding: tikz_data/pdfs/examples_Back.tex/examples_Back.tex_page_1.png (deflated 1%)
#   adding: tikz_data/pdfs/examples_Back.tex/examples_Back.tex.tex (deflated 30%)
#   adding: tikz_data/pdfs/examples_Back.tex/examples_Back.tex.pdf (deflated 11%)
#   adding: tikz_data/pdfs/figures_2d-graph_2d-graph.tex/ (stored 0%)
#   adding: tikz_data/pdfs/figures_2d-graph_2d-graph.tex/figures_2d-graph_2d-graph.tex_page_1.png (deflated 1%)
#   adding: tikz_data/pdfs/figures_2d-graph_2d-graph.tex/figures_2d-graph_2d-graph.tex.tex (deflated 81%)
#   adding: tikz_data/pdfs/figures_2d-graph_2d-graph.tex/figures_2d-graph_2d-graph.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/Homework_images_E03-img01.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Homework_images_E03-img01.tex/Homework_images_E03-img01.tex.tex (deflated 74%)
#   adding: tikz_data/pdfs/Slides_Lecture14_multilayer_perceptron.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Slides_Lecture14_multilayer_perceptron.tex/Slides_Lecture14_multilayer_perceptron.tex.tex (deflated 74%)
#   adding: tikz_data/pdfs/blockdiagram.tex/ (stored 0%)
#   adding: tikz_data/pdfs/blockdiagram.tex/blockdiagram.tex.tex (deflated 50%)
#   adding: tikz_data/pdfs/LaTeX_and_pdfs_EM_dump.tex/ (stored 0%)
#   adding: tikz_data/pdfs/LaTeX_and_pdfs_EM_dump.tex/LaTeX_and_pdfs_EM_dump.tex.tex (deflated 47%)
#   adding: tikz_data/pdfs/test_testbeamer3c.tex/ (stored 0%)
#   adding: tikz_data/pdfs/test_testbeamer3c.tex/test_testbeamer3c.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/assets_waveform_subband.tex/ (stored 0%)
#   adding: tikz_data/pdfs/assets_waveform_subband.tex/assets_waveform_subband.tex.tex (deflated 75%)
#   adding: tikz_data/pdfs/Slides_Lecture14_sigmoid-derivative.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Slides_Lecture14_sigmoid-derivative.tex/Slides_Lecture14_sigmoid-derivative.tex.tex (deflated 63%)
#   adding: tikz_data/pdfs/demo_semi-supervised_learning.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_semi-supervised_learning.tex/demo_semi-supervised_learning.tex.tex (deflated 84%)
#   adding: tikz_data/pdfs/block-diagram_example-3.tex/ (stored 0%)
#   adding: tikz_data/pdfs/block-diagram_example-3.tex/block-diagram_example-3.tex.tex (deflated 54%)
#   adding: tikz_data/pdfs/convexity.tex/ (stored 0%)
#   adding: tikz_data/pdfs/convexity.tex/convexity.tex.tex (deflated 53%)
#   adding: tikz_data/pdfs/Typesetting_Discrete_Math_Typeset.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Typesetting_Discrete_Math_Typeset.tex/Typesetting_Discrete_Math_Typeset.tex_page_1.png (deflated 3%)
#   adding: tikz_data/pdfs/Typesetting_Discrete_Math_Typeset.tex/Typesetting_Discrete_Math_Typeset.tex.tex (deflated 72%)
#   adding: tikz_data/pdfs/Typesetting_Discrete_Math_Typeset.tex/Typesetting_Discrete_Math_Typeset.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/paper_amor.tex/ (stored 0%)
#   adding: tikz_data/pdfs/paper_amor.tex/paper_amor.tex.tex (deflated 36%)
#   adding: tikz_data/pdfs/Fig._6-4._The_effect_of_a_gasoline_tax_on_consumption_and_production_and_total_tax_revenue.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Fig._6-4._The_effect_of_a_gasoline_tax_on_consumption_and_production_and_total_tax_revenue.tex/Fig._6-4._The_effect_of_a_gasoline_tax_on_consumption_and_production_and_total_tax_revenue.tex_page_1.png (deflated 14%)
#   adding: tikz_data/pdfs/Fig._6-4._The_effect_of_a_gasoline_tax_on_consumption_and_production_and_total_tax_revenue.tex/Fig._6-4._The_effect_of_a_gasoline_tax_on_consumption_and_production_and_total_tax_revenue.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/Fig._6-4._The_effect_of_a_gasoline_tax_on_consumption_and_production_and_total_tax_revenue.tex/Fig._6-4._The_effect_of_a_gasoline_tax_on_consumption_and_production_and_total_tax_revenue.tex.tex (deflated 67%)
#   adding: tikz_data/pdfs/lacan_graph_of_desire.tex/ (stored 0%)
#   adding: tikz_data/pdfs/lacan_graph_of_desire.tex/lacan_graph_of_desire.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/lacan_graph_of_desire.tex/lacan_graph_of_desire.tex.tex (deflated 68%)
#   adding: tikz_data/pdfs/lacan_graph_of_desire.tex/lacan_graph_of_desire.tex_page_1.png (deflated 6%)
#   adding: tikz_data/pdfs/ciphers_Pockenacci_LaTeX_stills_encryption_each_shift_forward.tex/ (stored 0%)
#   adding: tikz_data/pdfs/ciphers_Pockenacci_LaTeX_stills_encryption_each_shift_forward.tex/ciphers_Pockenacci_LaTeX_stills_encryption_each_shift_forward.tex.tex (deflated 79%)
#   adding: tikz_data/pdfs/test_testbeamer5.tex/ (stored 0%)
#   adding: tikz_data/pdfs/test_testbeamer5.tex/test_testbeamer5.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/braess.tex/ (stored 0%)
#   adding: tikz_data/pdfs/braess.tex/braess.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/braess.tex/braess.tex_page_1.png (deflated 8%)
#   adding: tikz_data/pdfs/braess.tex/braess.tex.pdf (deflated 4%)
#   adding: tikz_data/pdfs/circuits_circ_generic_U4.tex/ (stored 0%)
#   adding: tikz_data/pdfs/circuits_circ_generic_U4.tex/circuits_circ_generic_U4.tex.tex (deflated 54%)
#   adding: tikz_data/pdfs/circuits_circ_generic_U4.tex/circuits_circ_generic_U4.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/circuits_circ_generic_U4.tex/circuits_circ_generic_U4.tex_page_1.png (deflated 5%)
#   adding: tikz_data/pdfs/presentation_slides_einleitung.tex/ (stored 0%)
#   adding: tikz_data/pdfs/presentation_slides_einleitung.tex/presentation_slides_einleitung.tex.tex (deflated 31%)
#   adding: tikz_data/pdfs/doc_tikzpingus-doc.tex/ (stored 0%)
#   adding: tikz_data/pdfs/doc_tikzpingus-doc.tex/doc_tikzpingus-doc.tex.tex (deflated 37%)
#   adding: tikz_data/pdfs/demo_mcl.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_mcl.tex/demo_mcl.tex.tex (deflated 87%)
#   adding: tikz_data/pdfs/demo_convolutional_autoencoder.tex/ (stored 0%)
#   adding: tikz_data/pdfs/demo_convolutional_autoencoder.tex/demo_convolutional_autoencoder.tex.tex (deflated 72%)
#   adding: tikz_data/pdfs/example_paths.ortho-udlr.tex/ (stored 0%)
#   adding: tikz_data/pdfs/example_paths.ortho-udlr.tex/example_paths.ortho-udlr.tex.tex (deflated 56%)
#   adding: tikz_data/pdfs/12-electric-fields.tex/ (stored 0%)
#   adding: tikz_data/pdfs/12-electric-fields.tex/12-electric-fields.tex.tex (deflated 70%)
#   adding: tikz_data/pdfs/masterthesis_tikz_cnn.tex/ (stored 0%)
#   adding: tikz_data/pdfs/masterthesis_tikz_cnn.tex/masterthesis_tikz_cnn.tex.tex (deflated 83%)
#   adding: tikz_data/pdfs/tikz_Dissertationsprozess.tex/ (stored 0%)
#   adding: tikz_data/pdfs/tikz_Dissertationsprozess.tex/tikz_Dissertationsprozess.tex.tex (deflated 68%)
#   adding: tikz_data/pdfs/tex_files_1split.tex/ (stored 0%)
#   adding: tikz_data/pdfs/tex_files_1split.tex/tex_files_1split.tex_page_1.png (deflated 7%)
#   adding: tikz_data/pdfs/tex_files_1split.tex/tex_files_1split.tex.pdf (deflated 3%)
#   adding: tikz_data/pdfs/tex_files_1split.tex/tex_files_1split.tex.tex (deflated 86%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_DrazinInverse_DrazinInverse.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_DrazinInverse_DrazinInverse.tex/Intro-Math-Programming_baseText_foundationsAppliedMathematicsLabs_Volume1_DrazinInverse_DrazinInverse.tex.tex (deflated 75%)
#   adding: tikz_data/pdfs/prepurge.tex/ (stored 0%)
#   adding: tikz_data/pdfs/prepurge.tex/prepurge.tex.tex (deflated 54%)
#   adding: tikz_data/pdfs/examples_complex_ex_complex_01.tex/ (stored 0%)
#   adding: tikz_data/pdfs/examples_complex_ex_complex_01.tex/examples_complex_ex_complex_01.tex.tex (deflated 40%)
#   adding: tikz_data/pdfs/latex_lecture05_dl4nlp2023-lecture05.tex/ (stored 0%)
#   adding: tikz_data/pdfs/latex_lecture05_dl4nlp2023-lecture05.tex/latex_lecture05_dl4nlp2023-lecture05.tex.tex (deflated 66%)
#   adding: tikz_data/pdfs/figures_expansion_expansion_2.tex/ (stored 0%)
#   adding: tikz_data/pdfs/figures_expansion_expansion_2.tex/figures_expansion_expansion_2.tex.tex (deflated 79%)
#   adding: tikz_data/pdfs/figures_expansion_expansion_2.tex/figures_expansion_expansion_2.tex_page_1.png (deflated 82%)
#   adding: tikz_data/pdfs/figures_expansion_expansion_2.tex/figures_expansion_expansion_2.tex.pdf (deflated 16%)
#   adding: tikz_data/pdfs/masterthesis_tikz_bspline_beweis.tex/ (stored 0%)
#   adding: tikz_data/pdfs/masterthesis_tikz_bspline_beweis.tex/masterthesis_tikz_bspline_beweis.tex.tex (deflated 55%)
#   adding: tikz_data/pdfs/bardini-junk.tex/ (stored 0%)
#   adding: tikz_data/pdfs/bardini-junk.tex/bardini-junk.tex_page_1.png (deflated 12%)
#   adding: tikz_data/pdfs/bardini-junk.tex/bardini-junk.tex.tex (deflated 65%)
#   adding: tikz_data/pdfs/bardini-junk.tex/bardini-junk.tex.pdf (deflated 2%)
#   adding: tikz_data/pdfs/Content_images_L07-img09.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Content_images_L07-img09.tex/Content_images_L07-img09.tex.tex (deflated 70%)
#   adding: tikz_data/pdfs/Exam_images_mock-img01.tex/ (stored 0%)
#   adding: tikz_data/pdfs/Exam_images_mock-img01.tex/Exam_images_mock-img01.tex.tex (deflated 70%)
#   adding: tikz_data/pdfs/examples_fcn32s_fcn32.tex/ (stored 0%)
#   adding: tikz_data/pdfs/examples_fcn32s_fcn32.tex/examples_fcn32s_fcn32.tex.tex (deflated 78%)
#   adding: tikz_data/pdfs/images_step_function.tex/ (stored 0%)
# ...
#   adding: tikz_data/code/complete_atlasean_euclidea_apollonius-problem.tex (deflated 60%)
#   adding: tikz_data/code/complete_pgf-tikz_pgf_pgfmanual-en-oo.tex.tex (deflated 34%)
#   adding: tikz_data/code/complete_pgf-tikz_pgfplots_pgfmanual-en-macros.tex (deflated 34%)
#   adding: tikz_data/code/complete_PacktPublishing_LaTeX-graphics-with-TikZ_16-simple-graph.tex.tex (deflated 34%)
#   adding: tikz_data/code/complete_alextsagkas_Tikz-Graphics_bl.tex (deflated 57%)
#   adding: tikz_data/code/complete_PacktPublishing_LaTeX-graphics-with-TikZ_09-sideways-tree.tex.tex (deflated 59%)
#   adding: tikz_data/code/complete_mvoelk_nn_graphics_block_dense.tex (deflated 63%)
#   adding: tikz_data/code/complete_justintroutman_pocketblock_plaintext.tex (deflated 80%)
#   adding: tikz_data/code/complete_zhanggyb_nndl_sigmoid_like.tex (deflated 37%)
#   adding: tikz_data/code/complete_MartinThoma_LaTeX-examples_Kapitel-1.tex.tex (deflated 64%)
#   adding: tikz_data/code/complete_alextsagkas_Tikz-Graphics_Ressonance.tex.tex (deflated 73%)
#   adding: tikz_data/code/complete_jluttine_tikz-bayesnet_model_pca2.tex (deflated 63%)
#   adding: tikz_data/code/complete_zhanggyb_nndl_narrow_gaussian.tex (deflated 42%)
#   adding: tikz_data/code/complete_MartinThoma_LaTeX-examples_ECB-Mode-Encryption.tex.tex (deflated 59%)
#   adding: tikz_data/code/complete_PacktPublishing_LaTeX-graphics-with-TikZ_27-color-wheel.tex.tex (deflated 32%)
#   adding: tikz_data/code/complete_ravijo_Latex-Examples_example-3.tex (deflated 62%)
#   adding: tikz_data/code/complete_bonsai-rx_marble-diagrams_accumulate.tex (deflated 74%)
#   adding: tikz_data/code/complete_dl4nlp-tuda_deep-learning-for-nlp-lectures_dl4nlp2023-lecture07.tex (deflated 56%)
#   adding: tikz_data/code/complete_rusty1s_deep-learning-on-graphs_clustering.tex (deflated 57%)
#   adding: tikz_data/code/complete_WilloughbySeago_Uni-Notes_Waves.tex (deflated 69%)
#   adding: tikz_data/code/complete_MartinScharrer_standalone_testbeamer4c.tex (deflated 35%)
#   adding: tikz_data/code/complete_circuitikz_circuitikz_circuitikz-1.0-body.tex.tex (deflated 32%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_ProportionalDeriviateControl.tex.tex (deflated 58%)
#   adding: tikz_data/code/complete_PacktPublishing_LaTeX-graphics-with-TikZ_11-inverted-tree.tex.tex (deflated 47%)
#   adding: tikz_data/code/complete_skeydan_Deep-Learning-and-Scientific-Computing-with-R-torch_steepest-descent-symmetric.tex (deflated 62%)
#   adding: tikz_data/code/complete_Didnelpsun_Math_mathematical-statistics.tex (deflated 59%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_tech-stack.tex.tex (deflated 66%)
#   adding: tikz_data/code/complete_open-optimization_open-optimization-or-book_cut-3-color.tex (deflated 87%)
#   adding: tikz_data/code/complete_PacktPublishing_LaTeX-graphics-with-TikZ_17-filled-segment.tex.tex (deflated 51%)
#   adding: tikz_data/code/complete_gjoncas_Econ-Diagrams_shadow banking.tex (deflated 67%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_progressive_neural_network.tex.tex (deflated 92%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_generative_adversarial_network.tex (deflated 64%)
#   adding: tikz_data/code/complete_MartinThoma_LaTeX-examples_titlepage.tex.tex (deflated 49%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_stockReportArch.tex.tex (deflated 65%)
#   adding: tikz_data/code/complete_PetarV-_TikZ_reinforcement_learning_greedy_policy.tex.tex (deflated 76%)
#   adding: tikz_data/code/complete_UChicagoPhysics_PHYS250_sigmoid-derivative.tex (deflated 64%)
#   adding: tikz_data/code/complete_alextsagkas_Tikz-Graphics_Interferometer.tex.tex (deflated 65%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_a3c_execution.tex.tex (deflated 70%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_circleDia.tex (deflated 63%)
#   adding: tikz_data/code/complete_sreahw_schuller-geometric_10tangent_bundle.tex (deflated 67%)
#   adding: tikz_data/code/complete_jackypacky_pgf-econ-graphs_Fig. 5-7. The effect of a bumper harvest on the farm product market (L) and individual farmers (R).tex (deflated 74%)
#   adding: tikz_data/code/complete_PacktPublishing_LaTeX-graphics-with-TikZ_11-label.tex.tex (deflated 37%)
#   adding: tikz_data/code/complete_circuitikz_circuitikz_circuitikz-0.7-body.tex (deflated 34%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-3.11.tex.tex (deflated 44%)
#   adding: tikz_data/code/complete_justintroutman_pocketblock_column_down.tex (deflated 79%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-7.4.tex.tex (deflated 46%)
#   adding: tikz_data/code/complete_justintroutman_pocketblock_post_column_down.tex (deflated 80%)
#   adding: tikz_data/code/complete_TomEversdijk_Bomen_en_grafen_oefeningen_oef1-BFS.tex (deflated 51%)
#   adding: tikz_data/code/complete_xgerrmann_Optimization-Flowchart_main.tex (deflated 75%)
#   adding: tikz_data/code/complete_PacktPublishing_LaTeX-graphics-with-TikZ_16-filled-segment.tex.tex (deflated 53%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-10.6.tex.tex (deflated 41%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_SeqDiagramReport.tex.tex (deflated 74%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_genetic_crossover.tex (deflated 56%)
#   adding: tikz_data/code/complete_samcarter_tikzlings_bear.tex.tex (deflated 38%)
#   adding: tikz_data/code/complete_open-optimization_open-optimization-or-book_BinaryTrees.tex (deflated 68%)
#   adding: tikz_data/code/complete_XiangyunHuang_data-analysis-in-action_tikz-pgf.tex (deflated 32%)
#   adding: tikz_data/code/complete_jovyntls_cheatsheets_cs2102-finals-cheatsheet.tex (deflated 57%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_semi-supervised_embedding.tex.tex (deflated 79%)
#   adding: tikz_data/code/complete_facebookresearch_amortized-optimization-tutorial_2-foundations.tex (deflated 51%)
#   adding: tikz_data/code/complete_PetarV-_TikZ_semi-supervised_learning.tex.tex (deflated 84%)
#   adding: tikz_data/code/complete_snowztail_irs-aided-swipt-joint-waveform-active-and-passive-beamforming-design-under-nonlinear-harvester-model_convergence_gp.tex (deflated 45%)
#   adding: tikz_data/code/complete_maloleroy_coto_Intro.tex (deflated 60%)
#   adding: tikz_data/code/complete_drvinceknight_Year_3_game_theory_course_2013-2014-img03.tex (deflated 70%)
#   adding: tikz_data/code/complete_UCL-INMA_LINMA2345_chap4.tex (deflated 82%)
#   adding: tikz_data/code/complete_zhanggyb_nndl_sigmoid.tex (deflated 37%)
#   adding: tikz_data/code/complete_pgf-tikz_pgf_pgfmanual-en-library-rdf.tex.tex (deflated 79%)
#   adding: tikz_data/code/complete_mariosepulvedae_Drawing-with-LaTex_inverter.tex (deflated 67%)
#   adding: tikz_data/code/complete_pgf-tikz_pgf_pgfmanual-en-base-patterns.tex.tex (deflated 48%)
#   adding: tikz_data/code/complete_drvinceknight_Year_3_game_theory_course_video02.tex (deflated 58%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_x-lstm.tex (deflated 43%)
#   adding: tikz_data/code/complete_snowztail_irs-aided-swipt-joint-waveform-active-and-passive-beamforming-design-under-nonlinear-harvester-model_re_irs_10mhz.tex (deflated 51%)
#   adding: tikz_data/code/complete_open-optimization_open-optimization-or-book_SetupStudent.tex (deflated 53%)
#   adding: tikz_data/code/complete_HarisIqbal88_PlotNeuralNet_lenet.tex.tex (deflated 78%)
#   adding: tikz_data/code/complete_alextsagkas_Tikz-Graphics_control_unit.tex (deflated 71%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_rn_object_extraction.tex.tex (deflated 69%)
#   adding: tikz_data/code/complete_PetarV-_TikZ_message_passing_neural_network.tex.tex (deflated 72%)
#   adding: tikz_data/code/complete_drvinceknight_Year_3_game_theory_course_E03-img02.tex (deflated 78%)
#   adding: tikz_data/code/complete_PetarV-_TikZ_multiplex_epidemics-awareness_network.tex.tex (deflated 85%)
#   adding: tikz_data/code/complete_bamos_beamer-snippets_request-response.tex (deflated 61%)
#   adding: tikz_data/code/complete_samcarter_tikzlings_Mandala2.tex.tex (deflated 47%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-10.10.tex.tex (deflated 56%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-10.17.tex.tex (deflated 45%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-2.3.tex.tex (deflated 43%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_git_dataflow.tex (deflated 74%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_maximum_flow_problem.tex (deflated 73%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-3.1.tex.tex (deflated 48%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_LagCompensation.tex.tex (deflated 55%)
#   adding: tikz_data/code/complete_nichtich_tkz-orm_refmodes.tex (deflated 62%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_a5a11_a.tex.tex (deflated 52%)
#   adding: tikz_data/code/complete_PacktPublishing_LaTeX-graphics-with-TikZ_11-intersecting-rings.tex.tex (deflated 58%)
#   adding: tikz_data/code/complete_JaschaParis_LatexVorlageDissertation_cover-front.tex (deflated 46%)
#   adding: tikz_data/code/complete_WilloughbySeago_Uni-Notes_Numerical Recipes notes.tex (deflated 69%)
#   adding: tikz_data/code/complete_HarisIqbal88_PlotNeuralNet_fcn8.tex.tex (deflated 79%)
#   adding: tikz_data/code/complete_pgf-tikz_pgf_pgfmanual-en-tikz-trees.tex.tex (deflated 48%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_multiplex_epidemics-awareness_network.tex.tex (deflated 85%)
#   adding: tikz_data/code/complete_roflmaostc_Fast-Approximate-Energy-Minimization-via-Graph-Cuts_image_label.tex (deflated 79%)
#   adding: tikz_data/code/complete_rusty1s_deep-learning-on-graphs_cnn_aufbau.tex (deflated 68%)
#   adding: tikz_data/code/complete_sabrinaibnath_Tikz_All_Tikz_In_One.tex (deflated 72%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_deep_graph_infomax.tex.tex (deflated 81%)
#   adding: tikz_data/code/complete_bamos_beamer-snippets_overlayed-images.tex (deflated 50%)
#   adding: tikz_data/code/complete_gjoncas_Econ-Diagrams_identification.tex (deflated 60%)
#   adding: tikz_data/code/complete_alextsagkas_Tikz-Graphics_Gravitational-Energy-from-many-Masses.tex.tex (deflated 69%)
#   adding: tikz_data/code/complete_zhanggyb_nndl_initial_gradient.tex (deflated 75%)
#   adding: tikz_data/code/complete_gadepall_matgeo_circ_tang.tex (deflated 57%)
#   adding: tikz_data/code/complete_UweZiegenhagen_TikZ_Tutorial_006-relative-coordinates-no-updates.tex (deflated 38%)
#   adding: tikz_data/code/complete_Qrrbrbirlbel_tikz-extensions_tikz-ext-manual-en-pgf-shapes-heatmark.tex.tex (deflated 52%)
#   adding: tikz_data/code/complete_vEnhance_napkin_categories.tex (deflated 47%)
#   adding: tikz_data/code/complete_MartinThoma_LaTeX-examples_2d-chi-squared-pdf.tex.tex (deflated 50%)
#   adding: tikz_data/code/complete_tomepel_Technical_Book_DL_chapter3.tex (deflated 28%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_block.tex.tex (deflated 64%)
#   adding: tikz_data/code/complete_open-optimization_open-optimization-or-book_systemsofequationsGeometry.tex (deflated 58%)
#   adding: tikz_data/code/complete_gadepall_matgeo_tri_med_isect.tex (deflated 60%)
#   adding: tikz_data/code/complete_pgf-tikz_pgf_pgfmanual-en-dv-main.tex.tex (deflated 64%)
#   adding: tikz_data/code/complete_takidau_animations_gaming-diagrams.tex (deflated 54%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-2.23.tex.tex (deflated 63%)
#   adding: tikz_data/code/complete_Qrrbrbirlbel_TikZ-misc_paths.ortho-hvvh.tex (deflated 56%)
#   adding: tikz_data/code/complete_HuangJiaLian_visualizeNN_visulizeDemo4.tex.tex (deflated 61%)
#   adding: tikz_data/code/complete_gjlaurent_blockdiagram_blockdiagram.tex (deflated 53%)
#   adding: tikz_data/code/complete_drvinceknight_Year_3_game_theory_course_L07-img04.tex (deflated 64%)
#   adding: tikz_data/code/complete_PacktPublishing_LaTeX-graphics-with-TikZ_12-filled-rings-nonzero.tex.tex (deflated 44%)
#   adding: tikz_data/code/complete_MartinScharrer_standalone_test with spaces.tex (deflated 29%)
#   adding: tikz_data/code/complete_f0nzie_artificial_intelligence_diagrams_artificial_intelligence_bender-00.tex (deflated 61%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_reinforcement_learning_greedy_policy.tex (deflated 76%)
#   adding: tikz_data/code/complete_MartinThoma_LaTeX-examples_Zusammenhang.tex.tex (deflated 54%)
#   adding: tikz_data/code/complete_samcarter_tikzlings_Marmot_geek.tex.tex (deflated 57%)
#   adding: tikz_data/code/complete_EEKNTU_Drawing-Persian-chart-using-LaTeX_main.tex (deflated 76%)
#   adding: tikz_data/code/complete_sergiosja_Psnodig_BinarySearch_ibp.tex (deflated 69%)
#   adding: tikz_data/code/complete_jovyntls_cheatsheets_st2131-midterms-cheatsheet.tex (deflated 68%)
#   adding: tikz_data/code/complete_drvinceknight_Year_3_game_theory_course_video12.tex (deflated 46%)
#   adding: tikz_data/code/complete_st--_annotate-equations_annotate-equations.tex (deflated 48%)
#   adding: tikz_data/code/complete_drvinceknight_Year_3_game_theory_course_video18.tex (deflated 53%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_bidirectional_long_short-term_memory.tex.tex (deflated 81%)
#   adding: tikz_data/code/complete_rpguiteras_tikzecon_publicGoodsGarden.tex (deflated 55%)
#   adding: tikz_data/code/complete_pgf-tikz_pgf_pgfmanual-en-base-matrices.tex (deflated 44%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-7.5.tex.tex (deflated 47%)
#   adding: tikz_data/code/complete_pgf-tikz_pgf_pgfmanual-en-library-fadings.tex.tex (deflated 42%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_MatchingTable.tex.tex (deflated 61%)
#   adding: tikz_data/code/complete_lingkangjie_LaTex_Figures_coordinate_systems.tex (deflated 48%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-10.3.tex.tex (deflated 44%)
#   adding: tikz_data/code/complete_FriendlyUser_LatexDiagrams_dblayers.tex.tex (deflated 68%)
#   adding: tikz_data/code/complete_mankoff_sankey_gl_sankey.tex (deflated 74%)
#   adding: tikz_data/code/complete_pgf-tikz_pgf_pgfmanual-en-tikz-plots.tex.tex (deflated 32%)
#   adding: tikz_data/code/complete_pgf-tikz_pgf_pgfmanual-en-tikz-design.tex.tex (deflated 59%)
#   adding: tikz_data/code/complete_UCL-INMA_LINMA2345_0201extForm.tex (deflated 82%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-4.14.tex.tex (deflated 43%)
#   adding: tikz_data/code/complete_BenSt099_Bachelorarbeit-EGraphs_ast.tex (deflated 71%)
#   adding: tikz_data/code/complete_alextsagkas_Tikz-Graphics_Effective_Potential.tex.tex (deflated 54%)
#   adding: tikz_data/code/complete_drvinceknight_Year_3_game_theory_course_L18-img03.tex (deflated 66%)
#   adding: tikz_data/code/complete_MartinThoma_LaTeX-examples_b-tree-2-small.tex.tex (deflated 76%)
#   adding: tikz_data/code/complete_gadepall_geometry_circ_tang_icept.tex (deflated 58%)
#   adding: tikz_data/code/complete_HarisIqbal88_PlotNeuralNet_lenet.tex (deflated 78%)
#   adding: tikz_data/code/complete_PetarV-_TikZ_multiplex_network_underlying_graph.tex.tex (deflated 84%)
#   adding: tikz_data/code/complete_alextsagkas_Tikz-Graphics_datapath.tex (deflated 75%)
#   adding: tikz_data/code/complete_ernestyalumni_mathphysics_EM_dump.tex (deflated 53%)
#   adding: tikz_data/code/complete_jhauschild_tikz_pictures_circ_naive_MPS.tex (deflated 49%)
#   adding: tikz_data/code/complete_mbugert_latex-network-diagram-template_network_diagram.tex.tex (deflated 76%)
#   adding: tikz_data/code/complete_kiiwoom8_Flowchart-Example_main.tex (deflated 39%)
#   adding: tikz_data/code/complete_samcarter_tikzlings_elephant.tex.tex (deflated 41%)
#   adding: tikz_data/code/complete_tgkolda_latex-graphics-book-examples_example-3.9.tex.tex (deflated 56%)

# %%
from google.colab import files
files.download("code.zip")
