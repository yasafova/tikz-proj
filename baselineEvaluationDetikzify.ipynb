# %%
# !pip install --upgrade pip
# !pip install crystalbleu evaluate pillow transformers
# !pip install 'detikzify @ git+https://github.com/potamides/DeTikZify'
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.0.1)
# Requirement already satisfied: crystalbleu in /usr/local/lib/python3.11/dist-packages (0.1)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (10.4.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.21.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.1.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Collecting detikzify@ git+https://github.com/potamides/DeTikZify
#   Cloning https://github.com/potamides/DeTikZify to /tmp/pip-install-kmvzat5y/detikzify_9e41a115be114b93a0212e766cdabf5d
#   Running command git clone --filter=blob:none --quiet https://github.com/potamides/DeTikZify /tmp/pip-install-kmvzat5y/detikzify_9e41a115be114b93a0212e766cdabf5d
#   Resolved https://github.com/potamides/DeTikZify to commit 42aceeb61aa0b4803e828500da25cab69d335ce7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch~=2.5.1 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (2.5.1)
# Requirement already satisfied: torchvision~=0.20.1 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (0.20.1)
# Requirement already satisfied: transformers~=4.48.2 in /usr/local/lib/python3.11/dist-packages (from transformers[accelerate,tokenizers]~=4.48.2->detikzify@ git+https://github.com/potamides/DeTikZify) (4.48.3)
# Requirement already satisfied: datasets~=2.21.0 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (2.21.0)
# Requirement already satisfied: Pillow~=10.4.0 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (10.4.0)
# Requirement already satisfied: requests~=2.32.3 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (2.32.3)
# Requirement already satisfied: numpy~=2.1.1 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (2.1.3)
# Requirement already satisfied: PyMuPDF~=1.24.10 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (1.24.14)
# Requirement already satisfied: pdf2image~=1.17.0 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (1.17.0)
# Requirement already satisfied: pdfCropMargins~=2.1.4 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (2.1.4)
# Requirement already satisfied: gradio~=4.38.1 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (4.38.1)
# Requirement already satisfied: fastapi~=0.112.4 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (0.112.4)
# Requirement already satisfied: pydantic~=2.10.6 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (2.10.6)
# Requirement already satisfied: POT~=0.9.4 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (0.9.5)
# Requirement already satisfied: torchmetrics~=1.4.1 in /usr/local/lib/python3.11/dist-packages (from detikzify@ git+https://github.com/potamides/DeTikZify) (1.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (2.2.2)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (6.0.2)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /usr/local/lib/python3.11/dist-packages (from fastapi~=0.112.4->detikzify@ git+https://github.com/potamides/DeTikZify) (0.38.6)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi~=0.112.4->detikzify@ git+https://github.com/potamides/DeTikZify) (4.13.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (23.2.1)
# Requirement already satisfied: altair<6.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (5.5.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.5.0)
# Requirement already satisfied: gradio-client==1.1.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.1.0)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.28.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (3.1.6)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (3.10.0)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (3.10.16)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.0.20)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.11.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.15.2)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (2.3.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.34.2)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.1.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (11.0.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from pdfCropMargins~=2.1.4->detikzify@ git+https://github.com/potamides/DeTikZify) (0.45.1)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.11/dist-packages (from POT~=0.9.4->detikzify@ git+https://github.com/potamides/DeTikZify) (1.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.10.6->detikzify@ git+https://github.com/potamides/DeTikZify) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.10.6->detikzify@ git+https://github.com/potamides/DeTikZify) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests~=2.32.3->detikzify@ git+https://github.com/potamides/DeTikZify) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests~=2.32.3->detikzify@ git+https://github.com/potamides/DeTikZify) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests~=2.32.3->detikzify@ git+https://github.com/potamides/DeTikZify) (2025.1.31)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch~=2.5.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.3.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics~=1.4.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.14.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.48.2->transformers[accelerate,tokenizers]~=4.48.2->detikzify@ git+https://github.com/potamides/DeTikZify) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.48.2->transformers[accelerate,tokenizers]~=4.48.2->detikzify@ git+https://github.com/potamides/DeTikZify) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers~=4.48.2->transformers[accelerate,tokenizers]~=4.48.2->detikzify@ git+https://github.com/potamides/DeTikZify) (0.5.3)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers[accelerate,tokenizers]~=4.48.2->detikzify@ git+https://github.com/potamides/DeTikZify) (1.5.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->transformers[accelerate,tokenizers]~=4.48.2->detikzify@ git+https://github.com/potamides/DeTikZify) (5.9.5)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6.0,>=5.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6.0,>=5.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.35.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (1.20.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.14.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics~=1.4.1->detikzify@ git+https://github.com/potamides/DeTikZify) (75.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets~=2.21.0->detikzify@ git+https://github.com/potamides/DeTikZify) (2025.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (13.9.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.24.1->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6.0,>=5.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio~=4.38.1->detikzify@ git+https://github.com/potamides/DeTikZify) (0.1.2)

# %%
import torch
from detikzify.model import load
from detikzify.infer import DetikzifyPipeline
from PIL import Image

# %%
model, tokenizer = load(
    "nllg/detikzify-v2-8b",
    device_map="auto",
    torch_dtype=torch.float16,
)

pipeline = DetikzifyPipeline(model, tokenizer)

# 3. Build the inference pipeline
pipeline = DetikzifyPipeline(model, tokenizer)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# processor_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/459 [00:00<?, ?B/s]
# Some kwargs in processor config are unused and will not have any effect: image_seq_len, image_token.
# config.json:   0%|          | 0.00/4.85k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/77.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/7 [00:00<?, ?it/s]
# model-00001-of-00007.safetensors:   0%|          | 0.00/4.91G [00:00<?, ?B/s]
# model-00002-of-00007.safetensors:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# model-00003-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00007.safetensors:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# model-00006-of-00007.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00007-of-00007.safetensors:   0%|          | 0.00/4.32G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/223 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %%
pipeline = DetikzifyPipeline(*load(
    "nllg/detikzify-ds-1.3b",
    device_map="cpu",
    torch_dtype="auto",
))
# Out:
# config.json:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# You are using a model of type detikzify to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# tokenizer_config.json:   0%|          | 0.00/793 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/18.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]

# %%
img = Image.open("/content/test.png").convert("RGB")
fig = pipeline.sample(image=img)
print(fig.code)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-7f290483c5f7> in <cell line: 0>()
#       1 img = Image.open("/content/test.png").convert("RGB")
#       2 fig = pipeline.sample(image=img)
# ----> 3 print(fig.source)
#
# AttributeError: 'TikzDocument' object has no attribute 'source'

# %%
from  datasets  import  load_dataset
ds = load_dataset("nllg/datikz-v3", split="test[:50]")
# Out:
# Downloading readme:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/412M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/442M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/467M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/461M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/381M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/470M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/470M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/462M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/453M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/447M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/460M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/458M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/451M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/441M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/33.5M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/145366 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/542 [00:00<?, ? examples/s]

# %%
from tqdm.auto import tqdm
predictions = []
references  = []
caps = []

for ex in tqdm(ds, desc="Generating TikZ", total=len(ds)):
    img = ex["image"]
    fig = pipeline.sample(image=img)
    predictions.append(fig.code)
    references.append(ex["code"])
    caps.append(ex["caption"])
# Out:
# Generating TikZ:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
print(len(predictions))
# Out:
# 50

# %%
print(predictions[2])
# Out:
# \documentclass[11pt,a4paper]{amsart}
# \usepackage{amsmath,amsfonts,amssymb,amsthm}
# \usepackage{color}
# \usepackage{tikz}
# \usetikzlibrary{3d}
#
# \begin{document}
#
# \begin{tikzpicture}
# 		\pgftransformscale{0.8}
# 		\pgftransformyshift{1cm}
# 		\definecolor{dred}{rgb}{0.8, 0.0, 0.0}
# 		\definecolor{mdred}{rgb}{1.0, 0.4, 0.4}
# 		\definecolor{lred}{rgb}{1.0, 0.8, 0.8}
# 		\definecolor{mlred}{rgb}{1.0, 0.6, 0.6}
#
# 		\begin{scope}[shift={(0,0)}]
# 			\foreach \x in {1,...,4}
# 			{
# 				\draw[thick,black] (\x,-0.2) -- (\x,1.6);
# 				\draw[thick,black] (\x,-0.2+1.4) -- (\x,1.6+1.4);
# 			}
# 			\draw[thick,black] (1,-0.2+0.6) -- (1,1.6+0.6);
# 			\draw[thick,black] (5,-0.2+0.6) -- (5,1.6+0.6);
# 			\foreach \x in {1,2,4}
# 				\draw[fill=white] (\x,-0.2) rectangle +(0.4,1.4);
# 			\foreach \x in {1,2,4}
# 				\draw[fill=white] (\x,-0.2+1.4) rectangle +(0.4,1.4);
# 			\draw[fill=white] (3,-0.2) rectangle +(0.4,1.4);
# 			\draw[fill=white] (3,-0.2+1.4) rectangle +(0.4,1.4);
# 			\draw[thick,black] (3,-0.2) -- (3,1.6);
# 			\draw[thick,black] (3,-0.2+1.4) -- (3,1.6+1.4);
#
# 			\draw[dotted] (0.4,0) -- (4.6,0);
#
# 			\draw (0.7,1.2) node {$\widetilde{\omega_1}$};
# 			\draw (2.7,1.2) node {$\widetilde{\omega_1}$};
# 			\draw (4.5,1.2) node {$\widetilde{\omega_1}$};
# 			\draw (1.6,0.2) node {$\widetilde{\widetilde{w}_2}$};
# 			\draw (3.6,0.2) node {$\widetilde{\widetilde{w}_2}$};
#
# 			\draw[thick,black] (0,-0.2) -- (1,-0.2);
# 			\draw[thick,black] (5,-0.2) -- (6,-0.2);
# 			\draw[thick,black] (0,1.6) -- (1,1.6);
# 			\draw[thick,black] (5,1.6) -- (6,1.6);
#
# 			\draw[thick,black] (0,1.6+0.6) -- (1,1.6+0.6);
# 			\draw[thick,black] (5,1.6+0.6) -- (6,1.6+0.6);
#
# 			\draw[thick,black] (0,-0.2+1.4) -- (1,-0.2+1.4);
# 			\draw[thick,black] (5,-0.2+1.4) -- (6,-0.2+1.4);
# 			\draw[thick,black] (0,1.6+1.4) -- (1,1.6+1.4);
# 			\draw[thick,black] (5,1.6+1.4) -- (6,1.6+1.4);
#
# 			\draw[thick,black] (0,0) to [out=130,in=50] (3,3);
# 			\draw[thick,black] (3,3) to [out=310,in=10] (6,0);
# 		\end{scope}
#
# 	\end{tikzpicture}
#
# \end{document}

# %%
print(references[2])
# Out:
# \documentclass[conference]{IEEEtran}
# \usepackage{amsmath, amssymb, amsfonts}
# \usepackage{xcolor}
# \usepackage{tikz}
#
# \begin{document}
#
# \begin{tikzpicture}
#         \draw[black, thick] (0,-1.5) rectangle (0.2, 1.5);
#         \node[] at (0.1, 1.55) (a1) {};
#         \draw[thick, double] (0.25,0) -- (0.95, 0) node[above, midway] {$\widetilde{w}_1$};
#         \draw[black, thick] (1.0,-1.5) rectangle (1.2, 1.5);
#         \draw[thick] (1.25,0) -- (1.95, -1.5);
#         \node[] at (1.7, 0) {$w_{1}$};
#         \draw[black, thick] (2.0,-2.5) rectangle (2.2, -0.5);
#         \node[] at (2.1, -0.45) (b1) {};
#         \draw[thick, double] (2.25,-1.5) -- (2.95, -1.5) node[above, midway] {$\widetilde{w}_2$};
#         \draw[black, thick] (3.0,-2.5) rectangle (3.2, -0.5);
#         \draw[thick, double] (3.25,-1.5) -- (3.95, -1.5) node[above, midway] {$\widetilde{w}_2$};
#         \draw[black, thick] (4.0,-2.5) rectangle (4.2, -0.5);
#         \node[] at (4.1, -0.45) (b2) {};
#         \draw[thick] (b1) to[out=20,in=160] (b2);
#         \draw[thick, dashed] (4.25, -1.5) -- (4.95, 0);
#         \node[] at (4.5, 0) {$w_{1}$};
#         \draw[black, thick] (5.0,-1.5) rectangle (5.2, 1.5);
#         \draw[thick, double] (5.25,0) -- (5.95, 0) node[above, midway] {$\widetilde{w}_1$};
#         \draw[black, thick] (6.0,-1.5) rectangle (6.2, 1.5);
#         \node[] at (6.1, 1.55) (a2) {};
#         \draw[thick] (a1) to[out=20,in=160] (a2);
#     \end{tikzpicture}
#
# \end{document}

# %%
# !pip install crystalbleu evaluate
# Out:
# Requirement already satisfied: crystalbleu in /usr/local/lib/python3.11/dist-packages (0.1)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.3)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.21.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.1.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.11.15)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)

# %%
import evaluate

references_new = [[r] for r in references]

# 3) Load and compute BLEU
bleu = evaluate.load("bleu")
bleu_results = bleu.compute(
    predictions=predictions,
    references=references_new,
)

print(f"BLEU score: {bleu_results['bleu']:.4f}")
# Out:
# BLEU score: 0.0982

# %%
# !pip install -q crystalbleu

# %%
# 2) Import
from crystalbleu import corpus_bleu

# 3) Prepare your references exactly the same way you did for BLEU:
#    a list of 1-element lists of strings
references_cb = [[r] for r in references]

# 4) Call CrystalBLEU
#    - `ignoring={}` means “don’t drop any trivial tokens”
#    - `n=4` uses up to 4-gram overlap (the default)
cb_score = corpus_bleu(
    references_cb,   # List[List[str]]
    predictions,     # List[str]
    ignoring={},     # or supply a dict of common tokens to ignore
)

print(f"CrystalBLEU: {cb_score:.4f}")
# Out:
# CrystalBLEU: 0.0691

# %%
# !sudo apt-get update
# !sudo apt-get install -y texlive-latex-base texlive-latex-extra texlive-pictures poppler-utils!
# !pip install pdf2image
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,607 kB]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,848 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,244 kB]
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,154 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [47.1 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,118 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,543 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,844 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,696 kB]
# Fetched 26.4 MB in 4s (6,917 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package poppler-utils!
# E: Couldn't find any package by glob 'poppler-utils!'
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.11/dist-packages (1.17.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from pdf2image) (10.4.0)

# %%
import os
import subprocess
import tempfile
from pdf2image import convert_from_path
from PIL import Image

def compile_tikz_to_image(tikz_code: str, dpi: int = 300) -> Image.Image:
    """
    Compile a TikZ code snippet or full .tex document to a PIL Image.

    If `tikz_code` starts with a `\documentclass` declaration, it's treated as a
    complete LaTeX document. Otherwise, it is wrapped in a minimal standalone TikZ
    document. The function runs `pdflatex` to generate a PDF and converts the first
    page to a PNG image using `pdf2image`.
    """
    # Determine if this is a full document or snippet
    if tikz_code.lstrip().startswith(r"\documentclass"):
        full_tex = tikz_code
    else:
        full_tex = (
            "\\documentclass[tikz,border=2pt]{standalone}\n"
            "\\usepackage{tikz}\n"
            "\\begin{document}\n"
            f"{tikz_code}\n"
            "\\end{document}"
        )
    try:
        with tempfile.TemporaryDirectory() as tmpdir:
            tex_path = os.path.join(tmpdir, "compiled.tex")
            with open(tex_path, "w") as f:
                f.write(full_tex)

            # Compile to PDF silently
            subprocess.run(
                ["pdflatex", "-halt-on-error", tex_path],
                cwd=tmpdir,
                stdout=subprocess.DEVNULL,
                stderr=subprocess.DEVNULL,
                check=True
            )

            # Convert PDF -> PIL Image
            pdf_path = os.path.join(tmpdir, "compiled.pdf")
            pages = convert_from_path(pdf_path, dpi=dpi)
            return pages[0]
    except subprocess.CalledProcessError as e:
        print(f"[compile warning] pdflatex failed: {e}")
    except Exception as e:
        print(f"[compile warning] conversion error: {e}")

    # On failure, return None
    return None

# %%
compiled_figs = []
for code in tqdm(predictions, desc="Compiling TikZ to images"):
    img = compile_tikz_to_image(code, dpi=200)
    if img is not None:
        compiled_figs.append(img)
    else:
        # append a placeholder (e.g., blank white)
        compiled_figs.append(Image.new("RGB", (256, 256), "white"))
# Out:
# Compiling TikZ to images:   0%|          | 0/50 [00:00<?, ?it/s]
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'
# [compile warning] conversion error: [Errno 2] No such file or directory: 'pdflatex'

# %%
# !pip install -q transformers

# %%
from transformers import CLIPProcessor, CLIPModel
import torch

# 3) Load the processor & model
device = "cuda" if torch.cuda.is_available() else "cpu"
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
model     = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)

# 4) Prepare your data
#    ‘texts’ is a list of your input captions (strings)
#    ‘images’ is a list of PIL.Image objects from `fig.rasterize()`
#    Make sure len(texts) == len(images)
inputs = processor(
    text=caps,
    images=compiled_figs,
    return_tensors="pt",
    padding=True,
    truncation=True,
    max_length=processor.tokenizer.model_max_length,
).to(device)

# 5) Forward pass & extract embeddings
with torch.no_grad():
    outputs     = model(**inputs)
    img_embeds  = outputs.image_embeds  # shape (batch, dim)
    text_embeds = outputs.text_embeds   # shape (batch, dim)

# 6) Normalize & compute cosine similarities
img_norm  = img_embeds  / img_embeds.norm(p=2, dim=1, keepdim=True)
text_norm = text_embeds / text_embeds.norm(p=2, dim=1, keepdim=True)

# similarity per example
sims = (img_norm * text_norm).sum(dim=1)  # tensor of shape (batch,)

# 7) Report the mean (i.e. the “CLIPScore”)
mean_sim = sims.mean().item()
print(f"Mean CLIPScore: {mean_sim:.4f}")
# Out:
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Mean CLIPScore: 0.2203
