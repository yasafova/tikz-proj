# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)

# %%
import json
import os

PROCESSED_IDS_FILE = "processed_papers.json"

def load_processed_ids():
    """Load processed paper IDs from JSON file"""
    if os.path.exists(PROCESSED_IDS_FILE):
        with open(PROCESSED_IDS_FILE, 'r') as f:
            return set(json.load(f))
    return set()

def save_processed_ids(processed_ids):
    """Save processed paper IDs to JSON file"""
    with open(PROCESSED_IDS_FILE, 'w') as f:
        json.dump(list(processed_ids), f)

# %%
# !pip install regex
# Out:
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)

# %%
import os
import regex
import csv
import time
import requests
import tarfile
import logging
from bs4 import BeautifulSoup

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

ARXIV_API = "http://export.arxiv.org/api/query"

class ArxivTikzProcessor:
    def __init__(self):
        self.output_dir = "tikz_output"
        os.makedirs(self.output_dir, exist_ok=True)

    def search_arxiv(self, query, start=0, max_results=20000):
        """Search arXiv for papers matching the query."""
        params = {
            "search_query": query,
            "start": start,
            "max_results": max_results,
            "sortBy": "submittedDate",
            "sortOrder": "descending"
        }
        response = requests.get(ARXIV_API, params=params)
        soup = BeautifulSoup(response.content, 'xml')
        return [entry.id.text.split('/')[-1] for entry in soup.find_all('entry')]

    def download_source(self, paper_id):
        """Download the source files of a paper from arXiv."""
        source_url = f"https://arxiv.org/e-print/{paper_id}"
        retries = 3

        for attempt in range(retries):
            try:
                response = requests.get(source_url)
                if response.status_code == 200:
                    output_dir = "sources"
                    os.makedirs(output_dir, exist_ok=True)
                    tar_path = os.path.join(output_dir, f"{paper_id}.tar.gz")
                    with open(tar_path, 'wb') as f:
                        f.write(response.content)
                    return tar_path
            except Exception as e:
                logger.error(f"Error downloading {paper_id}: {e}")
            time.sleep(5)

        return None

    def extract_tikz_metadata(self, content):
        """Extract LaTeX metadata from file content."""
        metadata = {
            'packages': regex.findall(r'\\usepackage{([^}]+)}', content),
            'libraries': regex.findall(r'\\usetikzlibrary{([^}]+)}', content),
            'captions': regex.findall(r'\\caption{(.*?)}', content, regex.DOTALL)
        }
        return metadata

    def extract_tikz_code(self, content):
      """Extract outermost TikZ code blocks and convert nested ones to scopes."""
      # Match outermost tikzpicture environments
      tikz_pattern = regex.compile(
          r'(\\begin{tikzpicture}((?:(?!\\begin{tikzpicture}|\\end{tikzpicture}).|(?0))*)\\end{tikzpicture})',
          flags=regex.DOTALL | regex.MULTILINE
      )

      blocks = []
      for match in tikz_pattern.finditer(content):
          full_code = match.group(0)

          # Convert nested tikzpictures to scopes using recursive substitution
          converted_code = regex.sub(
              r'\\begin{tikzpicture}((?:(?!\\begin{tikzpicture}).|(?0))*)\\end{tikzpicture}',
              r'\\begin{scope}\1\\end{scope}',
              full_code,
              flags=regex.DOTALL
          )

          blocks.append(converted_code)

      return blocks

    def create_compilable_tex(self, tikz_code, packages, libraries, output_path):
      """Create compilable LaTeX with proper scope handling."""
      # Ensure essential packages and libraries
      essential_packages = {'amsmath', 'amssymb', 'tikz', 'xcolor'}
      essential_libraries = {'arrows.meta', 'calc', 'positioning', 'scopes'}

      all_packages = list(set(packages) | essential_packages)
      all_libraries = list(set(libraries) | essential_libraries)

      # Build document with proper nesting support
      doc_header = (
          "\\documentclass[crop,tikz]{standalone}\n"
          + "\n".join([f"\\usepackage{{{pkg}}}" for pkg in all_packages])
          + f"\n\\usetikzlibrary{{{','.join(all_libraries)}}}"
          + "\n\\begin{document}\n"
      )

      # Wrap in scaling environment for better compilation
      full_code = (
          "\\begin{tikzpicture}[every scope/.style={scale=1}]\n"
          + tikz_code
          + "\n\\end{tikzpicture}"
      )

      with open(output_path, 'w', encoding='utf-8') as f:
          f.write(doc_header + full_code + "\n\\end{document}")

    def process_tex_file(self, content, paper_id, csv_writer):
        """Process a single TeX file and its TikZ content."""
        metadata = self.extract_tikz_metadata(content)
        tikz_blocks = self.extract_tikz_code(content)

        for idx, block in enumerate(tikz_blocks):
            try:
                caption = metadata['captions'][idx] if idx < len(metadata['captions']) else ""
                # Clean caption
                caption = regex.sub(r'\\[a-zA-Z]+', '', caption).strip()

                # Generate filename
                tex_filename = f"{paper_id}_figure_{idx+1}.tex"
                tex_path = os.path.join(self.output_dir, tex_filename)

                # Create compilable document
                self.create_compilable_tex(
                    block,
                    metadata['packages'],
                    metadata['libraries'],
                    tex_path
                )

                # Write to CSV
                csv_writer.writerow([
                    paper_id,
                    tex_path,
                    caption,
                    ','.join(metadata['packages']),
                    ','.join(metadata['libraries'])
                ])

            except Exception as e:
                logger.error(f"Error processing block {idx} in {paper_id}: {str(e)}")

        return len(tikz_blocks)

    def process_paper(self, paper_id, csv_writer):
        """Process a single arXiv paper."""
        try:
            tar_path = self.download_source(paper_id)
            if not tar_path:
                return 0

            total_figures = 0
            with tarfile.open(tar_path, 'r:gz') as tar:
                tex_files = [m for m in tar.getmembers() if m.name.endswith('.tex')]

                for tex_file in tex_files:
                    content = tar.extractfile(tex_file).read().decode('utf-8')
                    total_figures += self.process_tex_file(content, paper_id, csv_writer)

            return total_figures

        except Exception as e:
            logger.error(f"Error processing {paper_id}: {str(e)}")
            return 0

if __name__ == "__main__":
    processor = ArxivTikzProcessor()

    # Load previously processed papers
    processed_ids = load_processed_ids()
    new_processed_ids = set()

    with open('tikz_collection.csv', 'a', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        # Write header if new file
        if os.stat('tikz_collection.csv').st_size == 0:
            writer.writerow(['source_id', 'code_path', 'caption', 'used_packages', 'used_libraries'])

        # Example search query
        query = "all:(tikz OR 'LaTeX diagram' OR 'LaTeX figure' OR pgfplots OR 'code illustration')"
        total_figures = 0
        start = 0
        BATCH_SIZE = 2000  # Max allowed by arXiv API
        TARGET_FIGURES = 10

        while total_figures < TARGET_FIGURES:
            paper_ids = processor.search_arxiv(query, start=start, max_results=BATCH_SIZE)
            if not paper_ids:
                break

                    # Process each paper in batch
            for pid in paper_ids:
                if pid in processed_ids:
                    print(f"Skipping already processed paper: {pid}")
                    continue

                figures = processor.process_paper(pid, writer)
                total_figures += figures
                new_processed_ids.add(pid)

                # Early exit if target reached
                if total_figures >= TARGET_FIGURES:
                    break

                # Rate limiting
                time.sleep(1.5)  # Reduced from 3s for faster processing

            # Update pagination
            start += len(paper_ids)
            save_processed_ids(processed_ids.union(new_processed_ids))  # Frequent saves

# %%
# !zip -r arvixv2.zip tikz_output
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: tikz_output/2102.00276v1_figure_617.tex (deflated 65%)
#   adding: tikz_output/1512.08296v3_figure_14.tex (deflated 52%)
#   adding: tikz_output/2102.00276v1_figure_13.tex (deflated 45%)
#   adding: tikz_output/2106.01855v1_figure_41.tex (deflated 52%)
#   adding: tikz_output/2007.15675v3_figure_52.tex (deflated 67%)
#   adding: tikz_output/1512.08296v3_figure_107.tex (deflated 50%)
#   adding: tikz_output/2106.14211v4_figure_36.tex (deflated 66%)
#   adding: tikz_output/1709.06005v2_figure_3.tex (deflated 56%)
#   adding: tikz_output/1608.04259v2_figure_53.tex (deflated 57%)
#   adding: tikz_output/1911.04630v3_figure_41.tex (deflated 52%)
#   adding: tikz_output/1709.06005v2_figure_149.tex (deflated 54%)
#   adding: tikz_output/1702.08108v3_figure_165.tex (deflated 52%)
#   adding: tikz_output/1308.5150v2_figure_150.tex (deflated 72%)
#   adding: tikz_output/2102.00276v1_figure_174.tex (deflated 63%)
#   adding: tikz_output/1306.0074v4_figure_28.tex (deflated 56%)
#   adding: tikz_output/2210.09583v1_figure_17.tex (deflated 54%)
#   adding: tikz_output/2104.07747v1_figure_73.tex (deflated 54%)
#   adding: tikz_output/1308.5150v2_figure_71.tex (deflated 81%)
#   adding: tikz_output/1911.04630v3_figure_100.tex (deflated 56%)
#   adding: tikz_output/2104.07747v1_figure_90.tex (deflated 64%)
#   adding: tikz_output/1512.08296v3_figure_221.tex (deflated 61%)
#   adding: tikz_output/1802.00689v1_figure_46.tex (deflated 58%)
#   adding: tikz_output/1709.02813v1_figure_38.tex (deflated 61%)
#   adding: tikz_output/2110.04212v2_figure_7.tex (deflated 55%)
#   adding: tikz_output/1504.07671v2_figure_88.tex (deflated 59%)
#   adding: tikz_output/1709.06005v2_figure_20.tex (deflated 57%)
#   adding: tikz_output/2203.15964v1_figure_122.tex (deflated 69%)
#   adding: tikz_output/1911.04630v3_figure_51.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_167.tex (deflated 61%)
#   adding: tikz_output/2007.15675v3_figure_79.tex (deflated 53%)
#   adding: tikz_output/0810.4503v1_figure_2.tex (deflated 62%)
#   adding: tikz_output/1911.04630v3_figure_94.tex (deflated 54%)
#   adding: tikz_output/2305.19686v2_figure_33.tex (deflated 58%)
#   adding: tikz_output/2106.14211v4_figure_16.tex (deflated 63%)
#   adding: tikz_output/1608.04259v2_figure_43.tex (deflated 56%)
#   adding: tikz_output/1510.05330v2_figure_1.tex (deflated 46%)
#   adding: tikz_output/2203.15964v1_figure_34.tex (deflated 60%)
#   adding: tikz_output/2008.05577v2_figure_45.tex (deflated 64%)
#   adding: tikz_output/1005.4559v7_figure_22.tex (deflated 62%)
#   adding: tikz_output/2102.01693v2_figure_49.tex (deflated 80%)
#   adding: tikz_output/2102.00276v1_figure_158.tex (deflated 56%)
#   adding: tikz_output/1702.08108v3_figure_96.tex (deflated 54%)
#   adding: tikz_output/1504.07671v2_figure_104.tex (deflated 54%)
#   adding: tikz_output/2102.00276v1_figure_227.tex (deflated 49%)
#   adding: tikz_output/1903.11611v1_figure_8.tex (deflated 52%)
#   adding: tikz_output/2310.16576v2_figure_17.tex (deflated 73%)
#   adding: tikz_output/1709.06005v2_figure_164.tex (deflated 57%)
#   adding: tikz_output/2305.05971v1_figure_2.tex (deflated 62%)
#   adding: tikz_output/2207.00580v1_figure_35.tex (deflated 64%)
#   adding: tikz_output/2305.19686v2_figure_35.tex (deflated 76%)
#   adding: tikz_output/2209.12947v2_figure_29.tex (deflated 59%)
#   adding: tikz_output/2102.00276v1_figure_280.tex (deflated 54%)
#   adding: tikz_output/2102.00276v1_figure_542.tex (deflated 70%)
#   adding: tikz_output/2106.14211v4_figure_18.tex (deflated 63%)
#   adding: tikz_output/2203.14153v2_figure_18.tex (deflated 52%)
#   adding: tikz_output/2104.07747v1_figure_50.tex (deflated 58%)
#   adding: tikz_output/1510.01556v2_figure_35.tex (deflated 64%)
#   adding: tikz_output/1005.4559v7_figure_19.tex (deflated 61%)
#   adding: tikz_output/2102.00276v1_figure_92.tex (deflated 51%)
#   adding: tikz_output/1510.01556v2_figure_8.tex (deflated 61%)
#   adding: tikz_output/2207.02243v1_figure_61.tex (deflated 59%)
#   adding: tikz_output/2104.07747v1_figure_12.tex (deflated 50%)
#   adding: tikz_output/2008.05577v2_figure_36.tex (deflated 66%)
#   adding: tikz_output/1212.6076v1_figure_347.tex (deflated 56%)
#   adding: tikz_output/1709.02813v1_figure_37.tex (deflated 61%)
#   adding: tikz_output/1709.06005v2_figure_120.tex (deflated 56%)
#   adding: tikz_output/1308.5150v2_figure_52.tex (deflated 71%)
#   adding: tikz_output/1812.02832v2_figure_16.tex (deflated 60%)
#   adding: tikz_output/1212.6076v1_figure_121.tex (deflated 72%)
#   adding: tikz_output/1212.6076v1_figure_476.tex (deflated 69%)
#   adding: tikz_output/2207.02243v1_figure_113.tex (deflated 56%)
#   adding: tikz_output/2008.05577v2_figure_78.tex (deflated 71%)
#   adding: tikz_output/1504.07671v2_figure_79.tex (deflated 55%)
#   adding: tikz_output/0905.1444v2_figure_6.tex (deflated 60%)
#   adding: tikz_output/1306.0074v4_figure_18.tex (deflated 52%)
#   adding: tikz_output/2203.15964v1_figure_24.tex (deflated 60%)
#   adding: tikz_output/1212.6076v1_figure_208.tex (deflated 71%)
#   adding: tikz_output/2110.04212v2_figure_19.tex (deflated 54%)
#   adding: tikz_output/2102.00276v1_figure_144.tex (deflated 48%)
#   adding: tikz_output/2207.02243v1_figure_11.tex (deflated 63%)
#   adding: tikz_output/1003.5730v1_figure_7.tex (deflated 56%)
#   adding: tikz_output/2110.04212v2_figure_5.tex (deflated 54%)
#   adding: tikz_output/2106.01855v1_figure_24.tex (deflated 57%)
#   adding: tikz_output/2303.11845v2_figure_55.tex (deflated 61%)
#   adding: tikz_output/1212.6076v1_figure_180.tex (deflated 54%)
#   adding: tikz_output/2102.00276v1_figure_76.tex (deflated 59%)
#   adding: tikz_output/2008.05577v2_figure_106.tex (deflated 64%)
#   adding: tikz_output/1308.5150v2_figure_153.tex (deflated 78%)
#   adding: tikz_output/1605.00227v1_figure_21.tex (deflated 70%)
#   adding: tikz_output/2102.00276v1_figure_625.tex (deflated 45%)
#   adding: tikz_output/1811.02515v1_figure_23.tex (deflated 79%)
#   adding: tikz_output/1709.06005v2_figure_100.tex (deflated 56%)
#   adding: tikz_output/2104.07747v1_figure_155.tex (deflated 51%)
#   adding: tikz_output/1608.04259v2_figure_4.tex (deflated 47%)
#   adding: tikz_output/2102.00276v1_figure_26.tex (deflated 47%)
#   adding: tikz_output/2104.07747v1_figure_168.tex (deflated 60%)
#   adding: tikz_output/2403.09580v2_figure_3.tex (deflated 63%)
#   adding: tikz_output/1212.6076v1_figure_285.tex (deflated 77%)
#   adding: tikz_output/1910.03770v1_figure_8.tex (deflated 66%)
#   adding: tikz_output/2208.14566v1_figure_4.tex (deflated 62%)
#   adding: tikz_output/2207.02243v1_figure_25.tex (deflated 60%)
#   adding: tikz_output/1602.04696v2_figure_2.tex (deflated 61%)
#   adding: tikz_output/2311.17692v2_figure_65.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_529.tex (deflated 62%)
#   adding: tikz_output/1504.07671v2_figure_103.tex (deflated 66%)
#   adding: tikz_output/2207.00580v1_figure_3.tex (deflated 48%)
#   adding: tikz_output/1410.2837v2_figure_5.tex (deflated 62%)
#   adding: tikz_output/1709.02813v1_figure_57.tex (deflated 57%)
#   adding: tikz_output/1410.2837v2_figure_17.tex (deflated 66%)
#   adding: tikz_output/2211.16438v1_figure_2.tex (deflated 67%)
#   adding: tikz_output/2404.18921v2_figure_8.tex (deflated 57%)
#   adding: tikz_output/2303.11845v2_figure_22.tex (deflated 68%)
#   adding: tikz_output/1212.6076v1_figure_50.tex (deflated 56%)
#   adding: tikz_output/1905.09890v2_figure_29.tex (deflated 61%)
#   adding: tikz_output/1608.04259v2_figure_39.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_546.tex (deflated 63%)
#   adding: tikz_output/1702.08108v3_figure_60.tex (deflated 55%)
#   adding: tikz_output/2207.02243v1_figure_67.tex (deflated 53%)
#   adding: tikz_output/1811.01125v1_figure_10.tex (deflated 75%)
#   adding: tikz_output/2102.00276v1_figure_606.tex (deflated 65%)
#   adding: tikz_output/2310.16576v2_figure_7.tex (deflated 63%)
#   adding: tikz_output/2311.17692v2_figure_63.tex (deflated 56%)
#   adding: tikz_output/2501.00614v9_figure_19.tex (deflated 61%)
#   adding: tikz_output/1709.06005v2_figure_52.tex (deflated 56%)
#   adding: tikz_output/2203.15330v1_figure_44.tex (deflated 59%)
#   adding: tikz_output/2102.00276v1_figure_314.tex (deflated 63%)
#   adding: tikz_output/2501.00614v9_figure_27.tex (deflated 59%)
#   adding: tikz_output/2102.00276v1_figure_190.tex (deflated 42%)
#   adding: tikz_output/2102.00276v1_figure_73.tex (deflated 60%)
#   adding: tikz_output/1812.02832v2_figure_37.tex (deflated 71%)
#   adding: tikz_output/1212.6076v1_figure_299.tex (deflated 55%)
#   adding: tikz_output/1212.6076v1_figure_306.tex (deflated 55%)
#   adding: tikz_output/2207.02243v1_figure_14.tex (deflated 65%)
#   adding: tikz_output/2102.00276v1_figure_343.tex (deflated 64%)
#   adding: tikz_output/1410.4761v3_figure_8.tex (deflated 56%)
#   adding: tikz_output/1702.08108v3_figure_13.tex (deflated 52%)
#   adding: tikz_output/2102.00276v1_figure_107.tex (deflated 50%)
#   adding: tikz_output/1702.08108v3_figure_36.tex (deflated 52%)
#   adding: tikz_output/1911.04630v3_figure_93.tex (deflated 53%)
#   adding: tikz_output/2104.07747v1_figure_149.tex (deflated 66%)
#   adding: tikz_output/1702.08108v3_figure_297.tex (deflated 58%)
#   adding: tikz_output/1308.5150v2_figure_100.tex (deflated 77%)
#   adding: tikz_output/2102.00276v1_figure_445.tex (deflated 56%)
#   adding: tikz_output/0905.1444v2_figure_4.tex (deflated 56%)
#   adding: tikz_output/1410.4761v3_figure_16.tex (deflated 57%)
#   adding: tikz_output/1308.5150v2_figure_67.tex (deflated 83%)
#   adding: tikz_output/2404.18921v2_figure_19.tex (deflated 75%)
#   adding: tikz_output/1410.2837v2_figure_13.tex (deflated 68%)
#   adding: tikz_output/2008.05577v2_figure_67.tex (deflated 65%)
#   adding: tikz_output/1212.6076v1_figure_276.tex (deflated 55%)
#   adding: tikz_output/2203.15330v1_figure_4.tex (deflated 74%)
#   adding: tikz_output/1709.02813v1_figure_2.tex (deflated 69%)
#   adding: tikz_output/2212.08509v1_figure_7.tex (deflated 55%)
#   adding: tikz_output/1512.08296v3_figure_165.tex (deflated 53%)
#   adding: tikz_output/2102.00276v1_figure_552.tex (deflated 62%)
#   adding: tikz_output/2007.15675v3_figure_108.tex (deflated 60%)
#   adding: tikz_output/1903.11611v1_figure_26.tex (deflated 63%)
#   adding: tikz_output/1512.08296v3_figure_60.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_444.tex (deflated 57%)
#   adding: tikz_output/1212.6076v1_figure_179.tex (deflated 66%)
#   adding: tikz_output/2008.05577v2_figure_76.tex (deflated 73%)
#   adding: tikz_output/2102.00276v1_figure_21.tex (deflated 45%)
#   adding: tikz_output/2102.00276v1_figure_333.tex (deflated 64%)
#   adding: tikz_output/1212.6076v1_figure_376.tex (deflated 51%)
#   adding: tikz_output/2210.09583v1_figure_55.tex (deflated 54%)
#   adding: tikz_output/1911.04630v3_figure_71.tex (deflated 59%)
#   adding: tikz_output/2102.00276v1_figure_106.tex (deflated 50%)
#   adding: tikz_output/1003.5730v1_figure_21.tex (deflated 49%)
#   adding: tikz_output/2210.09583v1_figure_57.tex (deflated 55%)
#   adding: tikz_output/2207.00596v1_figure_13.tex (deflated 54%)
#   adding: tikz_output/2303.11845v2_figure_67.tex (deflated 78%)
#   adding: tikz_output/1509.00204v1_figure_4.tex (deflated 79%)
#   adding: tikz_output/1509.02804v2_figure_5.tex (deflated 90%)
#   adding: tikz_output/1512.08296v3_figure_250.tex (deflated 53%)
#   adding: tikz_output/1212.6076v1_figure_88.tex (deflated 69%)
#   adding: tikz_output/1702.08108v3_figure_253.tex (deflated 66%)
#   adding: tikz_output/2102.00276v1_figure_492.tex (deflated 63%)
#   adding: tikz_output/2203.15330v1_figure_36.tex (deflated 59%)
#   adding: tikz_output/2207.00596v1_figure_7.tex (deflated 57%)
#   adding: tikz_output/2106.10265v2_figure_54.tex (deflated 76%)
#   adding: tikz_output/1512.08296v3_figure_138.tex (deflated 57%)
#   adding: tikz_output/2106.01855v1_figure_2.tex (deflated 58%)
#   adding: tikz_output/1512.08296v3_figure_35.tex (deflated 48%)
#   adding: tikz_output/1512.08296v3_figure_178.tex (deflated 56%)
#   adding: tikz_output/1212.6076v1_figure_238.tex (deflated 75%)
#   adding: tikz_output/1804.04408v3_figure_5.tex (deflated 55%)
#   adding: tikz_output/1702.08108v3_figure_71.tex (deflated 53%)
#   adding: tikz_output/2303.06211v2_figure_27.tex (deflated 61%)
#   adding: tikz_output/1709.06005v2_figure_17.tex (deflated 57%)
#   adding: tikz_output/1709.06005v2_figure_86.tex (deflated 56%)
#   adding: tikz_output/2207.02243v1_figure_60.tex (deflated 58%)
#   adding: tikz_output/1903.11611v1_figure_2.tex (deflated 55%)
#   adding: tikz_output/1005.4559v7_figure_27.tex (deflated 70%)
#   adding: tikz_output/2504.02023v1_figure_17.tex (deflated 65%)
#   adding: tikz_output/1609.07289v2_figure_8.tex (deflated 51%)
#   adding: tikz_output/2207.02243v1_figure_18.tex (deflated 63%)
#   adding: tikz_output/1308.5150v2_figure_122.tex (deflated 82%)
#   adding: tikz_output/2102.00276v1_figure_511.tex (deflated 47%)
#   adding: tikz_output/1512.08296v3_figure_258.tex (deflated 54%)
#   adding: tikz_output/2210.09583v1_figure_27.tex (deflated 55%)
#   adding: tikz_output/1702.08108v3_figure_239.tex (deflated 56%)
#   adding: tikz_output/1512.08296v3_figure_101.tex (deflated 53%)
#   adding: tikz_output/1308.5150v2_figure_141.tex (deflated 70%)
#   adding: tikz_output/0902.3527v3_figure_4.tex (deflated 68%)
#   adding: tikz_output/1504.07671v2_figure_7.tex (deflated 62%)
#   adding: tikz_output/1709.06005v2_figure_56.tex (deflated 52%)
#   adding: tikz_output/1911.04630v3_figure_113.tex (deflated 54%)
#   adding: tikz_output/2402.00635v1_figure_13.tex (deflated 62%)
#   adding: tikz_output/1510.01556v2_figure_34.tex (deflated 62%)
#   adding: tikz_output/1512.08296v3_figure_133.tex (deflated 54%)
#   adding: tikz_output/2207.00580v1_figure_5.tex (deflated 61%)
#   adding: tikz_output/1212.6076v1_figure_66.tex (deflated 65%)
#   adding: tikz_output/1512.08296v3_figure_181.tex (deflated 65%)
#   adding: tikz_output/1605.00227v1_figure_16.tex (deflated 61%)
#   adding: tikz_output/1208.3163v2_figure_4.tex (deflated 62%)
#   adding: tikz_output/1709.06005v2_figure_96.tex (deflated 55%)
#   adding: tikz_output/2203.10022v3_figure_5.tex (deflated 78%)
#   adding: tikz_output/1102.3549v1_figure_1.tex (deflated 59%)
#   adding: tikz_output/1504.07671v2_figure_102.tex (deflated 66%)
#   adding: tikz_output/1711.05931v1_figure_11.tex (deflated 67%)
#   adding: tikz_output/1602.04696v2_figure_1.tex (deflated 55%)
#   adding: tikz_output/1007.0725v3_figure_9.tex (deflated 68%)
#   adding: tikz_output/1308.5150v2_figure_185.tex (deflated 74%)
#   adding: tikz_output/1212.6076v1_figure_322.tex (deflated 64%)
#   adding: tikz_output/2102.00276v1_figure_237.tex (deflated 40%)
#   adding: tikz_output/2104.07747v1_figure_112.tex (deflated 52%)
#   adding: tikz_output/1510.01556v2_figure_43.tex (deflated 61%)
#   adding: tikz_output/2106.10265v2_figure_24.tex (deflated 82%)
#   adding: tikz_output/1802.00689v1_figure_39.tex (deflated 59%)
#   adding: tikz_output/2104.07747v1_figure_2.tex (deflated 58%)
#   adding: tikz_output/1709.02813v1_figure_39.tex (deflated 75%)
#   adding: tikz_output/1004.3599v2_figure_10.tex (deflated 49%)
#   adding: tikz_output/1212.6076v1_figure_103.tex (deflated 74%)
#   adding: tikz_output/2210.09583v1_figure_86.tex (deflated 54%)
#   adding: tikz_output/1005.4559v7_figure_18.tex (deflated 58%)
#   adding: tikz_output/1504.07671v2_figure_18.tex (deflated 64%)
#   adding: tikz_output/2102.00276v1_figure_272.tex (deflated 50%)
#   adding: tikz_output/1702.08108v3_figure_40.tex (deflated 60%)
#   adding: tikz_output/2102.00276v1_figure_323.tex (deflated 57%)
#   adding: tikz_output/1702.08108v3_figure_179.tex (deflated 53%)
#   adding: tikz_output/2008.05577v2_figure_39.tex (deflated 66%)
#   adding: tikz_output/2303.06211v2_figure_12.tex (deflated 78%)
#   adding: tikz_output/1510.01556v2_figure_40.tex (deflated 61%)
#   adding: tikz_output/2104.07747v1_figure_227.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_385.tex (deflated 70%)
#   adding: tikz_output/2008.05577v2_figure_100.tex (deflated 58%)
#   adding: tikz_output/2102.00276v1_figure_354.tex (deflated 54%)
#   adding: tikz_output/2203.10022v3_figure_23.tex (deflated 75%)
#   adding: tikz_output/2410.05120v1_figure_1.tex (deflated 56%)
#   adding: tikz_output/1709.02813v1_figure_87.tex (deflated 72%)
#   adding: tikz_output/2008.05577v2_figure_96.tex (deflated 60%)
#   adding: tikz_output/1608.04259v2_figure_44.tex (deflated 57%)
#   adding: tikz_output/1702.08108v3_figure_182.tex (deflated 54%)
#   adding: tikz_output/2303.11845v2_figure_27.tex (deflated 68%)
#   adding: tikz_output/1506.03754v3_figure_2.tex (deflated 67%)
#   adding: tikz_output/1903.11611v1_figure_7.tex (deflated 57%)
#   adding: tikz_output/1605.00227v1_figure_9.tex (deflated 60%)
#   adding: tikz_output/2207.00596v1_figure_4.tex (deflated 65%)
#   adding: tikz_output/2106.14211v4_figure_13.tex (deflated 63%)
#   adding: tikz_output/1212.6076v1_figure_10.tex (deflated 59%)
#   adding: tikz_output/1702.08108v3_figure_303.tex (deflated 53%)
#   adding: tikz_output/1306.0074v4_figure_4.tex (deflated 53%)
#   adding: tikz_output/1109.4090v1_figure_2.tex (deflated 62%)
#   adding: tikz_output/1802.00689v1_figure_15.tex (deflated 61%)
#   adding: tikz_output/1508.05445v1_figure_9.tex (deflated 56%)
#   adding: tikz_output/2102.00276v1_figure_2.tex (deflated 45%)
#   adding: tikz_output/1709.06005v2_figure_16.tex (deflated 57%)
#   adding: tikz_output/1702.08108v3_figure_148.tex (deflated 51%)
#   adding: tikz_output/1910.03770v1_figure_1.tex (deflated 53%)
#   adding: tikz_output/1512.08296v3_figure_244.tex (deflated 49%)
#   adding: tikz_output/2102.00276v1_figure_599.tex (deflated 63%)
#   adding: tikz_output/2102.00276v1_figure_370.tex (deflated 67%)
#   adding: tikz_output/2006.03521v2_figure_1.tex (deflated 61%)
#   adding: tikz_output/1212.6076v1_figure_268.tex (deflated 62%)
#   adding: tikz_output/2104.07747v1_figure_190.tex (deflated 56%)
#   adding: tikz_output/2203.15964v1_figure_8.tex (deflated 54%)
#   adding: tikz_output/1709.02813v1_figure_32.tex (deflated 75%)
#   adding: tikz_output/1709.02813v1_figure_22.tex (deflated 57%)
#   adding: tikz_output/1007.0725v3_figure_11.tex (deflated 63%)
#   adding: tikz_output/2410.05120v1_figure_4.tex (deflated 72%)
#   adding: tikz_output/1709.02813v1_figure_29.tex (deflated 55%)
#   adding: tikz_output/1702.08108v3_figure_266.tex (deflated 61%)
#   adding: tikz_output/1702.08108v3_figure_3.tex (deflated 53%)
#   adding: tikz_output/1212.6076v1_figure_288.tex (deflated 59%)
#   adding: tikz_output/2102.00276v1_figure_159.tex (deflated 56%)
#   adding: tikz_output/2209.12947v2_figure_11.tex (deflated 59%)
#   adding: tikz_output/2203.15964v1_figure_60.tex (deflated 51%)
#   adding: tikz_output/1911.04630v3_figure_108.tex (deflated 76%)
#   adding: tikz_output/2102.00276v1_figure_45.tex (deflated 51%)
#   adding: tikz_output/2102.00276v1_figure_104.tex (deflated 50%)
#   adding: tikz_output/2210.09583v1_figure_95.tex (deflated 55%)
#   adding: tikz_output/1802.00689v1_figure_13.tex (deflated 61%)
#   adding: tikz_output/1001.4501v2_figure_4.tex (deflated 73%)
#   adding: tikz_output/1308.5150v2_figure_145.tex (deflated 61%)
#   adding: tikz_output/2102.00276v1_figure_403.tex (deflated 40%)
#   adding: tikz_output/1212.6076v1_figure_271.tex (deflated 62%)
#   adding: tikz_output/2106.10265v2_figure_57.tex (deflated 74%)
#   adding: tikz_output/1212.6076v1_figure_419.tex (deflated 56%)
#   adding: tikz_output/1512.08296v3_figure_141.tex (deflated 58%)
#   adding: tikz_output/1911.04630v3_figure_24.tex (deflated 57%)
#   adding: tikz_output/1512.08296v3_figure_190.tex (deflated 67%)
#   adding: tikz_output/2203.15964v1_figure_91.tex (deflated 59%)
#   adding: tikz_output/2211.15989v4_figure_1.tex (deflated 57%)
#   adding: tikz_output/2106.10265v2_figure_43.tex (deflated 78%)
#   adding: tikz_output/1212.6076v1_figure_109.tex (deflated 59%)
#   adding: tikz_output/1703.08747v3_figure_2.tex (deflated 54%)
#   adding: tikz_output/1308.5150v2_figure_23.tex (deflated 70%)
#   adding: tikz_output/2305.19686v2_figure_12.tex (deflated 71%)
#   adding: tikz_output/2404.18921v2_figure_2.tex (deflated 59%)
#   adding: tikz_output/1911.04630v3_figure_63.tex (deflated 58%)
#   adding: tikz_output/2104.07747v1_figure_72.tex (deflated 54%)
#   adding: tikz_output/2102.00276v1_figure_475.tex (deflated 68%)
#   adding: tikz_output/2305.19686v2_figure_51.tex (deflated 76%)
#   adding: tikz_output/1709.02813v1_figure_20.tex (deflated 72%)
#   adding: tikz_output/1709.06005v2_figure_144.tex (deflated 54%)
#   adding: tikz_output/1609.02091v2_figure_35.tex (deflated 80%)
#   adding: tikz_output/2203.15964v1_figure_77.tex (deflated 60%)
#   adding: tikz_output/2303.11845v2_figure_2.tex (deflated 67%)
#   adding: tikz_output/2102.00276v1_figure_65.tex (deflated 58%)
#   adding: tikz_output/1504.07671v2_figure_81.tex (deflated 59%)
#   adding: tikz_output/1508.05445v1_figure_15.tex (deflated 71%)
#   adding: tikz_output/1702.08108v3_figure_156.tex (deflated 51%)
#   adding: tikz_output/2110.04212v2_figure_12.tex (deflated 56%)
#   adding: tikz_output/1512.08296v3_figure_32.tex (deflated 51%)
#   adding: tikz_output/2102.00276v1_figure_97.tex (deflated 50%)
#   adding: tikz_output/2104.07747v1_figure_75.tex (deflated 59%)
#   adding: tikz_output/2311.17692v2_figure_38.tex (deflated 59%)
#   adding: tikz_output/2207.00580v1_figure_19.tex (deflated 64%)
#   adding: tikz_output/1811.01125v1_figure_1.tex (deflated 80%)
#   adding: tikz_output/2102.00276v1_figure_152.tex (deflated 56%)
#   adding: tikz_output/2102.00276v1_figure_166.tex (deflated 61%)
#   adding: tikz_output/2106.10265v2_figure_21.tex (deflated 78%)
#   adding: tikz_output/1512.08296v3_figure_87.tex (deflated 56%)
#   adding: tikz_output/2207.01540v2_figure_1.tex (deflated 89%)
#   adding: tikz_output/2303.11845v2_figure_60.tex (deflated 82%)
#   adding: tikz_output/1911.04630v3_figure_27.tex (deflated 61%)
#   adding: tikz_output/2106.10265v2_figure_28.tex (deflated 82%)
#   adding: tikz_output/1609.02091v2_figure_14.tex (deflated 80%)
#   adding: tikz_output/1702.08108v3_figure_61.tex (deflated 55%)
#   adding: tikz_output/1212.6076v1_figure_64.tex (deflated 55%)
#   adding: tikz_output/0802.2225v2_figure_3.tex (deflated 58%)
#   adding: tikz_output/2102.01693v2_figure_9.tex (deflated 70%)
#   adding: tikz_output/2102.00276v1_figure_579.tex (deflated 56%)
#   adding: tikz_output/2203.14153v2_figure_12.tex (deflated 54%)
#   adding: tikz_output/2207.02243v1_figure_8.tex (deflated 64%)
#   adding: tikz_output/1212.6076v1_figure_225.tex (deflated 76%)
#   adding: tikz_output/1709.02813v1_figure_86.tex (deflated 62%)
#   adding: tikz_output/1512.08296v3_figure_93.tex (deflated 49%)
#   adding: tikz_output/2102.00276v1_figure_574.tex (deflated 71%)
#   adding: tikz_output/1308.5150v2_figure_5.tex (deflated 59%)
#   adding: tikz_output/1910.14584v2_figure_7.tex (deflated 83%)
#   adding: tikz_output/2207.00596v1_figure_15.tex (deflated 52%)
#   adding: tikz_output/1905.09890v2_figure_22.tex (deflated 80%)
#   adding: tikz_output/1605.00227v1_figure_12.tex (deflated 64%)
#   adding: tikz_output/1509.02804v2_figure_16.tex (deflated 73%)
#   adding: tikz_output/1702.08108v3_figure_102.tex (deflated 56%)
#   adding: tikz_output/2010.08524v1_figure_2.tex (deflated 70%)
#   adding: tikz_output/2102.00276v1_figure_108.tex (deflated 65%)
#   adding: tikz_output/2102.00276v1_figure_536.tex (deflated 66%)
#   adding: tikz_output/1512.08296v3_figure_230.tex (deflated 74%)
#   adding: tikz_output/2008.05577v2_figure_6.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_51.tex (deflated 54%)
#   adding: tikz_output/2106.01855v1_figure_50.tex (deflated 56%)
#   adding: tikz_output/1811.02515v1_figure_5.tex (deflated 78%)
#   adding: tikz_output/2007.15675v3_figure_95.tex (deflated 58%)
#   adding: tikz_output/1509.02804v2_figure_15.tex (deflated 72%)
#   adding: tikz_output/2106.10265v2_figure_32.tex (deflated 77%)
#   adding: tikz_output/1709.02813v1_figure_53.tex (deflated 60%)
#   adding: tikz_output/1212.6076v1_figure_275.tex (deflated 62%)
#   adding: tikz_output/1212.6076v1_figure_458.tex (deflated 54%)
#   adding: tikz_output/1910.03770v1_figure_5.tex (deflated 63%)
#   adding: tikz_output/2007.15675v3_figure_25.tex (deflated 55%)
#   adding: tikz_output/1608.04259v2_figure_56.tex (deflated 58%)
#   adding: tikz_output/2008.05577v2_figure_127.tex (deflated 63%)
#   adding: tikz_output/2203.15330v1_figure_9.tex (deflated 80%)
#   adding: tikz_output/2303.06211v2_figure_20.tex (deflated 61%)
#   adding: tikz_output/1302.0803v1_figure_12.tex (deflated 69%)
#   adding: tikz_output/1001.2020v9_figure_11.tex (deflated 54%)
#   adding: tikz_output/2102.00276v1_figure_308.tex (deflated 58%)
#   adding: tikz_output/1504.07671v2_figure_56.tex (deflated 58%)
#   adding: tikz_output/2102.01693v2_figure_1.tex (deflated 69%)
#   adding: tikz_output/1306.0074v4_figure_48.tex (deflated 64%)
#   adding: tikz_output/2203.15964v1_figure_51.tex (deflated 54%)
#   adding: tikz_output/1605.00227v1_figure_4.tex (deflated 61%)
#   adding: tikz_output/1004.3599v2_figure_9.tex (deflated 49%)
#   adding: tikz_output/2007.15675v3_figure_75.tex (deflated 51%)
#   adding: tikz_output/2106.10265v2_figure_47.tex (deflated 79%)
#   adding: tikz_output/1308.5150v2_figure_149.tex (deflated 77%)
#   adding: tikz_output/2305.05971v1_figure_1.tex (deflated 61%)
#   adding: tikz_output/2207.02243v1_figure_15.tex (deflated 60%)
#   adding: tikz_output/1709.06005v2_figure_98.tex (deflated 57%)
#   adding: tikz_output/1811.02515v1_figure_31.tex (deflated 77%)
#   adding: tikz_output/2102.00276v1_figure_164.tex (deflated 61%)
#   adding: tikz_output/2203.15964v1_figure_96.tex (deflated 52%)
#   adding: tikz_output/1903.11611v1_figure_12.tex (deflated 65%)
#   adding: tikz_output/2102.00276v1_figure_142.tex (deflated 47%)
#   adding: tikz_output/1609.07289v2_figure_16.tex (deflated 68%)
#   adding: tikz_output/1609.07289v2_figure_13.tex (deflated 58%)
#   adding: tikz_output/2404.09972v2_figure_17.tex (deflated 78%)
#   adding: tikz_output/1709.02813v1_figure_73.tex (deflated 71%)
#   adding: tikz_output/1308.5150v2_figure_17.tex (deflated 84%)
#   adding: tikz_output/1512.08296v3_figure_199.tex (deflated 51%)
#   adding: tikz_output/2007.15675v3_figure_109.tex (deflated 61%)
#   adding: tikz_output/2102.00276v1_figure_519.tex (deflated 62%)
#   adding: tikz_output/2007.15675v3_figure_69.tex (deflated 61%)
#   adding: tikz_output/1608.04259v2_figure_23.tex (deflated 44%)
#   adding: tikz_output/1702.08108v3_figure_147.tex (deflated 53%)
#   adding: tikz_output/1206.4138v2_figure_2.tex (deflated 65%)
#   adding: tikz_output/1212.6076v1_figure_113.tex (deflated 62%)
#   adding: tikz_output/2403.09580v2_figure_2.tex (deflated 51%)
#   adding: tikz_output/1709.02813v1_figure_101.tex (deflated 61%)
#   adding: tikz_output/1306.0074v4_figure_47.tex (deflated 66%)
#   adding: tikz_output/1702.08108v3_figure_82.tex (deflated 61%)
#   adding: tikz_output/1702.08108v3_figure_194.tex (deflated 56%)
#   adding: tikz_output/2110.04212v2_figure_31.tex (deflated 54%)
#   adding: tikz_output/2104.07747v1_figure_120.tex (deflated 53%)
#   adding: tikz_output/2311.17692v2_figure_35.tex (deflated 56%)
#   adding: tikz_output/2209.12947v2_figure_14.tex (deflated 60%)
#   adding: tikz_output/1212.6076v1_figure_219.tex (deflated 76%)
#   adding: tikz_output/1308.5150v2_figure_8.tex (deflated 53%)
#   adding: tikz_output/1504.07671v2_figure_35.tex (deflated 58%)
#   adding: tikz_output/2104.07747v1_figure_17.tex (deflated 54%)
#   adding: tikz_output/1802.00689v1_figure_58.tex (deflated 58%)
#   adding: tikz_output/1512.08296v3_figure_68.tex (deflated 45%)
#   adding: tikz_output/1709.06005v2_figure_14.tex (deflated 57%)
#   adding: tikz_output/1709.02813v1_figure_9.tex (deflated 54%)
#   adding: tikz_output/2207.02243v1_figure_111.tex (deflated 53%)
#   adding: tikz_output/1212.6076v1_figure_348.tex (deflated 64%)
#   adding: tikz_output/2102.00276v1_figure_470.tex (deflated 63%)
#   adding: tikz_output/1709.06005v2_figure_151.tex (deflated 55%)
#   adding: tikz_output/2102.00276v1_figure_49.tex (deflated 54%)
#   adding: tikz_output/2008.05577v2_figure_83.tex (deflated 74%)
#   adding: tikz_output/2104.07747v1_figure_45.tex (deflated 57%)
#   adding: tikz_output/2102.01693v2_figure_35.tex (deflated 85%)
#   adding: tikz_output/1212.6076v1_figure_379.tex (deflated 51%)
#   adding: tikz_output/2303.11845v2_figure_62.tex (deflated 73%)
#   adding: tikz_output/1003.5730v1_figure_26.tex (deflated 53%)
#   adding: tikz_output/2102.00276v1_figure_400.tex (deflated 47%)
#   adding: tikz_output/1308.5150v2_figure_86.tex (deflated 65%)
#   adding: tikz_output/1709.06005v2_figure_115.tex (deflated 57%)
#   adding: tikz_output/1709.06005v2_figure_36.tex (deflated 56%)
#   adding: tikz_output/2504.02023v1_figure_12.tex (deflated 70%)
#   adding: tikz_output/2102.00276v1_figure_266.tex (deflated 50%)
#   adding: tikz_output/1903.11611v1_figure_31.tex (deflated 52%)
#   adding: tikz_output/1001.2020v9_figure_39.tex (deflated 81%)
#   adding: tikz_output/2005.05893v3_figure_3.tex (deflated 64%)
#   adding: tikz_output/1212.6076v1_figure_332.tex (deflated 61%)
#   adding: tikz_output/1205.0022v2_figure_1.tex (deflated 56%)
#   adding: tikz_output/0905.1444v2_figure_5.tex (deflated 56%)
#   adding: tikz_output/2502.08039v2_figure_2.tex (deflated 54%)
#   adding: tikz_output/2106.01855v1_figure_60.tex (deflated 52%)
#   adding: tikz_output/1911.04630v3_figure_114.tex (deflated 60%)
#   adding: tikz_output/2106.01855v1_figure_56.tex (deflated 52%)
#   adding: tikz_output/2210.09583v1_figure_115.tex (deflated 55%)
#   adding: tikz_output/1004.3599v2_figure_1.tex (deflated 56%)
#   adding: tikz_output/2106.01855v1_figure_32.tex (deflated 52%)
#   adding: tikz_output/1212.6076v1_figure_251.tex (deflated 60%)
#   adding: tikz_output/1608.00253v1_figure_2.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_428.tex (deflated 58%)
#   adding: tikz_output/1709.02813v1_figure_42.tex (deflated 60%)
#   adding: tikz_output/2007.15675v3_figure_82.tex (deflated 53%)
#   adding: tikz_output/1709.02813v1_figure_4.tex (deflated 56%)
#   adding: tikz_output/1504.07671v2_figure_83.tex (deflated 58%)
#   adding: tikz_output/1504.07671v2_figure_15.tex (deflated 63%)
#   adding: tikz_output/2209.12947v2_figure_12.tex (deflated 61%)
#   adding: tikz_output/1702.08108v3_figure_127.tex (deflated 51%)
#   adding: tikz_output/1709.02813v1_figure_103.tex (deflated 66%)
#   adding: tikz_output/1911.04630v3_figure_54.tex (deflated 53%)
#   adding: tikz_output/1504.07671v2_figure_62.tex (deflated 58%)
#   adding: tikz_output/1212.6076v1_figure_283.tex (deflated 58%)
#   adding: tikz_output/1212.6076v1_figure_309.tex (deflated 55%)
#   adding: tikz_output/1812.02832v2_figure_26.tex (deflated 67%)
#   adding: tikz_output/2303.11845v2_figure_59.tex (deflated 73%)
#   adding: tikz_output/2104.07747v1_figure_1.tex (deflated 54%)
#   adding: tikz_output/1212.6076v1_figure_303.tex (deflated 55%)
#   adding: tikz_output/1702.08108v3_figure_33.tex (deflated 59%)
#   adding: tikz_output/1609.02091v2_figure_24.tex (deflated 79%)
#   adding: tikz_output/2102.00276v1_figure_136.tex (deflated 49%)
#   adding: tikz_output/1709.06005v2_figure_54.tex (deflated 56%)
#   adding: tikz_output/2104.07747v1_figure_49.tex (deflated 60%)
#   adding: tikz_output/2203.15964v1_figure_6.tex (deflated 54%)
#   adding: tikz_output/0809.1989v1_figure_2.tex (deflated 54%)
#   adding: tikz_output/1905.09890v2_figure_3.tex (deflated 68%)
#   adding: tikz_output/2008.05577v2_figure_55.tex (deflated 64%)
#   adding: tikz_output/1510.01556v2_figure_5.tex (deflated 60%)
#   adding: tikz_output/2008.05577v2_figure_33.tex (deflated 64%)
#   adding: tikz_output/2102.00276v1_figure_493.tex (deflated 63%)
#   adding: tikz_output/2007.15675v3_figure_50.tex (deflated 60%)
#   adding: tikz_output/1709.06005v2_figure_9.tex (deflated 57%)
#   adding: tikz_output/2008.05577v2_figure_22.tex (deflated 63%)
#   adding: tikz_output/1212.6076v1_figure_324.tex (deflated 64%)
#   adding: tikz_output/1510.08556v3_figure_3.tex (deflated 64%)
#   adding: tikz_output/2501.00614v9_figure_3.tex (deflated 54%)
#   adding: tikz_output/2409.05852v2_figure_11.tex (deflated 39%)
#   adding: tikz_output/2008.05577v2_figure_112.tex (deflated 62%)
#   adding: tikz_output/2012.00828v4_figure_8.tex (deflated 63%)
#   adding: tikz_output/2210.09583v1_figure_88.tex (deflated 54%)
#   adding: tikz_output/2305.19686v2_figure_30.tex (deflated 84%)
#   adding: tikz_output/1802.00689v1_figure_24.tex (deflated 59%)
#   adding: tikz_output/1504.07671v2_figure_60.tex (deflated 58%)
#   adding: tikz_output/1212.6076v1_figure_240.tex (deflated 62%)
#   adding: tikz_output/1308.5150v2_figure_25.tex (deflated 81%)
#   adding: tikz_output/1005.4559v7_figure_13.tex (deflated 58%)
#   adding: tikz_output/1702.08108v3_figure_257.tex (deflated 49%)
#   adding: tikz_output/1802.00689v1_figure_45.tex (deflated 60%)
#   adding: tikz_output/2311.17692v2_figure_72.tex (deflated 57%)
#   adding: tikz_output/2409.05852v2_figure_35.tex (deflated 55%)
#   adding: tikz_output/1512.08296v3_figure_22.tex (deflated 49%)
#   adding: tikz_output/1709.06005v2_figure_73.tex (deflated 55%)
#   adding: tikz_output/1709.06005v2_figure_33.tex (deflated 55%)
#   adding: tikz_output/1504.07671v2_figure_16.tex (deflated 63%)
#   adding: tikz_output/1512.08296v3_figure_2.tex (deflated 44%)
#   adding: tikz_output/1512.08296v3_figure_194.tex (deflated 52%)
#   adding: tikz_output/1903.11611v1_figure_6.tex (deflated 73%)
#   adding: tikz_output/2102.00276v1_figure_611.tex (deflated 63%)
#   adding: tikz_output/1508.05445v1_figure_23.tex (deflated 60%)
#   adding: tikz_output/1208.3163v2_figure_6.tex (deflated 53%)
#   adding: tikz_output/2210.09583v1_figure_51.tex (deflated 58%)
#   adding: tikz_output/2102.00276v1_figure_543.tex (deflated 71%)
#   adding: tikz_output/1308.5150v2_figure_35.tex (deflated 73%)
#   adding: tikz_output/2102.00276v1_figure_342.tex (deflated 64%)
#   adding: tikz_output/2104.07747v1_figure_189.tex (deflated 55%)
#   adding: tikz_output/1212.6076v1_figure_118.tex (deflated 72%)
#   adding: tikz_output/1903.11611v1_figure_13.tex (deflated 56%)
#   adding: tikz_output/1212.6076v1_figure_266.tex (deflated 62%)
#   adding: tikz_output/1512.08296v3_figure_11.tex (deflated 52%)
#   adding: tikz_output/1709.06005v2_figure_81.tex (deflated 56%)
#   adding: tikz_output/2303.11845v2_figure_51.tex (deflated 81%)
#   adding: tikz_output/2007.12931v2_figure_9.tex (deflated 54%)
#   adding: tikz_output/2404.09972v2_figure_14.tex (deflated 73%)
#   adding: tikz_output/2203.15964v1_figure_70.tex (deflated 60%)
#   adding: tikz_output/2102.00276v1_figure_483.tex (deflated 59%)
#   adding: tikz_output/1911.04630v3_figure_83.tex (deflated 53%)
#   adding: tikz_output/1711.05931v1_figure_8.tex (deflated 67%)
#   adding: tikz_output/2102.00276v1_figure_559.tex (deflated 53%)
#   adding: tikz_output/1702.08108v3_figure_272.tex (deflated 58%)
#   adding: tikz_output/2104.07747v1_figure_114.tex (deflated 62%)
#   adding: tikz_output/2102.00276v1_figure_355.tex (deflated 61%)
#   adding: tikz_output/1802.00689v1_figure_8.tex (deflated 62%)
#   adding: tikz_output/2102.00276v1_figure_201.tex (deflated 71%)
#   adding: tikz_output/1003.5730v1_figure_15.tex (deflated 49%)
#   adding: tikz_output/2008.05577v2_figure_85.tex (deflated 66%)
#   adding: tikz_output/1212.6076v1_figure_76.tex (deflated 62%)
#   adding: tikz_output/2104.07747v1_figure_169.tex (deflated 67%)
#   adding: tikz_output/1811.02515v1_figure_38.tex (deflated 61%)
#   adding: tikz_output/2104.07747v1_figure_226.tex (deflated 67%)
#   adding: tikz_output/1212.6076v1_figure_239.tex (deflated 74%)
#   adding: tikz_output/1511.09190v1_figure_4.tex (deflated 62%)
#   adding: tikz_output/1609.07289v2_figure_28.tex (deflated 67%)
#   adding: tikz_output/2412.13829v2_figure_7.tex (deflated 58%)
#   adding: tikz_output/2102.00276v1_figure_630.tex (deflated 42%)
#   adding: tikz_output/1709.06005v2_figure_125.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_583.tex (deflated 55%)
#   adding: tikz_output/1609.02091v2_figure_8.tex (deflated 82%)
#   adding: tikz_output/1811.02515v1_figure_17.tex (deflated 74%)
#   adding: tikz_output/1212.6076v1_figure_461.tex (deflated 68%)
#   adding: tikz_output/2104.07747v1_figure_146.tex (deflated 67%)
#   adding: tikz_output/1905.09890v2_figure_13.tex (deflated 80%)
#   adding: tikz_output/2106.12437v1_figure_1.tex (deflated 59%)
#   adding: tikz_output/2106.01855v1_figure_20.tex (deflated 57%)
#   adding: tikz_output/2101.00643v4_figure_12.tex (deflated 55%)
#   adding: tikz_output/1911.04630v3_figure_86.tex (deflated 52%)
#   adding: tikz_output/1811.02515v1_figure_3.tex (deflated 71%)
#   adding: tikz_output/1005.4559v7_figure_23.tex (deflated 57%)
#   adding: tikz_output/2106.01855v1_figure_25.tex (deflated 57%)
#   adding: tikz_output/1212.6076v1_figure_227.tex (deflated 51%)
#   adding: tikz_output/1903.11611v1_figure_37.tex (deflated 67%)
#   adding: tikz_output/1811.02515v1_figure_6.tex (deflated 53%)
#   adding: tikz_output/1709.06005v2_figure_95.tex (deflated 56%)
#   adding: tikz_output/1212.6076v1_figure_224.tex (deflated 75%)
#   adding: tikz_output/2102.00276v1_figure_498.tex (deflated 42%)
#   adding: tikz_output/1212.6076v1_figure_387.tex (deflated 56%)
#   adding: tikz_output/1512.08296v3_figure_235.tex (deflated 51%)
#   adding: tikz_output/1504.07671v2_figure_112.tex (deflated 64%)
#   adding: tikz_output/1504.07671v2_figure_31.tex (deflated 54%)
#   adding: tikz_output/1206.4138v2_figure_8.tex (deflated 49%)
#   adding: tikz_output/2203.15330v1_figure_28.tex (deflated 77%)
#   adding: tikz_output/2102.00276v1_figure_526.tex (deflated 61%)
#   adding: tikz_output/2012.00828v4_figure_5.tex (deflated 57%)
#   adding: tikz_output/2009.10266v1_figure_4.tex (deflated 73%)
#   adding: tikz_output/1911.04630v3_figure_36.tex (deflated 60%)
#   adding: tikz_output/2106.01855v1_figure_4.tex (deflated 58%)
#   adding: tikz_output/2210.09583v1_figure_44.tex (deflated 62%)
#   adding: tikz_output/1512.08296v3_figure_223.tex (deflated 61%)
#   adding: tikz_output/2305.19686v2_figure_26.tex (deflated 58%)
#   adding: tikz_output/1005.4559v7_figure_9.tex (deflated 56%)
#   adding: tikz_output/1802.00689v1_figure_53.tex (deflated 59%)
#   adding: tikz_output/2102.00276v1_figure_451.tex (deflated 50%)
#   adding: tikz_output/2102.01693v2_figure_33.tex (deflated 85%)
#   adding: tikz_output/1511.09190v1_figure_24.tex (deflated 62%)
#   adding: tikz_output/1512.08296v3_figure_1.tex (deflated 57%)
#   adding: tikz_output/1812.02832v2_figure_1.tex (deflated 67%)
#   adding: tikz_output/2102.00276v1_figure_593.tex (deflated 65%)
#   adding: tikz_output/2207.01540v2_figure_2.tex (deflated 88%)
#   adding: tikz_output/1702.08108v3_figure_255.tex (deflated 66%)
#   adding: tikz_output/1512.08296v3_figure_112.tex (deflated 61%)
#   adding: tikz_output/1306.0074v4_figure_13.tex (deflated 54%)
#   adding: tikz_output/1511.09190v1_figure_18.tex (deflated 61%)
#   adding: tikz_output/1911.04630v3_figure_18.tex (deflated 55%)
#   adding: tikz_output/2102.00276v1_figure_316.tex (deflated 63%)
#   adding: tikz_output/1004.3599v2_figure_25.tex (deflated 51%)
#   adding: tikz_output/2303.06211v2_figure_14.tex (deflated 81%)
#   adding: tikz_output/1212.6076v1_figure_431.tex (deflated 73%)
#   adding: tikz_output/1702.08108v3_figure_252.tex (deflated 66%)
#   adding: tikz_output/2203.15964v1_figure_85.tex (deflated 55%)
#   adding: tikz_output/2409.05852v2_figure_41.tex (deflated 61%)
#   adding: tikz_output/1212.6076v1_figure_2.tex (deflated 53%)
#   adding: tikz_output/1212.6076v1_figure_24.tex (deflated 73%)
#   adding: tikz_output/2409.05852v2_figure_17.tex (deflated 58%)
#   adding: tikz_output/2110.04212v2_figure_51.tex (deflated 53%)
#   adding: tikz_output/2409.05852v2_figure_56.tex (deflated 55%)
#   adding: tikz_output/1911.04630v3_figure_43.tex (deflated 52%)
#   adding: tikz_output/2104.07747v1_figure_129.tex (deflated 61%)
#   adding: tikz_output/1603.01117v2_figure_6.tex (deflated 77%)
#   adding: tikz_output/2207.02243v1_figure_86.tex (deflated 57%)
#   adding: tikz_output/1208.4188v1_figure_1.tex (deflated 46%)
#   adding: tikz_output/1212.6076v1_figure_295.tex (deflated 62%)
#   adding: tikz_output/2207.00580v1_figure_48.tex (deflated 66%)
#   adding: tikz_output/1308.5150v2_figure_183.tex (deflated 78%)
#   adding: tikz_output/2007.15675v3_figure_19.tex (deflated 57%)
#   adding: tikz_output/1903.11611v1_figure_15.tex (deflated 59%)
#   adding: tikz_output/1608.04259v2_figure_52.tex (deflated 57%)
#   adding: tikz_output/2203.10022v3_figure_18.tex (deflated 68%)
#   adding: tikz_output/2007.15675v3_figure_13.tex (deflated 60%)
#   adding: tikz_output/1512.08296v3_figure_81.tex (deflated 54%)
#   adding: tikz_output/1709.06005v2_figure_12.tex (deflated 55%)
#   adding: tikz_output/2203.15964v1_figure_5.tex (deflated 48%)
#   adding: tikz_output/2210.09583v1_figure_120.tex (deflated 54%)
#   adding: tikz_output/2303.11845v2_figure_40.tex (deflated 83%)
#   adding: tikz_output/1212.6076v1_figure_144.tex (deflated 71%)
#   adding: tikz_output/2102.00276v1_figure_310.tex (deflated 58%)
#   adding: tikz_output/1212.6076v1_figure_65.tex (deflated 56%)
#   adding: tikz_output/1410.2837v2_figure_3.tex (deflated 70%)
#   adding: tikz_output/2207.02243v1_figure_73.tex (deflated 58%)
#   adding: tikz_output/2009.10266v1_figure_3.tex (deflated 71%)
#   adding: tikz_output/1005.4559v7_figure_30.tex (deflated 57%)
#   adding: tikz_output/2203.15330v1_figure_34.tex (deflated 82%)
#   adding: tikz_output/2007.15675v3_figure_12.tex (deflated 53%)
#   adding: tikz_output/1410.2837v2_figure_6.tex (deflated 73%)
#   adding: tikz_output/2102.00276v1_figure_238.tex (deflated 43%)
#   adding: tikz_output/2106.01855v1_figure_13.tex (deflated 57%)
#   adding: tikz_output/2008.05577v2_figure_126.tex (deflated 75%)
#   adding: tikz_output/1911.04630v3_figure_4.tex (deflated 75%)
#   adding: tikz_output/1709.06005v2_figure_85.tex (deflated 57%)
#   adding: tikz_output/1508.05445v1_figure_12.tex (deflated 62%)
#   adding: tikz_output/1709.06005v2_figure_41.tex (deflated 55%)
#   adding: tikz_output/1702.08108v3_figure_203.tex (deflated 52%)
#   adding: tikz_output/2207.00580v1_figure_13.tex (deflated 60%)
#   adding: tikz_output/1911.04630v3_figure_87.tex (deflated 52%)
#   adding: tikz_output/2007.15675v3_figure_88.tex (deflated 51%)
#   adding: tikz_output/2402.00635v1_figure_22.tex (deflated 65%)
#   adding: tikz_output/1609.07289v2_figure_4.tex (deflated 48%)
#   adding: tikz_output/1504.07671v2_figure_72.tex (deflated 57%)
#   adding: tikz_output/1504.07671v2_figure_84.tex (deflated 59%)
#   adding: tikz_output/1812.02832v2_figure_33.tex (deflated 62%)
#   adding: tikz_output/2102.00276v1_figure_612.tex (deflated 55%)
#   adding: tikz_output/2207.02243v1_figure_93.tex (deflated 57%)
#   adding: tikz_output/1003.5730v1_figure_16.tex (deflated 48%)
#   adding: tikz_output/2102.01693v2_figure_21.tex (deflated 85%)
#   adding: tikz_output/1609.02091v2_figure_38.tex (deflated 68%)
#   adding: tikz_output/1512.08296v3_figure_179.tex (deflated 53%)
#   adding: tikz_output/1512.08296v3_figure_59.tex (deflated 54%)
#   adding: tikz_output/1709.06005v2_figure_38.tex (deflated 56%)
#   adding: tikz_output/1812.02832v2_figure_13.tex (deflated 65%)
#   adding: tikz_output/1410.8080v1_figure_6.tex (deflated 73%)
#   adding: tikz_output/2207.02243v1_figure_89.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_384.tex (deflated 69%)
#   adding: tikz_output/1802.00689v1_figure_52.tex (deflated 59%)
#   adding: tikz_output/2102.00276v1_figure_418.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_372.tex (deflated 67%)
#   adding: tikz_output/2404.18921v2_figure_21.tex (deflated 71%)
#   adding: tikz_output/2007.15675v3_figure_29.tex (deflated 62%)
#   adding: tikz_output/1512.08296v3_figure_124.tex (deflated 58%)
#   adding: tikz_output/1702.08108v3_figure_98.tex (deflated 56%)
#   adding: tikz_output/1702.08108v3_figure_93.tex (deflated 54%)
#   adding: tikz_output/1212.6076v1_figure_480.tex (deflated 62%)
#   adding: tikz_output/1206.4138v2_figure_12.tex (deflated 49%)
#   adding: tikz_output/2207.02243v1_figure_84.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_632.tex (deflated 43%)
#   adding: tikz_output/1603.01117v2_figure_15.tex (deflated 65%)
#   adding: tikz_output/2106.14211v4_figure_20.tex (deflated 59%)
#   adding: tikz_output/1702.08108v3_figure_207.tex (deflated 52%)
#   adding: tikz_output/2212.08509v1_figure_2.tex (deflated 60%)
#   adding: tikz_output/1508.05445v1_figure_36.tex (deflated 51%)
#   adding: tikz_output/2102.00276v1_figure_406.tex (deflated 59%)
#   adding: tikz_output/2007.15675v3_figure_30.tex (deflated 54%)
#   adding: tikz_output/1702.08108v3_figure_137.tex (deflated 52%)
#   adding: tikz_output/1511.09190v1_figure_7.tex (deflated 62%)
#   adding: tikz_output/2102.00276v1_figure_33.tex (deflated 43%)
#   adding: tikz_output/2104.07747v1_figure_5.tex (deflated 54%)
#   adding: tikz_output/2409.05852v2_figure_44.tex (deflated 53%)
#   adding: tikz_output/1511.09190v1_figure_3.tex (deflated 63%)
#   adding: tikz_output/2106.14211v4_figure_10.tex (deflated 64%)
#   adding: tikz_output/2501.00614v9_figure_15.tex (deflated 52%)
#   adding: tikz_output/1702.08108v3_figure_31.tex (deflated 52%)
#   adding: tikz_output/1410.4761v3_figure_12.tex (deflated 57%)
#   adding: tikz_output/1709.06005v2_figure_42.tex (deflated 54%)
#   adding: tikz_output/1709.02813v1_figure_23.tex (deflated 65%)
#   adding: tikz_output/2106.01855v1_figure_12.tex (deflated 58%)
#   adding: tikz_output/1911.04630v3_figure_56.tex (deflated 55%)
#   adding: tikz_output/2010.08524v1_figure_7.tex (deflated 65%)
#   adding: tikz_output/1308.5150v2_figure_85.tex (deflated 74%)
#   adding: tikz_output/1709.02813v1_figure_60.tex (deflated 67%)
#   adding: tikz_output/1212.6076v1_figure_317.tex (deflated 55%)
#   adding: tikz_output/2007.15675v3_figure_87.tex (deflated 58%)
#   adding: tikz_output/2210.09583v1_figure_122.tex (deflated 54%)
#   adding: tikz_output/2311.17692v2_figure_32.tex (deflated 53%)
#   adding: tikz_output/1709.06005v2_figure_24.tex (deflated 54%)
#   adding: tikz_output/1709.02813v1_figure_95.tex (deflated 66%)
#   adding: tikz_output/1308.5150v2_figure_21.tex (deflated 84%)
#   adding: tikz_output/2102.00276v1_figure_62.tex (deflated 66%)
#   adding: tikz_output/2310.16576v2_figure_4.tex (deflated 57%)
#   adding: tikz_output/2203.15330v1_figure_25.tex (deflated 77%)
#   adding: tikz_output/1001.4501v2_figure_6.tex (deflated 48%)
#   adding: tikz_output/2207.00596v1_figure_1.tex (deflated 56%)
#   adding: tikz_output/2203.15964v1_figure_117.tex (deflated 59%)
#   adding: tikz_output/1511.09190v1_figure_22.tex (deflated 62%)
#   adding: tikz_output/1302.0803v1_figure_14.tex (deflated 55%)
#   adding: tikz_output/2112.08114v3_figure_5.tex (deflated 53%)
#   adding: tikz_output/1512.08296v3_figure_147.tex (deflated 48%)
#   adding: tikz_output/1709.06005v2_figure_130.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_14.tex (deflated 42%)
#   adding: tikz_output/1709.02813v1_figure_7.tex (deflated 70%)
#   adding: tikz_output/1903.11611v1_figure_33.tex (deflated 52%)
#   adding: tikz_output/2409.05852v2_figure_31.tex (deflated 49%)
#   adding: tikz_output/0905.1444v2_figure_7.tex (deflated 60%)
#   adding: tikz_output/1512.08296v3_figure_211.tex (deflated 53%)
#   adding: tikz_output/1505.00048v1_figure_26.tex (deflated 50%)
#   adding: tikz_output/2203.15964v1_figure_28.tex (deflated 70%)
#   adding: tikz_output/1903.11611v1_figure_25.tex (deflated 62%)
#   adding: tikz_output/2102.00276v1_figure_59.tex (deflated 56%)
#   adding: tikz_output/2104.07747v1_figure_173.tex (deflated 69%)
#   adding: tikz_output/2303.11845v2_figure_50.tex (deflated 63%)
#   adding: tikz_output/1508.05445v1_figure_29.tex (deflated 43%)
#   adding: tikz_output/2104.07747v1_figure_139.tex (deflated 61%)
#   adding: tikz_output/2102.00276v1_figure_150.tex (deflated 58%)
#   adding: tikz_output/2210.09583v1_figure_20.tex (deflated 55%)
#   adding: tikz_output/2210.09583v1_figure_64.tex (deflated 55%)
#   adding: tikz_output/2311.17692v2_figure_22.tex (deflated 61%)
#   adding: tikz_output/2305.12006v3_figure_2.tex (deflated 59%)
#   adding: tikz_output/1701.06579v2_figure_2.tex (deflated 71%)
#   adding: tikz_output/1904.03550v4_figure_17.tex (deflated 70%)
#   adding: tikz_output/1512.08296v3_figure_105.tex (deflated 56%)
#   adding: tikz_output/1702.08108v3_figure_177.tex (deflated 54%)
#   adding: tikz_output/1212.6076v1_figure_371.tex (deflated 56%)
#   adding: tikz_output/2008.05577v2_figure_47.tex (deflated 64%)
#   adding: tikz_output/2106.14211v4_figure_34.tex (deflated 65%)
#   adding: tikz_output/2104.07747v1_figure_188.tex (deflated 59%)
#   adding: tikz_output/2102.00276v1_figure_410.tex (deflated 62%)
# ...
#   adding: tikz_output/1212.6076v1_figure_37.tex (deflated 57%)
#   adding: tikz_output/1504.07671v2_figure_51.tex (deflated 61%)
#   adding: tikz_output/2106.01855v1_figure_80.tex (deflated 52%)
#   adding: tikz_output/2501.00614v9_figure_22.tex (deflated 60%)
#   adding: tikz_output/1212.6076v1_figure_359.tex (deflated 55%)
#   adding: tikz_output/1512.08296v3_figure_197.tex (deflated 51%)
#   adding: tikz_output/2310.16576v2_figure_18.tex (deflated 68%)
#   adding: tikz_output/2008.05577v2_figure_19.tex (deflated 67%)
#   adding: tikz_output/2102.00276v1_figure_90.tex (deflated 55%)
#   adding: tikz_output/1709.06005v2_figure_88.tex (deflated 54%)
#   adding: tikz_output/2407.07635v2_figure_1.tex (deflated 61%)
#   adding: tikz_output/1510.01556v2_figure_36.tex (deflated 61%)
#   adding: tikz_output/1802.00689v1_figure_7.tex (deflated 61%)
#   adding: tikz_output/1504.07671v2_figure_95.tex (deflated 59%)
#   adding: tikz_output/1308.5150v2_figure_22.tex (deflated 80%)
#   adding: tikz_output/2311.17692v2_figure_27.tex (deflated 56%)
#   adding: tikz_output/1505.00048v1_figure_18.tex (deflated 55%)
#   adding: tikz_output/2309.13440v1_figure_2.tex (deflated 77%)
#   adding: tikz_output/2203.15964v1_figure_36.tex (deflated 53%)
#   adding: tikz_output/1911.04630v3_figure_12.tex (deflated 52%)
#   adding: tikz_output/2102.00276v1_figure_248.tex (deflated 54%)
#   adding: tikz_output/2110.04212v2_figure_13.tex (deflated 56%)
#   adding: tikz_output/2203.15964v1_figure_38.tex (deflated 54%)
#   adding: tikz_output/2305.05971v1_figure_8.tex (deflated 59%)
#   adding: tikz_output/2104.07747v1_figure_98.tex (deflated 71%)
#   adding: tikz_output/2201.05622v2_figure_3.tex (deflated 58%)
#   adding: tikz_output/1212.6076v1_figure_162.tex (deflated 56%)
#   adding: tikz_output/2102.01693v2_figure_17.tex (deflated 82%)
#   adding: tikz_output/1306.0074v4_figure_27.tex (deflated 54%)
#   adding: tikz_output/1812.02832v2_figure_44.tex (deflated 58%)
#   adding: tikz_output/2007.12931v2_figure_5.tex (deflated 53%)
#   adding: tikz_output/1911.04630v3_figure_111.tex (deflated 52%)
#   adding: tikz_output/2102.00276v1_figure_36.tex (deflated 53%)
#   adding: tikz_output/2102.00276v1_figure_102.tex (deflated 53%)
#   adding: tikz_output/2102.00276v1_figure_207.tex (deflated 64%)
#   adding: tikz_output/2102.00276v1_figure_530.tex (deflated 59%)
#   adding: tikz_output/2203.15964v1_figure_121.tex (deflated 63%)
#   adding: tikz_output/1306.0074v4_figure_52.tex (deflated 58%)
#   adding: tikz_output/2102.00276v1_figure_173.tex (deflated 62%)
#   adding: tikz_output/1212.6076v1_figure_430.tex (deflated 73%)
#   adding: tikz_output/2405.19979v2_figure_5.tex (deflated 57%)
#   adding: tikz_output/1911.04630v3_figure_26.tex (deflated 53%)
#   adding: tikz_output/2102.00276v1_figure_357.tex (deflated 56%)
#   adding: tikz_output/2305.19686v2_figure_1.tex (deflated 58%)
#   adding: tikz_output/1212.6076v1_figure_6.tex (deflated 51%)
#   adding: tikz_output/2104.07747v1_figure_66.tex (deflated 56%)
#   adding: tikz_output/1512.08296v3_figure_92.tex (deflated 49%)
#   adding: tikz_output/2102.00276v1_figure_564.tex (deflated 52%)
#   adding: tikz_output/2110.06092v2_figure_5.tex (deflated 64%)
#   adding: tikz_output/2104.07747v1_figure_164.tex (deflated 57%)
#   adding: tikz_output/2203.15330v1_figure_57.tex (deflated 90%)
#   adding: tikz_output/2102.00276v1_figure_6.tex (deflated 50%)
#   adding: tikz_output/1702.08108v3_figure_283.tex (deflated 58%)
#   adding: tikz_output/2102.00276v1_figure_171.tex (deflated 58%)
#   adding: tikz_output/2303.06211v2_figure_55.tex (deflated 71%)
#   adding: tikz_output/2311.17692v2_figure_3.tex (deflated 54%)
#   adding: tikz_output/1609.07289v2_figure_25.tex (deflated 63%)
#   adding: tikz_output/1608.04259v2_figure_22.tex (deflated 55%)
#   adding: tikz_output/2106.10265v2_figure_59.tex (deflated 66%)
#   adding: tikz_output/1611.09211v1_figure_2.tex (deflated 51%)
#   adding: tikz_output/1307.2100v1_figure_2.tex (deflated 65%)
#   adding: tikz_output/2106.14211v4_figure_29.tex (deflated 63%)
#   adding: tikz_output/2102.01693v2_figure_34.tex (deflated 86%)
#   adding: tikz_output/2311.17692v2_figure_25.tex (deflated 58%)
#   adding: tikz_output/1709.02813v1_figure_1.tex (deflated 74%)
#   adding: tikz_output/1511.09190v1_figure_19.tex (deflated 61%)
#   adding: tikz_output/2311.17692v2_figure_5.tex (deflated 53%)
#   adding: tikz_output/1308.5150v2_figure_170.tex (deflated 81%)
#   adding: tikz_output/2201.05622v2_figure_1.tex (deflated 56%)
#   adding: tikz_output/1306.0074v4_figure_6.tex (deflated 58%)
#   adding: tikz_output/2102.00276v1_figure_582.tex (deflated 56%)
#   adding: tikz_output/2207.02243v1_figure_112.tex (deflated 56%)
#   adding: tikz_output/1504.07671v2_figure_67.tex (deflated 62%)
#   adding: tikz_output/1212.6076v1_figure_32.tex (deflated 70%)
#   adding: tikz_output/1702.08108v3_figure_284.tex (deflated 50%)
#   adding: tikz_output/2102.00276v1_figure_234.tex (deflated 57%)
#   adding: tikz_output/1811.02515v1_figure_32.tex (deflated 54%)
#   adding: tikz_output/1802.00689v1_figure_55.tex (deflated 58%)
#   adding: tikz_output/1812.02832v2_figure_11.tex (deflated 63%)
#   adding: tikz_output/1802.00689v1_figure_34.tex (deflated 59%)
#   adding: tikz_output/1609.02091v2_figure_40.tex (deflated 71%)
#   adding: tikz_output/1512.08296v3_figure_69.tex (deflated 47%)
#   adding: tikz_output/2102.00276v1_figure_484.tex (deflated 65%)
#   adding: tikz_output/2102.00276v1_figure_285.tex (deflated 49%)
#   adding: tikz_output/1709.06005v2_figure_25.tex (deflated 58%)
#   adding: tikz_output/1308.5150v2_figure_176.tex (deflated 78%)
#   adding: tikz_output/2303.11845v2_figure_48.tex (deflated 64%)
#   adding: tikz_output/1005.4559v7_figure_14.tex (deflated 59%)
#   adding: tikz_output/1308.5150v2_figure_93.tex (deflated 79%)
#   adding: tikz_output/1609.07289v2_figure_6.tex (deflated 52%)
#   adding: tikz_output/1512.08296v3_figure_130.tex (deflated 57%)
#   adding: tikz_output/1702.08108v3_figure_130.tex (deflated 52%)
#   adding: tikz_output/1510.05330v2_figure_2.tex (deflated 46%)
#   adding: tikz_output/1812.02832v2_figure_43.tex (deflated 59%)
#   adding: tikz_output/2101.00643v4_figure_11.tex (deflated 58%)
#   adding: tikz_output/2102.00276v1_figure_330.tex (deflated 64%)
#   adding: tikz_output/2102.01693v2_figure_3.tex (deflated 84%)
#   adding: tikz_output/2102.00276v1_figure_390.tex (deflated 65%)
#   adding: tikz_output/2402.00635v1_figure_8.tex (deflated 59%)
#   adding: tikz_output/1212.6076v1_figure_36.tex (deflated 61%)
#   adding: tikz_output/1905.09890v2_figure_14.tex (deflated 80%)
#   adding: tikz_output/2102.00276v1_figure_540.tex (deflated 67%)
#   adding: tikz_output/1611.09211v1_figure_6.tex (deflated 49%)
#   adding: tikz_output/2102.00276v1_figure_20.tex (deflated 46%)
#   adding: tikz_output/1208.4188v1_figure_3.tex (deflated 51%)
#   adding: tikz_output/2303.11845v2_figure_1.tex (deflated 70%)
#   adding: tikz_output/2102.00276v1_figure_429.tex (deflated 57%)
#   adding: tikz_output/2207.13416v1_figure_6.tex (deflated 51%)
#   adding: tikz_output/1410.6857v2_figure_1.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_296.tex (deflated 66%)
#   adding: tikz_output/2203.15330v1_figure_19.tex (deflated 59%)
#   adding: tikz_output/1102.3549v1_figure_3.tex (deflated 75%)
#   adding: tikz_output/1811.02515v1_figure_18.tex (deflated 74%)
#   adding: tikz_output/1306.0074v4_figure_53.tex (deflated 55%)
#   adding: tikz_output/2102.00276v1_figure_471.tex (deflated 59%)
#   adding: tikz_output/1609.02091v2_figure_32.tex (deflated 76%)
#   adding: tikz_output/1603.01117v2_figure_26.tex (deflated 66%)
#   adding: tikz_output/2102.00276v1_figure_623.tex (deflated 45%)
#   adding: tikz_output/2102.01693v2_figure_18.tex (deflated 81%)
#   adding: tikz_output/2210.09583v1_figure_84.tex (deflated 54%)
#   adding: tikz_output/2008.05577v2_figure_23.tex (deflated 61%)
#   adding: tikz_output/1212.6076v1_figure_477.tex (deflated 49%)
#   adding: tikz_output/1709.02813v1_figure_106.tex (deflated 64%)
#   adding: tikz_output/2305.19686v2_figure_46.tex (deflated 57%)
#   adding: tikz_output/2104.07747v1_figure_85.tex (deflated 73%)
#   adding: tikz_output/2011.04350v5_figure_1.tex (deflated 58%)
#   adding: tikz_output/2501.00614v9_figure_7.tex (deflated 54%)
#   adding: tikz_output/1212.6076v1_figure_39.tex (deflated 56%)
#   adding: tikz_output/2305.19686v2_figure_10.tex (deflated 72%)
#   adding: tikz_output/1212.6076v1_figure_483.tex (deflated 62%)
#   adding: tikz_output/1212.6076v1_figure_210.tex (deflated 72%)
#   adding: tikz_output/1702.08108v3_figure_251.tex (deflated 67%)
#   adding: tikz_output/1508.05445v1_figure_38.tex (deflated 55%)
#   adding: tikz_output/1212.6076v1_figure_193.tex (deflated 75%)
#   adding: tikz_output/2106.10265v2_figure_41.tex (deflated 77%)
#   adding: tikz_output/2006.03521v2_figure_2.tex (deflated 56%)
#   adding: tikz_output/1212.6076v1_figure_388.tex (deflated 58%)
#   adding: tikz_output/1003.5730v1_figure_3.tex (deflated 44%)
#   adding: tikz_output/1910.14584v2_figure_2.tex (deflated 81%)
#   adding: tikz_output/1702.08108v3_figure_186.tex (deflated 54%)
#   adding: tikz_output/1212.6076v1_figure_415.tex (deflated 57%)
#   adding: tikz_output/2102.00276v1_figure_482.tex (deflated 61%)
#   adding: tikz_output/2102.00276v1_figure_232.tex (deflated 43%)
#   adding: tikz_output/2102.00276v1_figure_235.tex (deflated 56%)
#   adding: tikz_output/1603.01117v2_figure_27.tex (deflated 74%)
#   adding: tikz_output/1609.07289v2_figure_20.tex (deflated 53%)
#   adding: tikz_output/2106.10265v2_figure_36.tex (deflated 72%)
#   adding: tikz_output/2207.02243v1_figure_57.tex (deflated 63%)
#   adding: tikz_output/1905.09890v2_figure_12.tex (deflated 79%)
#   adding: tikz_output/2106.10265v2_figure_46.tex (deflated 83%)
#   adding: tikz_output/1505.00048v1_figure_31.tex (deflated 58%)
#   adding: tikz_output/1212.6076v1_figure_352.tex (deflated 52%)
#   adding: tikz_output/1509.02804v2_figure_11.tex (deflated 65%)
#   adding: tikz_output/1505.00048v1_figure_23.tex (deflated 63%)
#   adding: tikz_output/2102.00276v1_figure_212.tex (deflated 65%)
#   adding: tikz_output/1306.0074v4_figure_1.tex (deflated 57%)
#   adding: tikz_output/2207.02243v1_figure_109.tex (deflated 53%)
#   adding: tikz_output/1410.4761v3_figure_2.tex (deflated 53%)
#   adding: tikz_output/2203.15964v1_figure_87.tex (deflated 71%)
#   adding: tikz_output/1505.00048v1_figure_17.tex (deflated 67%)
#   adding: tikz_output/2110.04212v2_figure_20.tex (deflated 56%)
#   adding: tikz_output/1212.6076v1_figure_384.tex (deflated 55%)
#   adding: tikz_output/2007.12931v2_figure_1.tex (deflated 51%)
#   adding: tikz_output/1212.6076v1_figure_73.tex (deflated 56%)
#   adding: tikz_output/1308.5150v2_figure_162.tex (deflated 78%)
#   adding: tikz_output/2102.01693v2_figure_27.tex (deflated 85%)
#   adding: tikz_output/2102.00276v1_figure_441.tex (deflated 62%)
#   adding: tikz_output/1903.11611v1_figure_10.tex (deflated 56%)
#   adding: tikz_output/1410.2837v2_figure_9.tex (deflated 71%)
#   adding: tikz_output/2207.01540v2_figure_16.tex (deflated 89%)
#   adding: tikz_output/1004.0060v1_figure_3.tex (deflated 57%)
#   adding: tikz_output/2203.10022v3_figure_14.tex (deflated 74%)
#   adding: tikz_output/1212.6076v1_figure_463.tex (deflated 72%)
#   adding: tikz_output/2203.15964v1_figure_2.tex (deflated 57%)
#   adding: tikz_output/1212.6076v1_figure_464.tex (deflated 72%)
#   adding: tikz_output/2102.00276v1_figure_169.tex (deflated 60%)
#   adding: tikz_output/2203.15964v1_figure_72.tex (deflated 60%)
#   adding: tikz_output/1504.07671v2_figure_57.tex (deflated 58%)
#   adding: tikz_output/2102.00276v1_figure_570.tex (deflated 67%)
#   adding: tikz_output/2106.01855v1_figure_61.tex (deflated 56%)
#   adding: tikz_output/2110.04212v2_figure_33.tex (deflated 55%)
#   adding: tikz_output/1702.08108v3_figure_89.tex (deflated 52%)
#   adding: tikz_output/2305.19686v2_figure_17.tex (deflated 78%)
#   adding: tikz_output/2106.10265v2_figure_50.tex (deflated 74%)
#   adding: tikz_output/1702.08108v3_figure_224.tex (deflated 53%)
#   adding: tikz_output/1609.00270v1_figure_3.tex (deflated 62%)
#   adding: tikz_output/1212.6076v1_figure_292.tex (deflated 62%)
#   adding: tikz_output/1212.6076v1_figure_365.tex (deflated 52%)
#   adding: tikz_output/1212.6076v1_figure_33.tex (deflated 60%)
#   adding: tikz_output/2102.00276v1_figure_528.tex (deflated 61%)
#   adding: tikz_output/2203.15964v1_figure_114.tex (deflated 65%)
#   adding: tikz_output/1702.08108v3_figure_151.tex (deflated 53%)
#   adding: tikz_output/2102.00276v1_figure_462.tex (deflated 59%)
#   adding: tikz_output/1206.4138v2_figure_15.tex (deflated 51%)
#   adding: tikz_output/2311.17692v2_figure_13.tex (deflated 59%)
#   adding: tikz_output/2208.14566v1_figure_1.tex (deflated 54%)
#   adding: tikz_output/1702.08108v3_figure_144.tex (deflated 52%)
#   adding: tikz_output/1709.02813v1_figure_41.tex (deflated 60%)
#   adding: tikz_output/1212.6076v1_figure_114.tex (deflated 61%)
#   adding: tikz_output/2303.11845v2_figure_74.tex (deflated 70%)
#   adding: tikz_output/1709.02813v1_figure_79.tex (deflated 71%)
#   adding: tikz_output/1812.02832v2_figure_46.tex (deflated 66%)
#   adding: tikz_output/2102.00276v1_figure_614.tex (deflated 67%)
#   adding: tikz_output/2007.15675v3_figure_48.tex (deflated 63%)
#   adding: tikz_output/2102.00276v1_figure_576.tex (deflated 62%)
#   adding: tikz_output/2207.02243v1_figure_24.tex (deflated 60%)
#   adding: tikz_output/1510.01556v2_figure_48.tex (deflated 68%)
#   adding: tikz_output/2203.15964v1_figure_43.tex (deflated 54%)
#   adding: tikz_output/2207.01540v2_figure_28.tex (deflated 95%)
#   adding: tikz_output/2102.01693v2_figure_47.tex (deflated 77%)
#   adding: tikz_output/1005.4559v7_figure_21.tex (deflated 62%)
#   adding: tikz_output/2210.09583v1_figure_11.tex (deflated 55%)
#   adding: tikz_output/1410.8080v1_figure_1.tex (deflated 64%)
#   adding: tikz_output/1001.4501v2_figure_2.tex (deflated 70%)
#   adding: tikz_output/1308.5150v2_figure_47.tex (deflated 63%)
#   adding: tikz_output/2102.00276v1_figure_491.tex (deflated 65%)
#   adding: tikz_output/2102.00276v1_figure_358.tex (deflated 56%)
#   adding: tikz_output/1212.6076v1_figure_407.tex (deflated 65%)
#   adding: tikz_output/1212.6076v1_figure_315.tex (deflated 58%)
#   adding: tikz_output/1711.05931v1_figure_5.tex (deflated 61%)
#   adding: tikz_output/1308.5150v2_figure_184.tex (deflated 78%)
#   adding: tikz_output/2310.07385v1_figure_2.tex (deflated 38%)
#   adding: tikz_output/1709.02813v1_figure_13.tex (deflated 55%)
#   adding: tikz_output/1911.04630v3_figure_2.tex (deflated 71%)
#   adding: tikz_output/2203.10022v3_figure_16.tex (deflated 65%)
#   adding: tikz_output/2201.05622v2_figure_4.tex (deflated 59%)
#   adding: tikz_output/1212.6076v1_figure_301.tex (deflated 55%)
#   adding: tikz_output/1512.08296v3_figure_151.tex (deflated 48%)
#   adding: tikz_output/1609.07289v2_figure_12.tex (deflated 58%)
#   adding: tikz_output/1306.0074v4_figure_7.tex (deflated 58%)
#   adding: tikz_output/1702.08108v3_figure_208.tex (deflated 53%)
#   adding: tikz_output/1512.08296v3_figure_152.tex (deflated 54%)
#   adding: tikz_output/1109.4090v1_figure_4.tex (deflated 66%)
#   adding: tikz_output/1308.5150v2_figure_132.tex (deflated 60%)
#   adding: tikz_output/1703.08747v3_figure_4.tex (deflated 54%)
#   adding: tikz_output/2211.16438v1_figure_1.tex (deflated 60%)
#   adding: tikz_output/1001.2020v9_figure_23.tex (deflated 65%)
#   adding: tikz_output/2102.00276v1_figure_78.tex (deflated 65%)
#   adding: tikz_output/2104.07747v1_figure_102.tex (deflated 59%)
#   adding: tikz_output/2102.00276v1_figure_68.tex (deflated 57%)
#   adding: tikz_output/1308.5150v2_figure_110.tex (deflated 64%)
#   adding: tikz_output/1212.6076v1_figure_257.tex (deflated 60%)
#   adding: tikz_output/2207.02243v1_figure_62.tex (deflated 56%)
#   adding: tikz_output/2311.17692v2_figure_51.tex (deflated 57%)
#   adding: tikz_output/1212.6076v1_figure_17.tex (deflated 61%)
#   adding: tikz_output/1609.07289v2_figure_18.tex (deflated 53%)
#   adding: tikz_output/2102.00276v1_figure_467.tex (deflated 67%)
#   adding: tikz_output/1702.08108v3_figure_21.tex (deflated 52%)
#   adding: tikz_output/2007.15675v3_figure_53.tex (deflated 64%)
#   adding: tikz_output/1212.6076v1_figure_124.tex (deflated 72%)

# %%
from google.colab import files

# Download the zip file
files.download('tikz_collectionv2.csv')
